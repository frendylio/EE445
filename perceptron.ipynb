# %% [markdown]
# In this assignment, we will learn how to build simple neural networks. We will build the three basic blocks we learnt in class: the perceptron, the LinearRegression classifier (Fisher discriminant) and the Support Vector Machine. All these three are just one-neuron "networks". In each case, we train the neuron (ie set the weights) by minimizing a different kind of loss function. Specifically:
# 1. Perceptron: activation is linear, train by minimizing the ramp loss = max(0, -y_true* y_predicted)
# 2. Fisher Discriminant: activation is linear, train by minimizing square loss (y_true - y_predicted)^2
# 3. Support vector machine: activation is linear (for now). We train by minimizing the hinge loss = max(0, 1- y_true* y_predicted), but to the hinge loss, we add a (1/C)||w||^2 term, where C is some constant. In machine learning parlance, adding a ||w||^2 term to the loss is called l2 regularization. So this is a single neuron, linear activation, trained using hinge loss with l2 regularization.
#
# This assignment will build all three neurons. Rather than code each one from scratch, we are going to use off-the-shelf components from keras, and use gradient descent to learn the weights. To help you, I have simulated the one neuron network that simulates the perceptron completely (and as you can see, it does separate linearly separable data by running enough epochs).
#
# In the code below, every component of keras is stripped down to its bare essentials, so we know what is happening. We will learn to add back the more complicated parts later.

# %%
import numpy as np


import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# A good linearly separable dataset is the IRIS dataset (contains dimensions of various flowers, the task is to classify the type of flower). It has a nice backstory as well.

# %%
from sklearn import datasets

iris = datasets.load_iris()

# let us check what has been loaded
print(dir(iris))
# a short description
print(iris.DESCR)
print(iris.target_names)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target', 'target_names']
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# Let us visualize the dataset, after all there are only 4 features. Let us plot all examples in the space of the first three features. Based on the class (0,1,2---corresponding to setosa, versicolor and virginica respectively), we assign a different color. The darkest dots are the setosa examples, the green ones are versicolor and the yellow ones are virginica (compare with the colorbar at 0, 1 and 2, I am a little colorblind myself).

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

fig = plt.figure()
ax = plt.axes(projection='3d')
figiris = ax.scatter(iris.data[:,0],iris.data[:,1],iris.data[:,2],c=iris.target)
ax.set_xlabel(iris.feature_names[0]+' (0)')
ax.set_ylabel(iris.feature_names[1]+' (1)')
ax.set_zlabel(iris.feature_names[2]+' (2)')

# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)


plt.colorbar(figiris)
ax.view_init(45,45)

# %% [markdown]
# Choosing sepal width (feature 1) against petal length (feature 2) seems to yield linearly separable points if we want to classify the setosia (label 0) examples against all the other examples. Let us double check that.

# %%
fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 0, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')

# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)

# %% [markdown]
# Sure enough it works. Let us train a perceptron with this data. Our training data are features 1 and 2, label is 1 if setosia, -1 else. A perceptron is a neural network with 1 layer, 1 node, linear activation function, and the ramp loss we discussed in class. Its inputs are weight two vectors (features 1 and 2).
#
# We could implement the perceptron algorithm as a loop of course. But we have a better way: to do this in keras. keras allows us to build a wide variety of networks either by simply building them layer by layer (Sequential) or as arbitrary graphs (we will worry about this later).
#
# With the perceptron,
# 1. The topology is trivial---just a single layer with one neuron
# 2. The input here has dimension 2 (feature 1 and 2)
#
# Let us first put that into keras. keras also wants to know what activation function to use. To understand the activation function, recall that the neuron computes the dot product between the example and its weights. The activation function is applied to the dot product.
#
# When we learnt about this topic, we initially used the sign activation function (label was the sign of the dot product). But doing so yielded a loss terrain with plateaus at different heights (run the old demo again if you do not remember). It is difficult to figure out which direction to move while doing gradient descent, so we shifted to the ramp loss instead. To compute the ramp loss, we just ask the neuron to output the entire dot product---so essentially, we want the activation function to leave the dot product unchanged. The way to do that is to use the linear activation function (f(x)=x).
#
# One additional detail here. In class, we ignored the intercept. Here we will use the intercept---so we will classify using a plane w^T x +b =0 (instead of just planes through the origin, w^T x=0). The keras neuron automatically makes the intercept available.
#
# Conceptually, the intercept is not a big deal---we just pretend that the weights in the neuron are the coefficients of the input coordinates and the intercept b. So here, since the input has dimension 2, we have two coefficients and one intercept---bringing the number of tunable weights to be 3. We also pretend that every example is actually a vector with 3 coordinates, the first two coordinates are the ones given to us and the last coordinate is simply 1. Then w^T z +b = (w,b)^T(z,1), so we have reduced it to a case without an intercept (albeit by adding in an additional dummy coordinate).

# %%
# This piece of code defines the perceptron as above. 

perceptron = Sequential([
    Dense(1, input_shape=(2,)),
    Activation('linear'),
])

# %% [markdown]
# Ok, now on to the training algorithm. Recall that we use
# 1. stochastic gradient descent on the
# 2. the ramp loss function
#
# keras has a lot of useful loss functions built in, but the ramp loss is not one of them (though the hinge loss is). We will just write the function out here. Unfortunately, here there is a catch---we cannot use the extensive numpy libraries (though it is ok to pass numpy arrays here). Instead we have to use the tensorflow functions, which can sometimes be a little clumsy and eschews lot of automatic type conversions (because it is built for speed, not convenience always). That is why we explicity convert the label to a float below (else we could not multiply in the last line), and note that we write max (0.0, ...) not max (0, ...). This is to indicate that the comparison is a float comparison. If you do not do these things, TensorFlow will complain.
#
# loss functions we define *must* be tensorflow functions, and *always* take in two arguments (y_true and y_pred). y_true is the correct label of the example while y_pred is the output of the neuron (in our case, z\dot w, since we used linear activation).
#
# Finally perceptron training algorithm was vanilla stochastic gradient descent with learning parameter 1. We first pass the name of the algorithm (sgd for stochastic gradient descent, which is built into keras), the loss and what we are interested in achieving on test data (accuracy of classification---categorical accuracy in other words).

# %%
from keras.optimizers import SGD

# the ramp loss we used is not predefined, so we define it ourselves here. The code here is tensorflow
# code as is required. We cannot use numpy code/data types here.

def perceptron_loss(y_true,y_pred):
    tf.cast(y_true, tf.float32)
    return(tf.maximum(0.0,-(y_true)*y_pred))

# We want to do plain vanilla stochastic gradient descent here, nothing fancy. 
# The call below removes all bells and whistles from the keras implementation of stochastic gradient
# descent. We will learn how to add back the momentum and Nesterov acceleration later.

opt = SGD(lr=1,momentum=0,nesterov=False)

# Here we tell the perceptron to use plain vanilla stochastic gradient descent to optimize the perceptron loss defined
# above

perceptron.compile(optimizer=opt, loss=perceptron_loss)

# %% [markdown]
# We set the learning rate to 1 so as to mimic the Perceptron Training Algorithm exactly.

# %% [markdown]
# Now, we prepare the training data by extracting columns 1 and 2 from the data. We want to separate out setosa (original label 0) from the other two classes, so we assign label 1 to setosas (original label 0) and -1 to the other two classes (original labels 1 and 2).

# %%
# Get hold of the training data. We will classify setosas vs the other two. This yields a linear separable data
# that we know the perceptron can handle.

training = iris.data[:,[1,2]]
labels = np.where(iris.target == 0, 1,-1)

n = training.shape[0]

# We shuffle the order of the training examples and labels. Normally
# keras does this automatically. Here, we do it manually and we will
# ask keras not to shuffle. This is so that we can observe the perceptron
# algorithm as it progresses.

from sklearn.utils import shuffle

training, labels = shuffle(training, labels)

# %% [markdown]
# Now we just get keras to train our model, and get the output at the end of the training into w

# %%
from keras.callbacks import LambdaCallback
import keras.backend as K
    
# We initialize weights to something a little away from 0, since the perceptron has 0 loss when the weights are exactly 0
# regardless of input and output. This is because when weights are 0, w^Tz -b = 0^Tz -0 =0, so our prediction is 0. Therefore,
# y_true*y_predicted =0 always. This is not a fatal flaw, it just means we cannot start at 0.

perceptron.layers[0].set_weights([np.array([[0.01],[0.01]]),np.array([0.0])])

# The line below trains the perceptron.
# In the line below, increase the number of epochs till you see the loss become 0. You may need more than one/two epochs.

perceptron.fit(training, labels, epochs=2, batch_size=1, shuffle=False)

# These are weights obtained after training.

w = perceptron.layers[0].get_weights()
# Out:
# Epoch 1/2
# 150/150 [==============================] - 0s 1ms/step - loss: 0.2261
# Epoch 2/2
# 150/150 [==============================] - 0s 1ms/step - loss: 0.0000e+00

# %% [markdown]
# Let us plot the separating line. The line is w0 x + w1 y + b=0, or y = -(b+w0 x)/w1

# %%
fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 0, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(w[1][0]+w[0][0,0]*x)/w[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)

# %% [markdown]
# It worked as we expected it to! We want a little more transparency of course. Let us also retrieve the input and weights at the beginning of every example.

# %%
from keras.callbacks import LambdaCallback
import keras.backend as K
    
print_weights = LambdaCallback(on_batch_begin=lambda batch, logs: print('\n w',batch,': \n',perceptron.layers[0].get_weights(),'\n'))
print_examples = LambdaCallback(on_batch_end = lambda batch, logs: print('\n z: ',training[batch,:],'y: ', labels[batch]))

# Again we initialize weights
perceptron.layers[0].set_weights([np.array([[0.01],[0.01]]),np.array([0.0])])
# And start stochastic gradient descent. This time, we print out the weights and examples corresponding to each step of the
# SGD.
perceptron.fit(training, labels, epochs=1, batch_size=1, callbacks = [ print_weights, print_examples ],shuffle=False)
# Out:
# Epoch 1/1
#
#  w 0 :
#  [array([[0.01],
#        [0.01]], dtype=float32), array([0.], dtype=float32)]
#
#   1/150 [..............................] - ETA: 0s - loss: 0.0860
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-3.09],
#        [-5.49]], dtype=float32), array([-1.], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.31000018],
#        [-3.8899999 ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 4.11     ],
#        [-2.1899998]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 4.11     ],
#        [-2.1899998]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[ 4.11     ],
#        [-2.1899998]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[ 4.11     ],
#        [-2.1899998]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[ 0.9100001],
#        [-8.19     ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  11/150 [=>............................] - ETA: 0s - loss: 3.0837
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
#
#  w 15 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.4] y:  1
#
#  w 16 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.4] y:  1
#
#  w 17 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.5] y:  -1
#
#  w 18 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [4.2 1.4] y:  1
#
#  w 19 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.4] y:  1
#
#  w 20 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 6.7] y:  -1
#
#  w 21 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  22/150 [===>..........................] - ETA: 0s - loss: 1.5419
#  z:  [2.9 4.2] y:  -1
#
#  w 22 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.3 4.4] y:  -1
#
#  w 23 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  24/150 [===>..........................] - ETA: 1s - loss: 1.4134
#  z:  [2.7 5.1] y:  -1
#
#  w 24 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 5. ] y:  -1
#
#  w 25 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.6 5.6] y:  -1
#
#  w 26 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 5.7] y:  -1
#
#  w 27 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  6.1] y:  -1
#
#  w 28 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.2 5. ] y:  -1
#
#  w 29 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 30 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 31 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.9] y:  -1
#
#  w 32 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 1.5] y:  1
#
#  w 33 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 6.3] y:  -1
#
#  w 34 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.  3.5] y:  -1
#
#  w 35 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  36/150 [======>.......................] - ETA: 0s - loss: 0.9422
#  z:  [3.  5.9] y:  -1
#
#  w 36 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.5] y:  1
#
#  w 37 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 5.1] y:  -1
#
#  w 38 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.4 3.3] y:  -1
#
#  w 39 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 6. ] y:  -1
#
#  w 40 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
#
#  w 41 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.6 1.4] y:  1
#
#  w 42 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 4.9] y:  -1
#
#  w 43 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.1] y:  -1
#
#  w 44 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 5.7] y:  -1
#
#  w 45 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.7] y:  -1
#
#  w 46 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  47/150 [========>.....................] - ETA: 0s - loss: 0.7217
#  z:  [2.8 5.6] y:  -1
#
#  w 47 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 48 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 49 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 3.6] y:  -1
#
#  w 50 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 5.6] y:  -1
#
#  w 51 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.2] y:  1
#
#  w 52 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.3] y:  1
#
#  w 53 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 54 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 55 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 5.9] y:  -1
#
#  w 56 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 57 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.6] y:  1
#
#  w 58 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  59/150 [==========>...................] - ETA: 0s - loss: 0.5749
#  z:  [3.8 1.9] y:  1
#
#  w 59 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 60 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 3. ] y:  -1
#
#  w 61 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 5.4] y:  -1
#
#  w 62 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 3.9] y:  -1
#
#  w 63 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 4.5] y:  -1
#
#  w 64 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
#
#  w 65 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 4.9] y:  -1
#
#  w 66 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.9 1.7] y:  1
#
#  w 67 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 4.4] y:  -1
#
#  w 68 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.8] y:  -1
#  w 69 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 4. ] y:  -1
#
#  w 70 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  71/150 [=============>................] - ETA: 0s - loss: 0.4778
#  z:  [3. 5.] y:  -1
#
#  w 71 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 72 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.6 1. ] y:  1
#
#  w 73 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 6.4] y:  -1
#
#  w 74 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.6] y:  -1
#
#  w 75 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.6] y:  1
#
#  w 76 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 5.8] y:  -1
#
#  w 77 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.8] y:  -1
#
#  w 78 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 79 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.6] y:  -1
#
#  w 80 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.6 3.5] y:  -1
#
#  w 81 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  82/150 [===============>..............] - ETA: 0s - loss: 0.4137
#  z:  [3.4 5.4] y:  -1
#
#  w 82 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.3] y:  -1
#
#  w 83 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 4.1] y:  -1
#
#  w 84 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 85 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 5.6] y:  -1
#
#  w 86 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.3] y:  -1
#
#  w 87 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.3] y:  1
#
#  w 88 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 5.3] y:  -1
#
#  w 89 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
#
#  w 90 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.4 3.7] y:  -1
#
#  w 91 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.4] y:  1
#
#  w 92 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#  93/150 [=================>............] - ETA: 0s - loss: 0.3647
#  z:  [2.9 1.4] y:  1
#
#  w 93 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4. ] y:  -1
#
#  w 94 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 95 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 5.6] y:  -1
#
#  w 96 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [4.4 1.5] y:  1
#
#  w 97 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [4.1 1.5] y:  1
#
#  w 98 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 5. ] y:  -1
#
#  w 99 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.6 1.4] y:  1
#
#  w 100 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.6 6.1] y:  -1
#
#  w 101 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.6] y:  1
#
#  w 102 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.4] y:  -1
#
#  w 103 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
# 104/150 [===================>..........] - ETA: 0s - loss: 0.3262
#  z:  [2.7 5.1] y:  -1
#
#  w 104 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.4 3.8] y:  -1
#
#  w 105 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.3 1.3] y:  1
#
#  w 106 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 107 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 108 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.2] y:  -1
#
#  w 109 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.6 6.9] y:  -1
#
#  w 110 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.3] y:  1
#
#  w 111 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.5] y:  -1
#
#  w 112 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 113 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 5.7] y:  -1
#
#  w 114 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.2] y:  -1
#
#  w 115 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
# 116/150 [======================>.......] - ETA: 0s - loss: 0.2924
#  z:  [2.3 3.3] y:  -1
#
#  w 116 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 4.9] y:  -1
#
#  w 117 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 6.1] y:  -1
#
#  w 118 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 4.5] y:  -1
#
#  w 119 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.5] y:  -1
#
#  w 120 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.5] y:  -1
#
#  w 121 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 4.5] y:  -1
#
#  w 122 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 1.7] y:  1
#
#  w 123 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 1.4] y:  1
#
#  w 124 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 125 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 1.6] y:  1
#
#  w 126 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
# 127/150 [========================>.....] - ETA: 0s - loss: 0.2671
#  z:  [3.4 1.7] y:  1
#
#  w 127 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 128 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 129 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 130 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.6] y:  -1
#
#  w 131 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.2 4. ] y:  -1
#
#  w 132 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 6.7] y:  -1
#
#  w 133 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.3 4. ] y:  -1
#
#  w 134 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#  w 135 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.1] y:  -1
#
#  w 136 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 137 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 138 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.1] y:  1
#
#  w 139 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
# 140/150 [===========================>..] - ETA: 0s - loss: 0.2423
#  z:  [3.2 5.1] y:  -1
#
#  w 140 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.2 4.5] y:  -1
#
#  w 141 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.5] y:  -1
#
#  w 142 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 4.7] y:  -1
#
#  w 143 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 144 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 5.1] y:  -1
#
#  w 145 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 5.1] y:  -1
#
#  w 146 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.5] y:  -1
#
#  w 147 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 148 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
# 149/150 [============================>.] - ETA: 0s - loss: 0.2277
#  z:  [3.5 1.4] y:  1
#
#  w 149 :
#  [array([[ 4.8100004],
#        [-6.8899994]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
# 150/150 [==============================] - 1s 5ms/step - loss: 0.2261

# %% [markdown]
# Note above that whenever there is a mistake made, the weights are updated as:
#
# w_{i+1} = w_i +y_i z_i.
#
# Note again that here there are effectively three weights: the two coefficients of the coordinates of the example and the intercept, because we are looking for separating boundaries that are lines not necessarily through the origin. Correspondingly, each example is interpreted as a vector of length 3, the first two coefficients being the actual example and the third coordinate equal to 1 always.
#
# This is exactly the perceptron training algorithm we studied in class. We have simulated it exactly using keras and gradient descent.
#
# Your assignment is as follows:
#
# ### Problem 1.
# a. Using keras and gradient descent, simulate a 1-neuron network that mimics LinearRegression. Use a learning rate of .01 here.

# %%
# Create model
# 1 Neuron network
iris_lr = Sequential([
    Dense(1, input_shape=(2,)), 
    Activation('linear'), 
])

#Lr of 0.1
opt = SGD(lr=0.01,momentum=0,nesterov=False)

iris_lr.compile(optimizer=opt, loss=keras.losses.MSE)

# %% [markdown]
# b. Test your simulation on the Iris dataset above. This time do both cases: (a) classes that are *NOT* linearly separable (for eg. label 1 in the IRIS dataset from the other two) and (b) classes that are linearly separable as above. Make sure if the gradients are what you expect by checking the weights before and after an example using callbacks as above. Later on, we will learn how to extract/manipulate gradient information. Choose the batch size wisely.

# %%
print_weights = LambdaCallback(on_batch_begin=lambda batch, logs: print('\n w',batch,': \n',iris_lr.layers[0].get_weights(),'\n'))
print_examples = LambdaCallback(on_batch_end = lambda batch, logs: print('\n z: ',training[batch,:],'y: ', labels[batch]))
# 

# Again we initialize weights
iris_lr.layers[0].set_weights([np.array([[0.01],[0.01]]),np.array([0.0])])

# %%
##############
# (a) not linearly seperable
#############
color_train = iris.data[:,[1,2]]
color_target = np.where(iris.target == 2, 1,-1)

color_train, color_target = shuffle(training, color_target)

iris_lr.fit(color_train, color_target, epochs=40, batch_size=10,callbacks = [ print_weights, print_examples ], shuffle=False)

lr = iris_lr.layers[0].get_weights()

fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 2, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(lr[1][0]+lr[0][0,0]*x)/lr[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)
# Out:
# Epoch 1/40
#
#  w 0 :
#  [array([[0.01],
#        [0.01]], dtype=float32), array([0.], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0461
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.0051578],
#        [-0.0261016]], dtype=float32), array([-0.005394], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[0.01449596],
#        [0.00965991]], dtype=float32), array([0.00089107], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.02792795],
#        [-0.02606464]], dtype=float32), array([-0.01278382], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.0435157 ],
#        [-0.04970293]], dtype=float32), array([-0.01647983], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.02230481],
#        [-0.01262909]], dtype=float32), array([-0.00896786], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.03648842],
#        [-0.04132282]], dtype=float32), array([-0.01463621], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.04315524],
#        [-0.04900446]], dtype=float32), array([-0.0170671], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.02010462],
#        [-0.02092049]], dtype=float32), array([-0.01022428], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.0312535 ],
#        [-0.06062577]], dtype=float32), array([-0.01514775], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.07385646],
#        [-0.10441895]], dtype=float32), array([-0.02885178], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.04382895],
#        [-0.05959306]], dtype=float32), array([-0.01833565], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.9628
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.05506527],
#        [-0.07717133]], dtype=float32), array([-0.02241012], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.04526747],
#        [-0.04284057]], dtype=float32), array([-0.01728455], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.03972255],
#        [-0.03009536]], dtype=float32), array([-0.01500346], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 859us/step - loss: 0.9526
# Epoch 2/40
#
#  w 0 :
#  [array([[-0.07676406],
#        [-0.06793489]], dtype=float32), array([-0.02592493], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9904
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.0563833],
#        [-0.0523336]], dtype=float32), array([-0.01940832], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.02017825],
#        [ 0.00353768]], dtype=float32), array([-0.00780951], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.05317431],
#        [-0.02123216]], dtype=float32), array([-0.01862391], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.0645482 ],
#        [-0.03971782]], dtype=float32), array([-0.02103088], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.04183745],
#        [-0.00142431]], dtype=float32), array([-0.01307836], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.05469089],
#        [-0.0294992 ]], dtype=float32), array([-0.01832485], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.06034819],
#        [-0.03672475]], dtype=float32), array([-0.0204502], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.03672572],
#        [-0.00849921]], dtype=float32), array([-0.01344926], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.04756572],
#        [-0.04851931]], dtype=float32), array([-0.01831713], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.08921127],
#        [-0.09215625]], dtype=float32), array([-0.03176975], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9944
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.05766207],
#        [-0.04695103]], dtype=float32), array([-0.02083427], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.06897939],
#        [-0.06588299]], dtype=float32), array([-0.0250143], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.05896519],
#        [-0.03220276]], dtype=float32), array([-0.01983614], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.05288667],
#        [-0.01963375]], dtype=float32), array([-0.01741671], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 509us/step - loss: 0.9544
# Epoch 3/40
#
#  w 0 :
#  [array([[-0.08967218],
#        [-0.05840814]], dtype=float32), array([-0.02830028], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0036
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.06908424],
#        [-0.04312881]], dtype=float32), array([-0.02172259], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.03228958],
#        [ 0.0129232 ]], dtype=float32), array([-0.00994796], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.06474263],
#        [-0.01222879]], dtype=float32), array([-0.02064783], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.07607513],
#        [-0.03154627]], dtype=float32), array([-0.0230719], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.05328634],
#        [ 0.00608123]], dtype=float32), array([-0.01513479], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.06555933],
#        [-0.02193961]], dtype=float32), array([-0.02020616], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.07074462],
#        [-0.02908009]], dtype=float32), array([-0.02219249], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.04684686],
#        [-0.00086764]], dtype=float32), array([-0.01511923], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.05753188],
#        [-0.04112713]], dtype=float32), array([-0.01996456], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.09860938],
#        [-0.08468685]], dtype=float32), array([-0.03326906], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.06614162],
#        [-0.03925772]], dtype=float32), array([-0.02208085], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.07751305],
#        [-0.05902096]], dtype=float32), array([-0.02632674], dtype=float32)]
#
# 130/150 [=========================>....] - ETA: 0s - loss: 0.9766
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.0673701 ],
#        [-0.02574007]], dtype=float32), array([-0.02111766], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.06096751],
#        [-0.01327894]], dtype=float32), array([-0.01861436], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 464us/step - loss: 0.9537
# Epoch 4/40
#
#  w 0 :
#  [array([[-0.09759788],
#        [-0.05262282]], dtype=float32), array([-0.0294751], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0120
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.07688453],
#        [-0.03753975]], dtype=float32), array([-0.02286047], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.03973123],
#        [ 0.01862234]], dtype=float32), array([-0.01097897], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.07185299],
#        [-0.00676141]], dtype=float32), array([-0.02160904], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.08315982],
#        [-0.02658424]], dtype=float32), array([-0.02404345], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.06032407],
#        [ 0.01063686]], dtype=float32), array([-0.01611593], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.07224535],
#        [-0.01735279]], dtype=float32), array([-0.02108127], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.07714326],
#        [-0.02444099]], dtype=float32), array([-0.02298302], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.05307777],
#        [ 0.00376375]], dtype=float32), array([-0.0158657], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.06366867],
#        [-0.03664194]], dtype=float32), array([-0.02069742], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.10440063],
#        [-0.08015514]], dtype=float32), array([-0.03391188], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.07137403],
#        [-0.03459011]], dtype=float32), array([-0.02256997], dtype=float32)]
# 120/150 [=======================>......] - ETA: 0s - loss: 0.9702
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.08277738],
#        [-0.05485834]], dtype=float32), array([-0.02685568], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.07255686],
#        [-0.02182085]], dtype=float32), array([-0.02162812], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.06595642],
#        [-0.00942442]], dtype=float32), array([-0.01907366], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 492us/step - loss: 0.9536
# Epoch 5/40
#
#  w 0 :
#  [array([[-0.10249241],
#        [-0.04911453]], dtype=float32), array([-0.02992055], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0172
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.08170313],
#        [-0.03415086]], dtype=float32), array([-0.02328358], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.04433162],
#        [ 0.02207847]], dtype=float32), array([-0.01133711], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.07625084],
#        [-0.00344547]], dtype=float32), array([-0.02192458], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.08754154],
#        [-0.02357495]], dtype=float32), array([-0.02436521], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.06467773],
#        [ 0.01339773]], dtype=float32), array([-0.01644373], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.07638647],
#        [-0.01457463]], dtype=float32), array([-0.02134509], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08110932],
#        [-0.02163051]], dtype=float32), array([-0.02319537], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.05694155],
#        [ 0.00656983]], dtype=float32), array([-0.01605119], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.06747536],
#        [-0.03392538]], dtype=float32), array([-0.02087474], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.10799716],
#        [-0.07741075]], dtype=float32), array([-0.03403447], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.07463058],
#        [-0.03176338]], dtype=float32), array([-0.02259914], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.08605236],
#        [-0.05233808]], dtype=float32), array([-0.02690881], dtype=float32)]
#
# 130/150 [=========================>....] - ETA: 0s - loss: 0.9770
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.07578539],
#        [-0.0194491 ]], dtype=float32), array([-0.02167033], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.0690639 ],
#        [-0.00709108]], dtype=float32), array([-0.01908465], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 484us/step - loss: 0.9536
# Epoch 6/40
#
#  w 0 :
#  [array([[-0.10554249],
#        [-0.0469916 ]], dtype=float32), array([-0.02992314], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0204
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.08470738],
#        [-0.03210058]], dtype=float32), array([-0.0232727], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.04720307],
#        [ 0.02416992]], dtype=float32), array([-0.01128677], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.07899809],
#        [-0.00143846]], dtype=float32), array([-0.02184818], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09027847],
#        [-0.02175373]], dtype=float32), array([-0.02429252], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.06739807],
#        [ 0.01506666]], dtype=float32), array([-0.01637492], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.07897893],
#        [-0.01289687]], dtype=float32), array([-0.02123787], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08359508],
#        [-0.01993257]], dtype=float32), array([-0.02305683], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.05936484],
#        [ 0.00826534]], dtype=float32), array([-0.01589626], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.06986407],
#        [-0.03228489]], dtype=float32), array([-0.02071494], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11025807],
#        [-0.07575379]], dtype=float32), array([-0.03384144], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.0766847 ],
#        [-0.03005667]], dtype=float32), array([-0.02234936], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.9713
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.08811669],
#        [-0.05081704]], dtype=float32), array([-0.02667333], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.07782222],
#        [-0.01801883]], dtype=float32), array([-0.02142855], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.0710264 ],
#        [-0.00568323]], dtype=float32), array([-0.01882374], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 520us/step - loss: 0.9536
# Epoch 7/40
#
#  w 0 :
#  [array([[-0.10747007],
#        [-0.04571154]], dtype=float32), array([-0.02965716], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0223
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.08660745],
#        [-0.0308647 ]], dtype=float32), array([-0.02299867], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.04902232],
#        [ 0.02543112]], dtype=float32), array([-0.01098879], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08074081],
#        [-0.00022784]], dtype=float32), array([-0.0215342], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.0920144 ],
#        [-0.02065533]], dtype=float32), array([-0.02398074], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.06912443],
#        [ 0.01607126]], dtype=float32), array([-0.01606569], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08062892],
#        [-0.01188858]], dtype=float32), array([-0.02090581], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08517996],
#        [-0.01891149]], dtype=float32), array([-0.0227057], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06091147],
#        [ 0.00928522]], dtype=float32), array([-0.01553509], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07138985],
#        [-0.03129904]], dtype=float32), array([-0.02035092], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11170617],
#        [-0.07475838]], dtype=float32), array([-0.03345727], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9969
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.07800701],
#        [-0.02903131]], dtype=float32), array([-0.02193074], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.08944423],
#        [-0.04990389]], dtype=float32), array([-0.02626316], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.07913377],
#        [-0.01716134]], dtype=float32), array([-0.02101486], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07229207],
#        [-0.00483844]], dtype=float32), array([-0.01839831], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 542us/step - loss: 0.9537
# Epoch 8/40
#
#  w 0 :
#  [array([[-0.1087145 ],
#        [-0.04494423]], dtype=float32), array([-0.02922867], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0235
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.0878355 ],
#        [-0.03012426]], dtype=float32), array([-0.02256541], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.0502012 ],
#        [ 0.02618723]], dtype=float32), array([-0.01054102], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08187217],
#        [ 0.00049832]], dtype=float32), array([-0.02107656], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09314112],
#        [-0.01999666]], dtype=float32), array([-0.02352436], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.0702458 ],
#        [ 0.01667171]], dtype=float32), array([-0.01561108], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08170525],
#        [-0.01128756]], dtype=float32), array([-0.02043782], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#  w 7 :
#  [array([[-0.08621648],
#        [-0.01830218]], dtype=float32), array([-0.0222261], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06192449],
#        [ 0.00989407]], dtype=float32), array([-0.01504934], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07239033],
#        [-0.03071146]], dtype=float32), array([-0.01986354], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11265947],
#        [-0.07416543]], dtype=float32), array([-0.0329577], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.07888381],
#        [-0.02842049]], dtype=float32), array([-0.02141029], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09032322],
#        [-0.04936057]], dtype=float32), array([-0.02574759], dtype=float32)]
#
# 130/150 [=========================>....] - ETA: 0s - loss: 0.9774
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08000379],
#        [-0.01665229]], dtype=float32), array([-0.02049748], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.0731335 ],
#        [-0.00433618]], dtype=float32), array([-0.01787367], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 515us/step - loss: 0.9537
# Epoch 9/40
#
#  w 0 :
#  [array([[-0.10954303],
#        [-0.04448889]], dtype=float32), array([-0.0287022], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0242
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.08865443],
#        [-0.02968526]], dtype=float32), array([-0.02203617], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05099018],
#        [ 0.02663602]], dtype=float32), array([-0.01000301], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08263126],
#        [ 0.00092972]], dtype=float32), array([-0.02053241], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09389689],
#        [-0.01960553]], dtype=float32), array([-0.02298091], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07099882],
#        [ 0.01702628]], dtype=float32), array([-0.01506891], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08243228],
#        [-0.01093431]], dtype=float32), array([-0.01988802], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.0869191 ],
#        [-0.01794337]], dtype=float32), array([-0.02166924], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06261257],
#        [ 0.01025285]], dtype=float32), array([-0.01448867], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07307097],
#        [-0.03036618]], dtype=float32), array([-0.01930199], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11331147],
#        [-0.07381736]], dtype=float32), array([-0.03238879], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9972
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.07948931],
#        [-0.02806187]], dtype=float32), array([-0.02082877], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09092906],
#        [-0.04904223]], dtype=float32), array([-0.02516877], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.0806049 ],
#        [-0.01635522]], dtype=float32), array([-0.01991788], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07371656],
#        [-0.00404231]], dtype=float32), array([-0.01728954], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 552us/step - loss: 0.9537
# Epoch 10/40
#
#  w 0 :
#  [array([[-0.11011824],
#        [-0.04422331]], dtype=float32), array([-0.028117], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0246
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.08922417],
#        [-0.02942961]], dtype=float32), array([-0.02144941], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05154169],
#        [ 0.0268979 ]], dtype=float32), array([-0.00941098], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08316364],
#        [ 0.00118182]], dtype=float32), array([-0.0199365], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09442675],
#        [-0.01937713]], dtype=float32), array([-0.02238536], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07152751],
#        [ 0.01723129]], dtype=float32), array([-0.01447434], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08294659],
#        [-0.01073175]], dtype=float32), array([-0.01928933], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08741836],
#        [-0.01773693]], dtype=float32), array([-0.02106624], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06310275],
#        [ 0.01045955]], dtype=float32), array([-0.01388331], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0138
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07355678],
#        [-0.03016824]], dtype=float32), array([-0.01869619], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11377993],
#        [-0.07361817]], dtype=float32), array([-0.03177858], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.07992952],
#        [-0.0278566 ]], dtype=float32), array([-0.02021097], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09136851],
#        [-0.04886071]], dtype=float32), array([-0.02455235], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08104222],
#        [-0.01618705]], dtype=float32), array([-0.01930132], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07414223],
#        [-0.00387516]], dtype=float32), array([-0.01667011], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 628us/step - loss: 0.9537
# Epoch 11/40
#
#  w 0 :
#  [array([[-0.11053915],
#        [-0.04407313]], dtype=float32), array([-0.02749694], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0248
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.08964211],
#        [-0.02928547]], dtype=float32), array([-0.02082854], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05194851],
#        [ 0.02704607]], dtype=float32), array([-0.00878696], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08355786],
#        [ 0.00132487]], dtype=float32), array([-0.01930999], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09481892],
#        [-0.01924772]], dtype=float32), array([-0.02175899], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07191946],
#        [ 0.01734534]], dtype=float32), array([-0.01384877], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.0833312 ],
#        [-0.01062086]], dtype=float32), array([-0.01866177], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08779361],
#        [-0.01762316]], dtype=float32), array([-0.02043605], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06347226],
#        [ 0.01057374]], dtype=float32), array([-0.01325162], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.0739238 ],
#        [-0.03005993]], dtype=float32), array([-0.01806435], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9553
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11413647],
#        [-0.07350955]], dtype=float32), array([-0.03114412], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.0802689 ],
#        [-0.02774461]], dtype=float32), array([-0.01957197], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09170645],
#        [-0.04876241]], dtype=float32), array([-0.02391394], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08137961],
#        [-0.01609729]], dtype=float32), array([-0.01866314], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07447187],
#        [-0.00378508]], dtype=float32), array([-0.01603007], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 573us/step - loss: 0.9537
# Epoch 12/40
#
#  w 0 :
#  [array([[-0.11086591],
#        [-0.04399315]], dtype=float32), array([-0.02685656], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0250
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.08996743],
#        [-0.02920914]], dtype=float32), array([-0.02018779], dtype=float32)]
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05226705],
#        [ 0.02712514]], dtype=float32), array([-0.00814436], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08386779],
#        [ 0.00140161]], dtype=float32), array([-0.01866573], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09512711],
#        [-0.01917848]], dtype=float32), array([-0.02111476], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.072228  ],
#        [ 0.01740411]], dtype=float32), array([-0.01320523], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08363669],
#        [-0.01056566]], dtype=float32), array([-0.01801752], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08809322],
#        [-0.01756572]], dtype=float32), array([-0.0197902], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06376813],
#        [ 0.0106317 ]], dtype=float32), array([-0.01260481], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07421832],
#        [-0.0300061 ]], dtype=float32), array([-0.01741755], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11442469],
#        [-0.07345599]], dtype=float32), array([-0.03049579], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9973
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08054672],
#        [-0.02768933]], dtype=float32), array([-0.01892097], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09198242],
#        [-0.0487147 ]], dtype=float32), array([-0.02326303], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08165597],
#        [-0.01605519]], dtype=float32), array([-0.0180127], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07474285],
#        [-0.00374187]], dtype=float32), array([-0.01537838], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 595us/step - loss: 0.9537
# Epoch 13/40
#
#  w 0 :
#  [array([[-0.11113515],
#        [-0.04395583]], dtype=float32), array([-0.02620469], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0251
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09023616],
#        [-0.02917403]], dtype=float32), array([-0.01953583], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05253164],
#        [ 0.02716216]], dtype=float32), array([-0.00749132], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08412617],
#        [ 0.00143804]], dtype=float32), array([-0.01801156], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09538394],
#        [-0.01914584]], dtype=float32), array([-0.02046053], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07248554],
#        [ 0.01742926]], dtype=float32), array([-0.01255162], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08389378],
#        [-0.01054434]], dtype=float32), array([-0.017364], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08834654],
#        [-0.01754251]], dtype=float32), array([-0.0191357], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06401895],
#        [ 0.01065547]], dtype=float32), array([-0.01194967], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07446849],
#        [-0.02998538]], dtype=float32), array([-0.01676252], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9554
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11467109],
#        [-0.07343589]], dtype=float32), array([-0.02983988], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08078684],
#        [-0.02766851]], dtype=float32), array([-0.01826352], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09222043],
#        [-0.04869773]], dtype=float32), array([-0.02260538], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08189496],
#        [-0.01604203]], dtype=float32), array([-0.01735565], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07497792],
#        [-0.00372711]], dtype=float32), array([-0.01472047], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 555us/step - loss: 0.9537
# Epoch 14/40
#
#  w 0 :
#  [array([[-0.11136916],
#        [-0.04394442]], dtype=float32), array([-0.0255467], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0251
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09047022],
#        [-0.02916396]], dtype=float32), array([-0.01887791], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05276316],
#        [ 0.02717366]], dtype=float32), array([-0.00683282], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08435299],
#        [ 0.00144997]], dtype=float32), array([-0.01735223], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09560932],
#        [-0.01913543]], dtype=float32), array([-0.01980109], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07271184],
#        [ 0.01743399]], dtype=float32), array([-0.01189276], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.0841212 ],
#        [-0.01054357]], dtype=float32), array([-0.0167057], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08857147],
#        [-0.01754011]], dtype=float32), array([-0.0184768], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06424213],
#        [ 0.01065849]], dtype=float32), array([-0.01129032], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07469143],
#        [-0.02998477]], dtype=float32), array([-0.01610334], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9554
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11489181],
#        [-0.0734361 ]], dtype=float32), array([-0.02918024], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08100377],
#        [-0.02766863]], dtype=float32), array([-0.01760303], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09243512],
#        [-0.04869942]], dtype=float32), array([-0.02194451], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08211098],
#        [-0.01604646]], dtype=float32), array([-0.01669547], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07519089],
#        [-0.00372965]], dtype=float32), array([-0.01405965], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 571us/step - loss: 0.9537
# Epoch 15/40
#
#  w 0 :
#  [array([[-0.1115815 ],
#        [-0.04394875]], dtype=float32), array([-0.02488586], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0251
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09068295],
#        [-0.02916909]], dtype=float32), array([-0.01821725], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05297433],
#        [ 0.02716963]], dtype=float32), array([-0.00617186], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08456035],
#        [ 0.00144702]], dtype=float32), array([-0.01669062], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.0958153 ],
#        [-0.01913852]], dtype=float32), array([-0.01913936], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07291885],
#        [ 0.01742632]], dtype=float32), array([-0.01123157], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.0843303 ],
#        [-0.01055529]], dtype=float32), array([-0.01604537], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08877887],
#        [-0.01755033]], dtype=float32), array([-0.01781609], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06444824],
#        [ 0.0106489 ]], dtype=float32), array([-0.01062929], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0140
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07489756],
#        [-0.02999636]], dtype=float32), array([-0.01544252], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11509667],
#        [-0.07344865]], dtype=float32), array([-0.0285192], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08120637],
#        [-0.02768144]], dtype=float32), array([-0.01694155], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09263539],
#        [-0.04871244]], dtype=float32), array([-0.02128254], dtype=float32)]
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08231278],
#        [-0.01606155]], dtype=float32), array([-0.01603423], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07539019],
#        [-0.00374267]], dtype=float32), array([-0.01339791], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 618us/step - loss: 0.9537
# Epoch 16/40
#
#  w 0 :
#  [array([[-0.11178043],
#        [-0.04396262]], dtype=float32), array([-0.02422415], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0251
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09088247],
#        [-0.02918344]], dtype=float32), array([-0.01755577], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05317288],
#        [ 0.02715622]], dtype=float32), array([-0.00551026], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08475565],
#        [ 0.00143506]], dtype=float32), array([-0.0160285], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09600928],
#        [-0.01914979]], dtype=float32), array([-0.01847709], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07311396],
#        [ 0.01741116]], dtype=float32), array([-0.01056984], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08452806],
#        [-0.01057454]], dtype=float32), array([-0.01538466], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.0889754 ],
#        [-0.01756817]], dtype=float32), array([-0.01715514], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06464376],
#        [ 0.0106317 ]], dtype=float32), array([-0.00996809], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07509325],
#        [-0.03001533]], dtype=float32), array([-0.01478155], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9554
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11529166],
#        [-0.07346865]], dtype=float32), array([-0.02785817], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08140001],
#        [-0.02770192]], dtype=float32), array([-0.01628033], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09282665],
#        [-0.0487323 ]], dtype=float32), array([-0.02062077], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.0825057 ],
#        [-0.01608306]], dtype=float32), array([-0.01537323], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07558094],
#        [-0.00376201]], dtype=float32), array([-0.01273649], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 613us/step - loss: 0.9537
# Epoch 17/40
#
#  w 0 :
#  [array([[-0.11197097],
#        [-0.04398225]], dtype=float32), array([-0.02356277], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0251
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09107372],
#        [-0.02920334]], dtype=float32), array([-0.01689467], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05336353],
#        [ 0.02713714]], dtype=float32), array([-0.00484914], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08494338],
#        [ 0.00141767]], dtype=float32), array([-0.01536693], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09619571],
#        [-0.01916599]], dtype=float32), array([-0.01781536], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07330155],
#        [ 0.01739147]], dtype=float32), array([-0.00990863], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08471866],
#        [-0.01059834]], dtype=float32), array([-0.01472458], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08916506],
#        [-0.01759062]], dtype=float32), array([-0.01649491], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06483257],
#        [ 0.01060991]], dtype=float32), array([-0.00930766], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07528234],
#        [-0.03003874]], dtype=float32), array([-0.01412137], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9554
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11548039],
#        [-0.07349312]], dtype=float32), array([-0.027198], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08158796],
#        [-0.02772702]], dtype=float32), array([-0.01562013], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.0930122 ],
#        [-0.04875626]], dtype=float32), array([-0.01995998], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08269299],
#        [-0.01610845]], dtype=float32), array([-0.01471323], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07576627],
#        [-0.00378517]], dtype=float32), array([-0.01207613], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 648us/step - loss: 0.9537
# Epoch 18/40
#
#  w 0 :
#  [array([[-0.11215618],
#        [-0.04400535]], dtype=float32), array([-0.02290247], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0251
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09125972],
#        [-0.0292266 ]], dtype=float32), array([-0.01623466], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05354914],
#        [ 0.02711464]], dtype=float32), array([-0.00418918], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08512628],
#        [ 0.00139698]], dtype=float32), array([-0.01470656], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09637733],
#        [-0.01918519]], dtype=float32), array([-0.01715482], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07348436],
#        [ 0.01736905]], dtype=float32), array([-0.00924861], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08490468],
#        [-0.01062488]], dtype=float32), array([-0.01406575], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08935032],
#        [-0.01761584]], dtype=float32), array([-0.01583599], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06501709],
#        [ 0.01058534]], dtype=float32), array([-0.00864855], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0140
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07546718],
#        [-0.03006483]], dtype=float32), array([-0.01346251], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11566509],
#        [-0.07352032]], dtype=float32), array([-0.02653921], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08177222],
#        [-0.02775491]], dtype=float32), array([-0.01496141], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09319404],
#        [-0.04878272]], dtype=float32), array([-0.01930064], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08287661],
#        [-0.01613617]], dtype=float32), array([-0.01405469], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07594804],
#        [-0.00381062]], dtype=float32), array([-0.01141726], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 698us/step - loss: 0.9537
# Epoch 19/40
#
#  w 0 :
#  [array([[-0.11233789],
#        [-0.04403052]], dtype=float32), array([-0.02224366], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0250
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09144227],
#        [-0.02925187]], dtype=float32), array([-0.01557616], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05373144],
#        [ 0.02709009]], dtype=float32), array([-0.00353077], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.085306  ],
#        [ 0.00137433]], dtype=float32), array([-0.01404777], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09655578],
#        [-0.01920615]], dtype=float32), array([-0.01649587], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07366402],
#        [ 0.01734502]], dtype=float32), array([-0.00859017], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08508767],
#        [-0.01065303]], dtype=float32), array([-0.01340852], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08953267],
#        [-0.0176427 ]], dtype=float32), array([-0.0151787], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06519876],
#        [ 0.01055914]], dtype=float32), array([-0.0079911], dtype=float32)]
#  90/150 [=================>............] - ETA: 0s - loss: 1.0140
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07564922],
#        [-0.03009249]], dtype=float32), array([-0.01280532], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11584711],
#        [-0.07354908]], dtype=float32), array([-0.02588214], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08195402],
#        [-0.02778443]], dtype=float32), array([-0.01430445], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09337341],
#        [-0.04881062]], dtype=float32), array([-0.01864306], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08305778],
#        [-0.01616525]], dtype=float32), array([-0.0133979], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07612745],
#        [-0.00383742]], dtype=float32), array([-0.01076016], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 780us/step - loss: 0.9537
# Epoch 20/40
#
#  w 0 :
#  [array([[-0.11251727],
#        [-0.04405691]], dtype=float32), array([-0.02158664], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0250
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09162251],
#        [-0.0292783 ]], dtype=float32), array([-0.01491945], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.0539115 ],
#        [ 0.02706434]], dtype=float32), array([-0.00287417], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08548358],
#        [ 0.00135052]], dtype=float32), array([-0.01339081], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.0967321 ],
#        [-0.01922817]], dtype=float32), array([-0.01583873], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07384155],
#        [ 0.01732003]], dtype=float32), array([-0.00793354], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08526859],
#        [-0.01068213]], dtype=float32), array([-0.01275314], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.08971301],
#        [-0.01767052]], dtype=float32), array([-0.01452327], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06537846],
#        [ 0.01053196]], dtype=float32), array([-0.00733552], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.0758293 ],
#        [-0.03012109]], dtype=float32), array([-0.01215], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9554
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11602725],
#        [-0.07357879]], dtype=float32), array([-0.02522694], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08213406],
#        [-0.02781492]], dtype=float32), array([-0.01364941], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09355103],
#        [-0.04883939]], dtype=float32), array([-0.01798739], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08323722],
#        [-0.01619512]], dtype=float32), array([-0.01274303], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07630517],
#        [-0.003865  ]], dtype=float32), array([-0.01010499], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 667us/step - loss: 0.9537
# Epoch 21/40
#
#  w 0 :
#  [array([[-0.11269498],
#        [-0.04408402]], dtype=float32), array([-0.02093154], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0250
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09180109],
#        [-0.02930542]], dtype=float32), array([-0.01426466], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05408997],
#        [ 0.0270379 ]], dtype=float32), array([-0.00221951], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08565961],
#        [ 0.00132605]], dtype=float32), array([-0.0127358], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09690689],
#        [-0.0192508 ]], dtype=float32), array([-0.01518355], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07401755],
#        [ 0.01729451]], dtype=float32), array([-0.00727886], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08544803],
#        [-0.01071176]], dtype=float32), array([-0.01209972], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.0898919 ],
#        [-0.01769889]], dtype=float32), array([-0.01386982], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06555674],
#        [ 0.01050425]], dtype=float32), array([-0.00668193], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0140
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07600798],
#        [-0.03015019]], dtype=float32), array([-0.01149666], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11620604],
#        [-0.07360902]], dtype=float32), array([-0.02457374], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08231282],
#        [-0.02784595]], dtype=float32), array([-0.01299639], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09372737],
#        [-0.04886863]], dtype=float32), array([-0.01733372], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08341537],
#        [-0.01622543]], dtype=float32), array([-0.01209016], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07648165],
#        [-0.00389303]], dtype=float32), array([-0.00945183], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 644us/step - loss: 0.9537
# Epoch 22/40
#
#  w 0 :
#  [array([[-0.11287147],
#        [-0.04411152]], dtype=float32), array([-0.02027847], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0250
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09197847],
#        [-0.02933291]], dtype=float32), array([-0.01361191], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05426726],
#        [ 0.02701107]], dtype=float32), array([-0.00156689], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08583449],
#        [ 0.0013012 ]], dtype=float32), array([-0.01208283], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09708052],
#        [-0.01927376]], dtype=float32), array([-0.01453042], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.0741924],
#        [ 0.0172687]], dtype=float32), array([-0.00662623], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08562634],
#        [-0.01074166]], dtype=float32), array([-0.01144835], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.0900697 ],
#        [-0.01772753]], dtype=float32), array([-0.01321842], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06573394],
#        [ 0.01047626]], dtype=float32), array([-0.00603039], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07618557],
#        [-0.03017957]], dtype=float32), array([-0.01084538], dtype=float32)]
#
# ...
#
#  w 12 :
#  [array([[-0.09578709],
#        [-0.04922115]], dtype=float32), array([-0.0096549], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.0854966 ],
#        [-0.01659006]], dtype=float32), array([-0.00442076], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07854356],
#        [-0.00423061]], dtype=float32), array([-0.00177914], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 665us/step - loss: 0.9537
# Epoch 34/40
#
#  w 0 :
#  [array([[-0.11493367],
#        [-0.04444217]], dtype=float32), array([-0.0126067], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0246
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09405122],
#        [-0.02966329]], dtype=float32), array([-0.00594394], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05633941],
#        [ 0.02668827]], dtype=float32), array([0.00609933], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08787885],
#        [ 0.00100199]], dtype=float32), array([-0.00441262], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09911031],
#        [-0.01955013]], dtype=float32), array([-0.0068582], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07623651],
#        [ 0.01695934]], dtype=float32), array([0.0010401], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08771148],
#        [-0.01109916]], dtype=float32), array([-0.00379695], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#  w 7 :
#  [array([[-0.09214915],
#        [-0.01807031]], dtype=float32), array([-0.00556681], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06780662],
#        [ 0.01014113]], dtype=float32), array([0.00162281], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0141
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07826307],
#        [-0.03053073]], dtype=float32), array([-0.00319525], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11846334],
#        [-0.07400391]], dtype=float32), array([-0.01627433], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08457115],
#        [-0.02825125]], dtype=float32), array([-0.00469958], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.0959549],
#        [-0.04925  ]], dtype=float32), array([-0.00902873], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08566618],
#        [-0.01661989]], dtype=float32), array([-0.00379537], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07871156],
#        [-0.00425824]], dtype=float32), array([-0.00115347], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 632us/step - loss: 0.9537
# Epoch 35/40
#
#  w 0 :
#  [array([[-0.1151017 ],
#        [-0.04446923]], dtype=float32), array([-0.01198111], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0246
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09422012],
#        [-0.02969033]], dtype=float32), array([-0.00531866], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05650827],
#        [ 0.02666185]], dtype=float32), array([0.00672447], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08804543],
#        [ 0.00097749]], dtype=float32), array([-0.00378716], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09927572],
#        [-0.01957275]], dtype=float32), array([-0.00623258], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07640307],
#        [ 0.01693404]], dtype=float32), array([0.00166525], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.0878814 ],
#        [-0.01112838]], dtype=float32), array([-0.00317302], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.09231861],
#        [-0.01809834]], dtype=float32), array([-0.00494287], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06797554],
#        [ 0.01011373]], dtype=float32), array([0.00224688], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0141
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07843238],
#        [-0.03055944]], dtype=float32), array([-0.00257143], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11863282],
#        [-0.0740337 ]], dtype=float32), array([-0.01565066], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08474073],
#        [-0.02828183]], dtype=float32), array([-0.00407611], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09612215],
#        [-0.04927877]], dtype=float32), array([-0.00840465], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08583517],
#        [-0.01664963]], dtype=float32), array([-0.00317204], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07887899],
#        [-0.00428578]], dtype=float32), array([-0.00052989], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 633us/step - loss: 0.9537
# Epoch 36/40
#
#  w 0 :
#  [array([[-0.11526915],
#        [-0.0444962 ]], dtype=float32), array([-0.01135761], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0246
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09438843],
#        [-0.02971727]], dtype=float32), array([-0.00469546], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05667654],
#        [ 0.02663553]], dtype=float32), array([0.00734752], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08821146],
#        [ 0.00095309]], dtype=float32), array([-0.00316379], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09944056],
#        [-0.01959529]], dtype=float32), array([-0.00560904], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07656908],
#        [ 0.01690883]], dtype=float32), array([0.00228831], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08805075],
#        [-0.01115751]], dtype=float32), array([-0.00255117], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.09248751],
#        [-0.01812627]], dtype=float32), array([-0.00432101], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06814388],
#        [ 0.01008642]], dtype=float32), array([0.00286887], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0141
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07860112],
#        [-0.03058805]], dtype=float32), array([-0.00194969], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11880173],
#        [-0.07406338]], dtype=float32), array([-0.01502907], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08490973],
#        [-0.0283123 ]], dtype=float32), array([-0.00345472], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09628884],
#        [-0.04930744]], dtype=float32), array([-0.00778264], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08600362],
#        [-0.01667928]], dtype=float32), array([-0.0025508], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07904588],
#        [-0.00431323]], dtype=float32), array([9.161793e-05], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 643us/step - loss: 0.9537
# Epoch 37/40
#
#  w 0 :
#  [array([[-0.11543607],
#        [-0.04452308]], dtype=float32), array([-0.01073617], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0246
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.0945562 ],
#        [-0.02974412]], dtype=float32), array([-0.00407434], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05684426],
#        [ 0.02660928]], dtype=float32), array([0.0079685], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08837693],
#        [ 0.00092876]], dtype=float32), array([-0.00254248], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09960485],
#        [-0.01961776]], dtype=float32), array([-0.00498757], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07673453],
#        [ 0.01688369]], dtype=float32), array([0.0029093], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08821953],
#        [-0.01118655]], dtype=float32), array([-0.0019314], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.09265583],
#        [-0.01815412]], dtype=float32), array([-0.00370122], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06831166],
#        [ 0.01005919]], dtype=float32), array([0.00348879], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.0787693 ],
#        [-0.03061657]], dtype=float32), array([-0.00133002], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11897008],
#        [-0.07409298]], dtype=float32), array([-0.01440955], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9975
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08507817],
#        [-0.02834269]], dtype=float32), array([-0.0028354], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09645498],
#        [-0.04933602]], dtype=float32), array([-0.00716271], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.0861715 ],
#        [-0.01670882]], dtype=float32), array([-0.00193163], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.0792122 ],
#        [-0.00434059]], dtype=float32), array([0.00071106], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 538us/step - loss: 0.9537
# Epoch 38/40
#
#  w 0 :
#  [array([[-0.11560242],
#        [-0.04454986]], dtype=float32), array([-0.01011681], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0245
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.0947234 ],
#        [-0.02977088]], dtype=float32), array([-0.00345528], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05701143],
#        [ 0.02658314]], dtype=float32), array([0.00858742], dtype=float32)]
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08854187],
#        [ 0.00090452]], dtype=float32), array([-0.00192325], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.0997686 ],
#        [-0.01964014]], dtype=float32), array([-0.00436817], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.07689945],
#        [ 0.01685865]], dtype=float32), array([0.00352823], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08838776],
#        [-0.01121548]], dtype=float32), array([-0.00131368], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.09282361],
#        [-0.01818186]], dtype=float32), array([-0.00308349], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.0684789 ],
#        [ 0.01003207]], dtype=float32), array([0.00410665], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0142
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07893692],
#        [-0.03064498]], dtype=float32), array([-0.00071241], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11913787],
#        [-0.07412246]], dtype=float32), array([-0.01379209], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08524605],
#        [-0.02837294]], dtype=float32), array([-0.00221814], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09662057],
#        [-0.04936448]], dtype=float32), array([-0.00654484], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08633883],
#        [-0.01673826]], dtype=float32), array([-0.00131452], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07937798],
#        [-0.00436785]], dtype=float32), array([0.00132843], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 603us/step - loss: 0.9537
# Epoch 39/40
#
#  w 0 :
#  [array([[-0.11576822],
#        [-0.04457656]], dtype=float32), array([-0.00949951], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0245
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09489006],
#        [-0.02979756]], dtype=float32), array([-0.00283829], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05717804],
#        [ 0.02655707]], dtype=float32), array([0.00920427], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08870624],
#        [ 0.00088036]], dtype=float32), array([-0.00130608], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.09993181],
#        [-0.01966246]], dtype=float32), array([-0.00375084], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.0770638 ],
#        [ 0.01683369]], dtype=float32), array([0.00414508], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08855543],
#        [-0.01124431]], dtype=float32), array([-0.00069803], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.09299082],
#        [-0.01820952]], dtype=float32), array([-0.00246782], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06864557],
#        [ 0.01000503]], dtype=float32), array([0.00472244], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0142
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07910398],
#        [-0.03067332]], dtype=float32), array([-9.686267e-05], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.1193051 ],
#        [-0.07415186]], dtype=float32), array([-0.01317669], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08541337],
#        [-0.02840313]], dtype=float32), array([-0.00160293], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.0967856 ],
#        [-0.04939288]], dtype=float32), array([-0.00592902], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08650558],
#        [-0.01676761]], dtype=float32), array([-0.00069946], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07954319],
#        [-0.00439503]], dtype=float32), array([0.00194375], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 688us/step - loss: 0.9537
# Epoch 40/40
#
#  w 0 :
#  [array([[-0.11593346],
#        [-0.04460318]], dtype=float32), array([-0.00888427], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0245
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.09505613],
#        [-0.02982415]], dtype=float32), array([-0.00222335], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.05734408],
#        [ 0.02653109]], dtype=float32), array([0.00981907], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.08887006],
#        [ 0.00085627]], dtype=float32), array([-0.00069096], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.10009446],
#        [-0.01968471]], dtype=float32), array([-0.00313556], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.0772276 ],
#        [ 0.01680879]], dtype=float32), array([0.00475989], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.08872253],
#        [-0.01127307]], dtype=float32), array([-8.441834e-05], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.09315747],
#        [-0.01823709]], dtype=float32), array([-0.00185419], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.06881168],
#        [ 0.00997808]], dtype=float32), array([0.00533619], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 1.0142
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.07927047],
#        [-0.03070155]], dtype=float32), array([0.00051664], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.11947177],
#        [-0.07418115]], dtype=float32), array([-0.01256334], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08558013],
#        [-0.02843319]], dtype=float32), array([-0.00098977], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.09695008],
#        [-0.04942116]], dtype=float32), array([-0.00531526], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.08667178],
#        [-0.01679686]], dtype=float32), array([-8.645328e-05], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.07970785],
#        [-0.00442212]], dtype=float32), array([0.00255702], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 628us/step - loss: 0.9536

# %%
##############
# (b) linearly seperable
#############

iris_lr.fit(training, labels, epochs=1, batch_size=1,callbacks = [ print_weights, print_examples ], shuffle=False)

lr = iris_lr.layers[0].get_weights()

fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 0, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(lr[1][0]+lr[0][0,0]*x)/lr[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)
# Out:
# Epoch 1/1
#
#  w 0 :
#  [array([[-0.11609815],
#        [-0.0446297 ]], dtype=float32), array([-0.00827107], dtype=float32)]
#
#   1/150 [..............................] - ETA: 0s - loss: 0.1493
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.14005254],
#        [-0.08712944]], dtype=float32), array([-0.0159983], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.02910483],
#        [-0.03491876]], dtype=float32), array([0.01663338], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[0.05854801],
#        [0.00429436]], dtype=float32), array([0.03969992], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[0.11622439],
#        [0.02159727]], dtype=float32), array([0.05411901], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[0.15088286],
#        [0.04096524]], dtype=float32), array([0.06431268], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[0.17544702],
#        [0.05180237]], dtype=float32), array([0.07153744], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[ 0.05104496],
#        [-0.18145148]], dtype=float32), array([0.0326618], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[ 0.12936865],
#        [-0.15534359]], dtype=float32), array([0.05274479], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[ 0.0918863 ],
#        [-0.21959907]], dtype=float32), array([0.03935824], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[ 0.07216899],
#        [-0.25027043]], dtype=float32), array([0.03205553], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[ 0.06600673],
#        [-0.26069888]], dtype=float32), array([0.02968543], dtype=float32)]
#
#  12/150 [=>............................] - ETA: 0s - loss: 0.8703
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[ 0.07211825],
#        [-0.2503093 ]], dtype=float32), array([0.03172261], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[ 0.06932269],
#        [-0.25478217]], dtype=float32), array([0.03079075], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[ 0.14136423],
#        [-0.21759944]], dtype=float32), array([0.05402996], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
#
#  w 15 :
#  [array([[ 0.1243947 ],
#        [-0.24825408]], dtype=float32), array([0.04855591], dtype=float32)]
#
#
#  z:  [3.4 1.4] y:  1
#
#  w 16 :
#  [array([[ 0.18396664],
#        [-0.22372445]], dtype=float32), array([0.06607707], dtype=float32)]
#
#
#  z:  [3.5 1.4] y:  1
#
#  w 17 :
#  [array([[ 0.22619441],
#        [-0.20683335]], dtype=float32), array([0.07814215], dtype=float32)]
#
#
#  z:  [2.9 4.5] y:  -1
#
#  w 18 :
#  [array([[ 0.17959976],
#        [-0.27913538]], dtype=float32), array([0.06207503], dtype=float32)]
#
#
#  z:  [4.2 1.4] y:  1
#
#  w 19 :
#  [array([[ 0.22784898],
#        [-0.2630523 ]], dtype=float32), array([0.07356294], dtype=float32)]
#
#
#  z:  [3.4 1.4] y:  1
#
#  w 20 :
#  [array([[ 0.2632106 ],
#        [-0.24849164]], dtype=float32), array([0.08396342], dtype=float32)]
#
#
#  z:  [2.8 6.7] y:  -1
#
#  w 21 :
#  [array([[ 0.25447127],
#        [-0.26940358]], dtype=float32), array([0.08084223], dtype=float32)]
#
#
#  z:  [2.9 4.2] y:  -1
#
#  w 22 :
#  [array([[ 0.21460706],
#        [-0.32713795]], dtype=float32), array([0.06709596], dtype=float32)]
#
#
#  z:  [2.3 4.4] y:  -1
#
#  w 23 :
#  [array([[ 0.20902795],
#        [-0.33781105]], dtype=float32), array([0.06467026], dtype=float32)]
#
#  24/150 [===>..........................] - ETA: 0s - loss: 0.6154
#  z:  [2.7 5.1] y:  -1
#
#  w 24 :
#  [array([[ 0.21409264],
#        [-0.32824442]], dtype=float32), array([0.06654607], dtype=float32)]
#
#
#  z:  [2.5 5. ] y:  -1
#
#  w 25 :
#  [array([[ 0.21606487],
#        [-0.32429996]], dtype=float32), array([0.06733496], dtype=float32)]
#
#
#  z:  [2.6 5.6] y:  -1
#
#  w 26 :
#  [array([[ 0.22578762],
#        [-0.30335864]], dtype=float32), array([0.07107448], dtype=float32)]
#
#
#  z:  [3.3 5.7] y:  -1
#
#  w 27 :
#  [array([[ 0.22004369],
#        [-0.31328   ]], dtype=float32), array([0.06933389], dtype=float32)]
#
#
#  z:  [3.  6.1] y:  -1
#
#  w 28 :
#  [array([[ 0.23093626],
#        [-0.29113176]], dtype=float32), array([0.07296474], dtype=float32)]
#
#
#  z:  [2.2 5. ] y:  -1
#
#  w 29 :
#  [array([[ 0.22542016],
#        [-0.30366835]], dtype=float32), array([0.07045743], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 30 :
#  [array([[ 0.26955104],
#        [-0.28290087]], dtype=float32), array([0.08343709], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 31 :
#  [array([[ 0.23849198],
#        [-0.33323798]], dtype=float32), array([0.07272707], dtype=float32)]
#
#
#  z:  [2.8 4.9] y:  -1
#
#  w 32 :
#  [array([[ 0.23246422],
#        [-0.34378654]], dtype=float32), array([0.0705743], dtype=float32)]
#
#
#  z:  [3.8 1.5] y:  1
#
#  w 33 :
#  [array([[ 0.2751566 ],
#        [-0.32693428]], dtype=float32), array([0.08180913], dtype=float32)]
#
#  34/150 [=====>........................] - ETA: 0s - loss: 0.4685
#  z:  [2.9 6.3] y:  -1
#
#  w 34 :
#  [array([[ 0.2855921],
#        [-0.304264 ]], dtype=float32), array([0.08540758], dtype=float32)]
#
#
#  z:  [2.  3.5] y:  -1
#
#  w 35 :
#  [array([[ 0.2619254 ],
#        [-0.34568074]], dtype=float32), array([0.07357422], dtype=float32)]
#
#
#  z:  [3.  5.9] y:  -1
#
#  w 36 :
#  [array([[ 0.27273536],
#        [-0.32442114]], dtype=float32), array([0.07717755], dtype=float32)]
#
#
#  z:  [3.5 1.5] y:  1
#
#  w 37 :
#  [array([[ 0.304577 ],
#        [-0.3107747]], dtype=float32), array([0.08627515], dtype=float32)]
#
#
#  z:  [2.8 5.1] y:  -1
#
#  w 38 :
#  [array([[ 0.28474516],
#        [-0.34689695]], dtype=float32), array([0.07919236], dtype=float32)]
#
#
#  z:  [2.4 3.3] y:  -1
#
#  w 39 :
#  [array([[ 0.25508976],
#        [-0.3876731 ]], dtype=float32), array([0.06683595], dtype=float32)]
#
#
#  z:  [3.3 6. ] y:  -1
#
#  w 40 :
#  [array([[ 0.28263858],
#        [-0.33758435]], dtype=float32), array([0.07518408], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
#
#  w 41 :
#  [array([[ 0.31560966],
#        [-0.32219782]], dtype=float32), array([0.08617444], dtype=float32)]
#
#
#  z:  [3.6 1.4] y:  1
#
#  w 42 :
#  [array([[ 0.33207664],
#        [-0.315794  ]], dtype=float32), array([0.0907486], dtype=float32)]
#
#
#  z:  [3.1 4.9] y:  -1
#
#  w 43 :
#  [array([[ 0.29656333],
#        [-0.37192795]], dtype=float32), array([0.07929269], dtype=float32)]
#
#
#  z:  [2.8 4.1] y:  -1
#
#  w 44 :
#  [array([[ 0.27501646],
#        [-0.4034787 ]], dtype=float32), array([0.07159738], dtype=float32)]
#
#  45/150 [========>.....................] - ETA: 0s - loss: 0.4034
#  z:  [3.2 5.7] y:  -1
#
#  w 45 :
#  [array([[ 0.2972999 ],
#        [-0.36378637]], dtype=float32), array([0.07856096], dtype=float32)]
#
#
#  z:  [2.8 4.7] y:  -1
#
#  w 46 :
#  [array([[ 0.28603244],
#        [-0.3826996 ]], dtype=float32), array([0.07453686], dtype=float32)]
#
#
#  z:  [2.8 5.6] y:  -1
#
#  w 47 :
#  [array([[ 0.30102307],
#        [-0.35271832]], dtype=float32), array([0.07989066], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 48 :
#  [array([[ 0.32584277],
#        [-0.34265628]], dtype=float32), array([0.08659869], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 49 :
#  [array([[ 0.291822  ],
#        [-0.39179742]], dtype=float32), array([0.07399839], dtype=float32)]
#
#
#  z:  [2.9 3.6] y:  -1
#
#  w 50 :
#  [array([[ 0.26225293],
#        [-0.42850384]], dtype=float32), array([0.06380216], dtype=float32)]
#
#
#  z:  [3.4 5.6] y:  -1
#
#  w 51 :
#  [array([[ 0.29245576],
#        [-0.37875798]], dtype=float32), array([0.07268535], dtype=float32)]
#
#
#  z:  [3.2 1.2] y:  1
#
#  w 52 :
#  [array([[ 0.32099757],
#        [-0.3680548 ]], dtype=float32), array([0.08160466], dtype=float32)]
#
#
#  z:  [3.  1.3] y:  1
#
#  w 53 :
#  [array([[ 0.34702998],
#        [-0.3567741 ]], dtype=float32), array([0.09028213], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 54 :
#  [array([[ 0.3638638 ],
#        [-0.34993535]], dtype=float32), array([0.0955427], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 55 :
#  [array([[ 0.37693498],
#        [-0.34416866]], dtype=float32), array([0.09938717], dtype=float32)]
#
#  56/150 [==========>...................] - ETA: 0s - loss: 0.3535
#  z:  [3.2 5.9] y:  -1
#
#  w 56 :
#  [array([[ 0.359336  ],
#        [-0.37661678]], dtype=float32), array([0.09388749], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 57 :
#  [array([[ 0.3781625 ],
#        [-0.33519846]], dtype=float32), array([0.10016299], dtype=float32)]
#
#
#  z:  [3.  1.6] y:  1
#
#  w 58 :
#  [array([[ 0.39626253],
#        [-0.32554513]], dtype=float32), array([0.10619633], dtype=float32)]
#
#
#  z:  [3.8 1.9] y:  1
#
#  w 59 :
#  [array([[ 0.3967597 ],
#        [-0.32529655]], dtype=float32), array([0.10632716], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 60 :
#  [array([[ 0.34254757],
#        [-0.4049206 ]], dtype=float32), array([0.08938587], dtype=float32)]
#
#
#  z:  [2.5 3. ] y:  -1
#
#  w 61 :
#  [array([[ 0.3059979 ],
#        [-0.44878018]], dtype=float32), array([0.07476601], dtype=float32)]
#
#
#  z:  [3.1 5.4] y:  -1
#
#  w 62 :
#  [array([[ 0.33080122],
#        [-0.4055744 ]], dtype=float32), array([0.08276708], dtype=float32)]
#
#
#  z:  [2.5 3.9] y:  -1
#
#  w 63 :
#  [array([[ 0.31439972],
#        [-0.43116075]], dtype=float32), array([0.07620648], dtype=float32)]
#
#
#  z:  [2.5 4.5] y:  -1
#
#  w 64 :
#  [array([[ 0.3183006 ],
#        [-0.42413917]], dtype=float32), array([0.07776684], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
#
#  w 65 :
#  [array([[ 0.31443113],
#        [-0.42994338]], dtype=float32), array([0.07655762], dtype=float32)]
#
#
#  z:  [2.7 4.9] y:  -1
#
#  w 66 :
#  [array([[ 0.32421598],
#        [-0.4121857 ]], dtype=float32), array([0.08018164], dtype=float32)]
#  z:  [3.9 1.7] y:  1
#
#  w 67 :
#  [array([[ 0.35199115],
#        [-0.4000786 ]], dtype=float32), array([0.08730347], dtype=float32)]
#
#
#  z:  [3.1 4.4] y:  -1
#
#  w 68 :
#  [array([[ 0.3260671 ],
#        [-0.43687406]], dtype=float32), array([0.07894086], dtype=float32)]
#
#  69/150 [============>.................] - ETA: 0s - loss: 0.3200
#  z:  [3.  5.8] y:  -1
#
#  w 69 :
#  [array([[ 0.35467073],
#        [-0.38157368]], dtype=float32), array([0.08847541], dtype=float32)]
#
#
#  z:  [2.5 4. ] y:  -1
#
#  w 70 :
#  [array([[ 0.33222786],
#        [-0.4174823 ]], dtype=float32), array([0.07949826], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 71 :
#  [array([[ 0.33290163],
#        [-0.41635934]], dtype=float32), array([0.07972285], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 72 :
#  [array([[ 0.33215556],
#        [-0.4176383 ]], dtype=float32), array([0.0794564], dtype=float32)]
#
#
#  z:  [3.6 1. ] y:  1
#
#  w 73 :
#  [array([[ 0.34240994],
#        [-0.41478986]], dtype=float32), array([0.08230484], dtype=float32)]
#
#
#  z:  [3.8 6.4] y:  -1
#
#  w 74 :
#  [array([[ 0.36302057],
#        [-0.38007718]], dtype=float32), array([0.08772869], dtype=float32)]
#
#
#  z:  [3.  4.6] y:  -1
#
#  w 75 :
#  [array([[ 0.33731446],
#        [-0.41949323]], dtype=float32), array([0.07915998], dtype=float32)]
#
#
#  z:  [3.2 1.6] y:  1
#
#  w 76 :
#  [array([[ 0.3701223 ],
#        [-0.40308928]], dtype=float32), array([0.08941244], dtype=float32)]
#
#
#  z:  [2.5 5.8] y:  -1
#
#  w 77 :
#  [array([[ 0.3862823],
#        [-0.3655981]], dtype=float32), array([0.09587643], dtype=float32)]
#
#
#  z:  [3.  5.8] y:  -1
#
#  w 78 :
#  [array([[ 0.37822706],
#        [-0.3811716 ]], dtype=float32), array([0.09319135], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 79 :
#  [array([[ 0.3690239],
#        [-0.3985554]], dtype=float32), array([0.08978277], dtype=float32)]
#
#
#  z:  [2.8 4.6] y:  -1
#
#  w 80 :
#  [array([[ 0.35280097],
#        [-0.42520732]], dtype=float32), array([0.08398887], dtype=float32)]
#
#
#  z:  [2.6 3.5] y:  -1
#
#  w 81 :
#  [array([[ 0.32612258],
#        [-0.46112052]], dtype=float32), array([0.07372795], dtype=float32)]
#
#  82/150 [===============>..............] - ETA: 0s - loss: 0.2855
#  z:  [3.4 5.4] y:  -1
#
#  w 82 :
#  [array([[ 0.347033  ],
#        [-0.42790988]], dtype=float32), array([0.07987807], dtype=float32)]
#
#
#  z:  [2.9 4.3] y:  -1
#
#  w 83 :
#  [array([[ 0.33274984],
#        [-0.44908834]], dtype=float32), array([0.07495285], dtype=float32)]
#
#
#  z:  [2.7 4.1] y:  -1
#
#  w 84 :
#  [array([[ 0.3256156 ],
#        [-0.45992178]], dtype=float32), array([0.07231054], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 85 :
#  [array([[ 0.36332175],
#        [-0.44167686]], dtype=float32), array([0.08447382], dtype=float32)]
#
#
#  z:  [2.9 5.6] y:  -1
#
#  w 86 :
#  [array([[ 0.38276818],
#        [-0.40412512]], dtype=float32), array([0.09117949], dtype=float32)]
#
#
#  z:  [2.9 4.3] y:  -1
#
#  w 87 :
#  [array([[ 0.35588697],
#        [-0.44398347]], dtype=float32), array([0.0819101], dtype=float32)]
#
#
#  z:  [3.5 1.3] y:  1
#
#  w 88 :
#  [array([[ 0.37336344],
#        [-0.4374922 ]], dtype=float32), array([0.08690339], dtype=float32)]
#
#
#  z:  [3.2 5.3] y:  -1
#
#  w 89 :
#  [array([[ 0.37573415],
#        [-0.4335657 ]], dtype=float32), array([0.08764423], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
#
#  w 90 :
#  [array([[ 0.39926288],
#        [-0.42258564]], dtype=float32), array([0.09548714], dtype=float32)]
#
#
#  z:  [2.4 3.7] y:  -1
#
#  w 91 :
#  [array([[ 0.3757356 ],
#        [-0.45885682]], dtype=float32), array([0.08568412], dtype=float32)]
#
#  92/150 [=================>............] - ETA: 0s - loss: 0.2693
#  z:  [3.2 1.4] y:  1
#
#  w 92 :
#  [array([[ 0.39841473],
#        [-0.4489347 ]], dtype=float32), array([0.09277135], dtype=float32)]
#
#
#  z:  [2.9 1.4] y:  1
#
#  w 93 :
#  [array([[ 0.42047414],
#        [-0.43828535]], dtype=float32), array([0.10037804], dtype=float32)]
#
#
#  z:  [2.8 4. ] y:  -1
#
#  w 94 :
#  [array([[ 0.39109856],
#        [-0.48025048]], dtype=float32), array([0.08988675], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 95 :
#  [array([[ 0.4126702 ],
#        [-0.43790615]], dtype=float32), array([0.09787625], dtype=float32)]
#
#
#  z:  [2.8 5.6] y:  -1
#
#  w 96 :
#  [array([[ 0.4238098 ],
#        [-0.41562694]], dtype=float32), array([0.10185468], dtype=float32)]
#
#
#  z:  [4.4 1.5] y:  1
#
#  w 97 :
#  [array([[ 0.39361018],
#        [-0.42592227]], dtype=float32), array([0.09499113], dtype=float32)]
#
#
#  z:  [4.1 1.5] y:  1
#
#  w 98 :
#  [array([[ 0.3878776 ],
#        [-0.42801955]], dtype=float32), array([0.09359294], dtype=float32)]
#
#
#  z:  [2.5 5. ] y:  -1
#
#  w 99 :
#  [array([[ 0.39171815],
#        [-0.42033848]], dtype=float32), array([0.09512916], dtype=float32)]
#
#
#  z:  [3.6 1.4] y:  1
#
#  w 100 :
#  [array([[ 0.3977056 ],
#        [-0.41801003]], dtype=float32), array([0.09679235], dtype=float32)]
#
#
#  z:  [3.6 6.1] y:  -1
#
#  w 101 :
#  [array([[ 0.39924127],
#        [-0.41540793]], dtype=float32), array([0.09721892], dtype=float32)]
#
#
#  z:  [3.5 1.6] y:  1
#
#  w 102 :
#  [array([[ 0.41114753],
#        [-0.40996507]], dtype=float32), array([0.10062071], dtype=float32)]
#
# 103/150 [===================>..........] - ETA: 0s - loss: 0.2509
#  z:  [3.  4.4] y:  -1
#
#  w 103 :
#  [array([[ 0.3793345 ],
#        [-0.45662415]], dtype=float32), array([0.09001637], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 104 :
#  [array([[ 0.39092094],
#        [-0.43473867]], dtype=float32), array([0.09430764], dtype=float32)]
#
#
#  z:  [2.4 3.8] y:  -1
#
#  w 105 :
#  [array([[ 0.3726564],
#        [-0.4636575]], dtype=float32), array([0.08669741], dtype=float32)]
#
#
#  z:  [2.3 1.3] y:  1
#
#  w 106 :
#  [array([[ 0.402968  ],
#        [-0.44652486]], dtype=float32), array([0.09987637], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 107 :
#  [array([[ 0.41655573],
#        [-0.44053027]], dtype=float32), array([0.10387276], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 108 :
#  [array([[ 0.3944663],
#        [-0.474514 ]], dtype=float32), array([0.09537683], dtype=float32)]
#
#
#  z:  [3.  4.2] y:  -1
#
#  w 109 :
#  [array([[ 0.37731728],
#        [-0.49852264]], dtype=float32), array([0.08966049], dtype=float32)]
#
#
#  z:  [2.6 6.9] y:  -1
#
#  w 110 :
#  [array([[ 0.44851157],
#        [-0.30958396]], dtype=float32), array([0.11704291], dtype=float32)]
#
#
#  z:  [3.5 1.3] y:  1
#
#  w 111 :
#  [array([[ 0.42860538],
#        [-0.31697768]], dtype=float32), array([0.11135542], dtype=float32)]
#
#
#  z:  [3.  5.5] y:  -1
#
#  w 112 :
#  [array([[ 0.3893777 ],
#        [-0.38889506]], dtype=float32), array([0.09827954], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 113 :
#  [array([[ 0.35520065],
#        [-0.43826193]], dtype=float32), array([0.08562136], dtype=float32)]
#
#
#  z:  [3.3 5.7] y:  -1
#
#  w 114 :
#  [array([[ 0.37106106],
#        [-0.41086665]], dtype=float32), array([0.09042755], dtype=float32)]
#
# 115/150 [======================>.......] - ETA: 0s - loss: 0.2594
#  z:  [3.  4.2] y:  -1
#
#  w 115 :
#  [array([[ 0.34238282],
#        [-0.4510162 ]], dtype=float32), array([0.08086813], dtype=float32)]
#
#
#  z:  [2.3 3.3] y:  -1
#
#  w 116 :
#  [array([[ 0.32490304],
#        [-0.47609589]], dtype=float32), array([0.07326823], dtype=float32)]
#
#
#  z:  [2.5 4.9] y:  -1
#
#  w 117 :
#  [array([[ 0.34727025],
#        [-0.43225616]], dtype=float32), array([0.08221511], dtype=float32)]
#
#
#  z:  [2.8 6.1] y:  -1
#
#  w 118 :
#  [array([[ 0.37987295],
#        [-0.36122888]], dtype=float32), array([0.09385893], dtype=float32)]
#
#
#  z:  [3.2 4.5] y:  -1
#
#  w 119 :
#  [array([[ 0.33610192],
#        [-0.42278188]], dtype=float32), array([0.08018048], dtype=float32)]
#
#
#  z:  [3.  5.5] y:  -1
#
#  w 120 :
#  [array([[ 0.35031077],
#        [-0.39673233]], dtype=float32), array([0.08491676], dtype=float32)]
#
#
#  z:  [3.  4.5] y:  -1
#
#  w 121 :
#  [array([[ 0.32927755],
#        [-0.42828214]], dtype=float32), array([0.07790569], dtype=float32)]
#
#
#  z:  [3.4 4.5] y:  -1
#
#  w 122 :
#  [array([[ 0.31090534],
#        [-0.4525983 ]], dtype=float32), array([0.0725021], dtype=float32)]
#
#
#  z:  [3.3 1.7] y:  1
#
#  w 123 :
#  [array([[ 0.35518655],
#        [-0.42978677]], dtype=float32), array([0.08592065], dtype=float32)]
#
#
#  z:  [3.3 1.4] y:  1
#
#  w 124 :
#  [array([[ 0.37786847],
#        [-0.42016414]], dtype=float32), array([0.09279396], dtype=float32)]
#
# 125/150 [========================>.....] - ETA: 0s - loss: 0.2555
#  z:  [3.1 1.5] y:  1
#
#  w 125 :
#  [array([[ 0.4005642 ],
#        [-0.40918234]], dtype=float32), array([0.10011516], dtype=float32)]
#
#
#  z:  [3.8 1.6] y:  1
#
#  w 126 :
#  [array([[ 0.40302908],
#        [-0.4081445 ]], dtype=float32), array([0.10076381], dtype=float32)]
#
#
#  z:  [3.4 1.7] y:  1
#
#  w 127 :
#  [array([[ 0.41817832],
#        [-0.4005699 ]], dtype=float32), array([0.10521947], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 128 :
#  [array([[ 0.4143581 ],
#        [-0.40211862]], dtype=float32), array([0.10418698], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 129 :
#  [array([[ 0.38343626],
#        [-0.44900015]], dtype=float32), array([0.09421219], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 130 :
#  [array([[ 0.38077104],
#        [-0.45335335]], dtype=float32), array([0.09332378], dtype=float32)]
#
#
#  z:  [2.9 4.6] y:  -1
#  w 131 :
#  [array([[ 0.37426725],
#        [-0.46366972]], dtype=float32), array([0.0910811], dtype=float32)]
#
#
#  z:  [2.2 4. ] y:  -1
#
#  w 132 :
#  [array([[ 0.37163648],
#        [-0.46845293]], dtype=float32), array([0.08988529], dtype=float32)]
#
#
#  z:  [3.8 6.7] y:  -1
#
#  w 133 :
#  [array([[ 0.4200128 ],
#        [-0.38315782]], dtype=float32), array([0.10261591], dtype=float32)]
#
#
#  z:  [2.3 4. ] y:  -1
#
#  w 134 :
#  [array([[ 0.39535615],
#        [-0.42603895]], dtype=float32), array([0.09189562], dtype=float32)]
#
# 135/150 [==========================>...] - ETA: 0s - loss: 0.2441
#  z:  [3.  5.2] y:  -1
#
#  w 135 :
#  [array([[ 0.39160246],
#        [-0.43254536]], dtype=float32), array([0.09064439], dtype=float32)]
#
#
#  z:  [3.  4.1] y:  -1
#
#  w 136 :
#  [array([[ 0.36208153],
#        [-0.47289065]], dtype=float32), array([0.08080407], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 137 :
#  [array([[ 0.38345498],
#        [-0.46422574]], dtype=float32), array([0.08658068], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 138 :
#  [array([[ 0.39407668],
#        [-0.4458148 ]], dtype=float32), array([0.09012125], dtype=float32)]
#
#
#  z:  [3.  1.1] y:  1
#
#  w 139 :
#  [array([[ 0.4071594],
#        [-0.4410178]], dtype=float32), array([0.09448215], dtype=float32)]
#
#
#  z:  [3.2 5.1] y:  -1
#
#  w 140 :
#  [array([[ 0.3976745 ],
#        [-0.45613435]], dtype=float32), array([0.09151812], dtype=float32)]
#
#
#  z:  [2.2 4.5] y:  -1
#
#  w 141 :
#  [array([[ 0.4014674 ],
#        [-0.44837612]], dtype=float32), array([0.09324217], dtype=float32)]
#
#
#  z:  [3.  4.5] y:  -1
#
#  w 142 :
#  [array([[ 0.38467032],
#        [-0.47357178]], dtype=float32), array([0.08764313], dtype=float32)]
#
#
#  z:  [3.3 4.7] y:  -1
#
#  w 143 :
#  [array([[ 0.37600663],
#        [-0.48591098]], dtype=float32), array([0.08501777], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 144 :
#  [array([[ 0.39798713],
#        [-0.4769814 ]], dtype=float32), array([0.09188668], dtype=float32)]
#
# 145/150 [============================>.] - ETA: 0s - loss: 0.2321
#  z:  [2.8 5.1] y:  -1
#
#  w 145 :
#  [array([[ 0.41066298],
#        [-0.45389324]], dtype=float32), array([0.09641377], dtype=float32)]
#
#
#  z:  [3.1 5.1] y:  -1
#
#  w 146 :
#  [array([[ 0.40727696],
#        [-0.4594638 ]], dtype=float32), array([0.0953215], dtype=float32)]
#
#
#  z:  [2.8 4.5] y:  -1
#
#  w 147 :
#  [array([[ 0.39786282],
#        [-0.4745937 ]], dtype=float32), array([0.09195931], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 148 :
#  [array([[ 0.4218293],
#        [-0.462997 ]], dtype=float32), array([0.09969044], dtype=float32)]
#
#
#  z:  [3.5 1.4] y:  1
#
#  w 149 :
#  [array([[ 0.42687652],
#        [-0.46097812]], dtype=float32), array([0.10113249], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
# 150/150 [==============================] - 1s 5ms/step - loss: 0.2261

# %% [markdown]
# ### Problem 2.
# a. Using keras and gradient descent, simulate a 1-neuron network that mimics support vector machine (namely minimize hinge loss, but add in l2 regularization for the model weights). You will have to look up the documentation on keras.regularizers (if you fail to figure this out, email me with the steps you tried).

# %%
from keras import regularizers
from keras.losses import hinge


iris_lr = Sequential([
    Dense(1, input_shape=(2,), 
          kernel_regularizer=regularizers.l2(0.001)),
    Activation('linear'),
    
])

opt = SGD(lr=0.01,momentum=0,nesterov=False)

iris_lr.compile(optimizer=opt,
              loss = hinge,
              metrics = ['categorical_accuracy'])

# %% [markdown]
# b. As before, test your algorithm on the Iris dataset above to classify non-linearly separable classes. Again, check if the gradients are what you expect by checking the weights before and after an example using callbacks as above.

# %%
print_weights = LambdaCallback(on_batch_begin=lambda batch, logs: print('\n w',batch,': \n',iris_lr.layers[0].get_weights(),'\n'))
print_examples = LambdaCallback(on_batch_end = lambda batch, logs: print('\n z: ',training[batch,:],'y: ', labels[batch]))

iris_lr.layers[0].set_weights([np.array([[0.01],[0.01]]),np.array([0.0])])



####################
## Non Linearly seperable
###################
print("=================== Non Linear ===================")


iris_lr.fit(color_train, color_target, epochs=40, batch_size=10,callbacks = [ print_weights, print_examples ], shuffle=False)

lr = iris_lr.layers[0].get_weights()

fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 2, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(lr[1][0]+lr[0][0,0]*x)/lr[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)


####################
## CAlls backs
###################
print("=================== CALLS BACKS ===================")

iris_lr.fit(training, labels, epochs=150, batch_size=32,callbacks = [ print_weights, print_examples ], shuffle=False)

lr = iris_lr.layers[0].get_weights()

fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 0, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(lr[1][0]+lr[0][0,0]*x)/lr[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)
# Out:
# =================== Non Linear ===================
# Epoch 1/40
#
#  w 0 :
#  [array([[0.01],
#        [0.01]], dtype=float32), array([0.], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 1s - loss: 1.0205 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.0044998],
#        [-0.0050002]], dtype=float32), array([-0.002], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[0.01079971],
#        [0.0081999 ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.00770051],
#        [-0.00620027]], dtype=float32), array([-0.006], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.02230036],
#        [-0.02840014]], dtype=float32), array([-0.01], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.02279991],
#        [-0.02829958]], dtype=float32), array([-0.01], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.03319945],
#        [-0.04699901]], dtype=float32), array([-0.014], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.04499879],
#        [-0.06219807]], dtype=float32), array([-0.018], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.04389789],
#        [-0.06229683]], dtype=float32), array([-0.018], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.05399701],
#        [-0.08859558]], dtype=float32), array([-0.022], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.08469593],
#        [-0.12219381]], dtype=float32), array([-0.032], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.08609423],
#        [-0.11489137]], dtype=float32), array([-0.032], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.8950 - categorical_accuracy: 1.0000
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.10379251],
#        [-0.14108908]], dtype=float32), array([-0.038], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.10599043],
#        [-0.13228627]], dtype=float32), array([-0.038], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.10638832],
#        [-0.12738362]], dtype=float32), array([-0.038], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 937us/step - loss: 0.8573 - categorical_accuracy: 1.0000
# Epoch 2/40
#
#  w 0 :
#  [array([[-0.12058619],
#        [-0.13328107]], dtype=float32), array([-0.042], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.7667 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.11728378],
#        [-0.1315784 ]], dtype=float32), array([-0.041], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.11098143],
#        [-0.11837577]], dtype=float32), array([-0.039], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.12337922],
#        [-0.1214734 ]], dtype=float32), array([-0.04300001], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.12197675],
#        [-0.11357097]], dtype=float32), array([-0.04200001], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.11947431],
#        [-0.1068687 ]], dtype=float32), array([-0.04100001], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.12987192],
#        [-0.12556656]], dtype=float32), array([-0.04500001], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.13506933],
#        [-0.12986405]], dtype=float32), array([-0.04700001], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.12796663],
#        [-0.12046146]], dtype=float32), array([-0.04500001], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.12886406],
#        [-0.13205905]], dtype=float32), array([-0.04600001], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.15406148],
#        [-0.15495642]], dtype=float32), array([-0.05400001], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.7627 - categorical_accuracy: 1.0000
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.1554584 ],
#        [-0.14765331]], dtype=float32), array([-0.05400001], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.15635529],
#        [-0.14355035]], dtype=float32), array([-0.05400001], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.15585217],
#        [-0.13084748]], dtype=float32), array([-0.05300001], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.15324906],
#        [-0.12134486]], dtype=float32), array([-0.05200001], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 489us/step - loss: 0.7266 - categorical_accuracy: 1.0000
# Epoch 3/40
#
#  w 0 :
#  [array([[-0.16464598],
#        [-0.12234244]], dtype=float32), array([-0.05500001], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.7969 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.15564269],
#        [-0.11153999]], dtype=float32), array([-0.05200001], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.14643958],
#        [-0.09363776]], dtype=float32), array([-0.04900001], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.15883665],
#        [-0.09673589]], dtype=float32), array([-0.05300001], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.15743347],
#        [-0.08883396]], dtype=float32), array([-0.05200002], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.15493032],
#        [-0.08213218]], dtype=float32), array([-0.05100002], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.16532722],
#        [-0.10083054]], dtype=float32), array([-0.05500002], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.17052391],
#        [-0.10512852]], dtype=float32), array([-0.05700002], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.1634205 ],
#        [-0.09572642]], dtype=float32), array([-0.05500002], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.16431724],
#        [-0.1073245 ]], dtype=float32), array([-0.05600002], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.18951395],
#        [-0.13022237]], dtype=float32), array([-0.06400002], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.7569 - categorical_accuracy: 1.0000
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.18431017],
#        [-0.11781976]], dtype=float32), array([-0.06200002], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.18520649],
#        [-0.11371741]], dtype=float32), array([-0.06200002], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.18470278],
#        [-0.10101514]], dtype=float32), array([-0.06100002], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.18209909],
#        [-0.09151311]], dtype=float32), array([-0.06000002], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 497us/step - loss: 0.7156 - categorical_accuracy: 1.0000
# Epoch 4/40
#
#  w 0 :
#  [array([[-0.19349545],
#        [-0.09251128]], dtype=float32), array([-0.06300002], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.7930 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.18449157],
#        [-0.08170943]], dtype=float32), array([-0.06000002], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.17818789],
#        [-0.0685078 ]], dtype=float32), array([-0.05800002], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.19668433],
#        [-0.08290642]], dtype=float32), array([-0.06400003], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.1952804 ],
#        [-0.07500476]], dtype=float32), array([-0.06300002], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.1896765 ],
#        [-0.06340326]], dtype=float32), array([-0.06100002], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.2000727],
#        [-0.082102 ]], dtype=float32), array([-0.06500002], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.20526871],
#        [-0.08640036]], dtype=float32), array([-0.06700002], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.19526461],
#        [-0.07279863]], dtype=float32), array([-0.06400002], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.1991607 ],
#        [-0.08919718]], dtype=float32), array([-0.06600001], dtype=float32)]
# 100/150 [===================>..........] - ETA: 0s - loss: 0.7161 - categorical_accuracy: 1.0000
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.2214567 ],
#        [-0.10779539]], dtype=float32), array([-0.07300001], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.21625228],
#        [-0.09539324]], dtype=float32), array([-0.07100002], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.20944795],
#        [-0.08829133]], dtype=float32), array([-0.06900002], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.21164376],
#        [-0.07948957]], dtype=float32), array([-0.06900002], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.20503952],
#        [-0.06878798]], dtype=float32), array([-0.06700002], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 640us/step - loss: 0.7043 - categorical_accuracy: 1.0000
# Epoch 5/40
#
#  w 0 :
#  [array([[-0.21923542],
#        [-0.0746866 ]], dtype=float32), array([-0.07100002], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.7993 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.21023104],
#        [-0.06388511]], dtype=float32), array([-0.06800003], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.20392683],
#        [-0.05068383]], dtype=float32), array([-0.06600003], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.21802275],
#        [-0.06358282]], dtype=float32), array([-0.07100003], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.2125184 ],
#        [-0.05418155]], dtype=float32), array([-0.06900004], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.21001415],
#        [-0.04748046]], dtype=float32), array([-0.06800003], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.22040994],
#        [-0.06617951]], dtype=float32), array([-0.07200003], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.22560553],
#        [-0.07047819]], dtype=float32), array([-0.07400003], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.21560103],
#        [-0.05687678]], dtype=float32), array([-0.07100003], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.7883 - categorical_accuracy: 1.0000
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.21949671],
#        [-0.07327564]], dtype=float32), array([-0.07300003], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.23799232],
#        [-0.08997417]], dtype=float32), array([-0.07900003], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.22818756],
#        [-0.07887238]], dtype=float32), array([-0.07600003], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.22138299],
#        [-0.07177079]], dtype=float32), array([-0.07400003], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.22357856],
#        [-0.06296936]], dtype=float32), array([-0.07400003], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.21697408],
#        [-0.0522681 ]], dtype=float32), array([-0.07200003], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 580us/step - loss: 0.6988 - categorical_accuracy: 1.0000
# Epoch 6/40
#
#  w 0 :
#  [array([[-0.23116975],
#        [-0.05816705]], dtype=float32), array([-0.07600003], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.7950 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.22766513],
#        [-0.05706589]], dtype=float32), array([-0.07500003], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.21476057],
#        [-0.03766475]], dtype=float32), array([-0.07100003], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.22885628],
#        [-0.05056399]], dtype=float32), array([-0.07600003], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.2233517 ],
#        [-0.04116298]], dtype=float32), array([-0.07400004], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.21694723],
#        [-0.03276215]], dtype=float32), array([-0.07200004], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.22734289],
#        [-0.0514615 ]], dtype=float32), array([-0.07600004], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.23253834],
#        [-0.05576047]], dtype=float32), array([-0.07800004], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.2282337 ],
#        [-0.05115935]], dtype=float32), array([-0.07700004], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.22602913],
#        [-0.05835833]], dtype=float32), array([-0.07700004], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.2501246 ],
#        [-0.08445716]], dtype=float32), array([-0.08500004], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.2403196 ],
#        [-0.07335547]], dtype=float32), array([-0.08200004], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.7198 - categorical_accuracy: 1.0000
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.23351479],
#        [-0.066254  ]], dtype=float32), array([-0.08000004], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.23211011],
#        [-0.05605268]], dtype=float32), array([-0.07900004], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22550547],
#        [-0.04535156]], dtype=float32), array([-0.07700004], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 526us/step - loss: 0.6998 - categorical_accuracy: 1.0000
# Epoch 7/40
#
#  w 0 :
#  [array([[-0.23970096],
#        [-0.05125065]], dtype=float32), array([-0.08100004], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.7977 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23619616],
#        [-0.05014962]], dtype=float32), array([-0.08000004], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22329144],
#        [-0.03074862]], dtype=float32), array([-0.07600004], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23738697],
#        [-0.04364801]], dtype=float32), array([-0.08100004], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23188223],
#        [-0.03424714]], dtype=float32), array([-0.07900005], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.22547759],
#        [-0.02584645]], dtype=float32), array([-0.07700005], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.23587307],
#        [-0.04454594]], dtype=float32), array([-0.08100005], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24106835],
#        [-0.04884505]], dtype=float32), array([-0.08300005], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23676352],
#        [-0.04424407]], dtype=float32), array([-0.08200005], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.23455879],
#        [-0.05144319]], dtype=float32), array([-0.08200005], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.2586541 ],
#        [-0.07754216]], dtype=float32), array([-0.09000005], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.7459 - categorical_accuracy: 1.0000
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.24884892],
#        [-0.0664406 ]], dtype=float32), array([-0.08700005], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.24204394],
#        [-0.05933928]], dtype=float32), array([-0.08500005], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.2406391 ],
#        [-0.04913809]], dtype=float32), array([-0.08400005], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.2340343 ],
#        [-0.03843711]], dtype=float32), array([-0.08200005], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 536us/step - loss: 0.6989 - categorical_accuracy: 1.0000
# Epoch 8/40
#
#  w 0 :
#  [array([[-0.2510296 ],
#        [-0.05103634]], dtype=float32), array([-0.08700006], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8072 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.24202459],
#        [-0.04023532]], dtype=float32), array([-0.08400006], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.23201975],
#        [-0.02553451]], dtype=float32), array([-0.08100006], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.24231511],
#        [-0.036934  ]], dtype=float32), array([-0.08500006], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23681027],
#        [-0.02753326]], dtype=float32), array([-0.08300006], dtype=float32)]
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.23340553],
#        [-0.02573271]], dtype=float32), array([-0.08200006], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.24380086],
#        [-0.0444322 ]], dtype=float32), array([-0.08600006], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24549599],
#        [-0.04733131]], dtype=float32), array([-0.08700006], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23839109],
#        [-0.03793036]], dtype=float32), array([-0.08500007], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.7878 - categorical_accuracy: 1.0000
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.24528632],
#        [-0.0594296 ]], dtype=float32), array([-0.08800007], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.2504814 ],
#        [-0.06762841]], dtype=float32), array([-0.09000006], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.24067639],
#        [-0.05652706]], dtype=float32), array([-0.08700006], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.23637158],
#        [-0.05442593]], dtype=float32), array([-0.08600006], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.23496684],
#        [-0.04422484]], dtype=float32), array([-0.08500006], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.23136215],
#        [-0.03812396]], dtype=float32), array([-0.08400006], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 618us/step - loss: 0.6935 - categorical_accuracy: 1.0000
# Epoch 9/40
#
#  w 0 :
#  [array([[-0.25135753],
#        [-0.0565232 ]], dtype=float32), array([-0.09000006], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8143 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.2423525 ],
#        [-0.04572207]], dtype=float32), array([-0.08700006], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22944765],
#        [-0.02632115]], dtype=float32), array([-0.08300006], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.24354306],
#        [-0.03922063]], dtype=float32), array([-0.08800006], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23803818],
#        [-0.02981984]], dtype=float32), array([-0.08600006], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.23463342],
#        [-0.02801925]], dtype=float32), array([-0.08500006], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.24502872],
#        [-0.04671869]], dtype=float32), array([-0.08900006], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24672382],
#        [-0.04961775]], dtype=float32), array([-0.09000006], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23331888],
#        [-0.03451676]], dtype=float32), array([-0.08600006], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.24341421],
#        [-0.06081607]], dtype=float32), array([-0.09000006], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.7127 - categorical_accuracy: 1.0000
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24590933],
#        [-0.06481485]], dtype=float32), array([-0.09100007], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.23610441],
#        [-0.05371356]], dtype=float32), array([-0.08800007], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.2344997 ],
#        [-0.05651248]], dtype=float32), array([-0.08800007], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.233095  ],
#        [-0.04631135]], dtype=float32), array([-0.08700006], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22949034],
#        [-0.04021043]], dtype=float32), array([-0.08600006], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 585us/step - loss: 0.6951 - categorical_accuracy: 1.0000
# Epoch 10/40
#
#  w 0 :
#  [array([[-0.24648575],
#        [-0.05280962]], dtype=float32), array([-0.09100007], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8062 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23748082],
#        [-0.04200856]], dtype=float32), array([-0.08800007], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22747608],
#        [-0.02730772]], dtype=float32), array([-0.08500007], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.24157153],
#        [-0.04020718]], dtype=float32), array([-0.09000007], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.2360667 ],
#        [-0.03080637]], dtype=float32), array([-0.08800007], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.23266198],
#        [-0.02900576]], dtype=float32), array([-0.08700007], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.24305733],
#        [-0.04770518]], dtype=float32), array([-0.09100007], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24475247],
#        [-0.05060423]], dtype=float32), array([-0.09200007], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23134758],
#        [-0.03550322]], dtype=float32), array([-0.08800007], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.24144295],
#        [-0.06180251]], dtype=float32), array([-0.09200007], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24393812],
#        [-0.06580127]], dtype=float32), array([-0.09300008], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.23413324],
#        [-0.05469996]], dtype=float32), array([-0.09000008], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.7141 - categorical_accuracy: 1.0000
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.23252857],
#        [-0.05749886]], dtype=float32), array([-0.09000008], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.23112392],
#        [-0.04729772]], dtype=float32), array([-0.08900008], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.2275193 ],
#        [-0.04119677]], dtype=float32), array([-0.08800007], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 461us/step - loss: 0.6938 - categorical_accuracy: 1.0000
# Epoch 11/40
#
#  w 0 :
#  [array([[-0.24171476],
#        [-0.04709595]], dtype=float32), array([-0.09200007], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.7990 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23820993],
#        [-0.045995  ]], dtype=float32), array([-0.09100007], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22820517],
#        [-0.03129409]], dtype=float32), array([-0.08800007], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23850061],
#        [-0.04269346]], dtype=float32), array([-0.09200007], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23299584],
#        [-0.03329261]], dtype=float32), array([-0.09000008], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.22659118],
#        [-0.02489194]], dtype=float32), array([-0.08800008], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.23698665],
#        [-0.04359144]], dtype=float32), array([-0.09200008], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24218191],
#        [-0.04789057]], dtype=float32), array([-0.09400008], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23507707],
#        [-0.03848961]], dtype=float32), array([-0.09200008], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.24197237],
#        [-0.05998884]], dtype=float32), array([-0.09500008], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.7103 - categorical_accuracy: 1.0000
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24446753],
#        [-0.06398764]], dtype=float32), array([-0.09600008], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.23466264],
#        [-0.05288636]], dtype=float32), array([-0.09300008], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.23305795],
#        [-0.0556853 ]], dtype=float32), array([-0.09300008], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.23165329],
#        [-0.04548419]], dtype=float32), array([-0.09200008], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22804865],
#        [-0.03938328]], dtype=float32), array([-0.09100008], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 615us/step - loss: 0.6934 - categorical_accuracy: 1.0000
# Epoch 12/40
#
#  w 0 :
#  [array([[-0.2450441],
#        [-0.0519825]], dtype=float32), array([-0.09600008], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8055 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23603919],
#        [-0.04118146]], dtype=float32), array([-0.09300008], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22603448],
#        [-0.02648063]], dtype=float32), array([-0.09000009], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.24012996],
#        [-0.0393801 ]], dtype=float32), array([-0.09500009], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23462516],
#        [-0.02997932]], dtype=float32), array([-0.09300009], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.23122047],
#        [-0.02817872]], dtype=float32), array([-0.09200009], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.24161585],
#        [-0.04687816]], dtype=float32), array([-0.09600009], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24331102],
#        [-0.04977722]], dtype=float32), array([-0.09700009], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23330615],
#        [-0.03617622]], dtype=float32), array([-0.09400009], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.24020149],
#        [-0.0576755 ]], dtype=float32), array([-0.09700009], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.7103 - categorical_accuracy: 1.0000
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24539669],
#        [-0.06587435]], dtype=float32), array([-0.09900009], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.23559178],
#        [-0.05477304]], dtype=float32), array([-0.09600009], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.23128708],
#        [-0.05267194]], dtype=float32), array([-0.09500009], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.22988245],
#        [-0.04247089]], dtype=float32), array([-0.09400009], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22627786],
#        [-0.03637004]], dtype=float32), array([-0.09300008], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 610us/step - loss: 0.6939 - categorical_accuracy: 1.0000
# Epoch 13/40
#
#  w 0 :
#  [array([[-0.24927333],
#        [-0.06066931]], dtype=float32), array([-0.10000008], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8199 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.24026835],
#        [-0.0498681 ]], dtype=float32), array([-0.09700008], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22736354],
#        [-0.0304671 ]], dtype=float32), array([-0.09300008], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23765899],
#        [-0.04186649]], dtype=float32), array([-0.09700008], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23215424],
#        [-0.03246565]], dtype=float32), array([-0.09500009], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.2257496],
#        [-0.024065 ]], dtype=float32), array([-0.09300009], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.23614508],
#        [-0.04276452]], dtype=float32), array([-0.09700009], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24134035],
#        [-0.04706367]], dtype=float32), array([-0.09900009], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23423553],
#        [-0.03766273]], dtype=float32), array([-0.09700009], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.24113084],
#        [-0.05916197]], dtype=float32), array([-0.10000009], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.7136 - categorical_accuracy: 1.0000
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24632601],
#        [-0.06736079]], dtype=float32), array([-0.10200009], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.2365211 ],
#        [-0.05625944]], dtype=float32), array([-0.09900009], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.23221636],
#        [-0.05415832]], dtype=float32), array([-0.09800009], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.23081172],
#        [-0.04395723]], dtype=float32), array([-0.09700008], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.2272071 ],
#        [-0.03785636]], dtype=float32), array([-0.09600008], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 591us/step - loss: 0.6962 - categorical_accuracy: 1.0000
# Epoch 14/40
#
#  w 0 :
#  [array([[-0.24720255],
#        [-0.0562556 ]], dtype=float32), array([-0.10200008], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8139 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.2381976 ],
#        [-0.04545447]], dtype=float32), array([-0.09900008], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22529283],
#        [-0.02605356]], dtype=float32), array([-0.09500008], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23938833],
#        [-0.03895304]], dtype=float32), array([-0.10000008], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23388354],
#        [-0.02955227]], dtype=float32), array([-0.09800009], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.23047887],
#        [-0.02775167]], dtype=float32), array([-0.09700008], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.24087426],
#        [-0.04645112]], dtype=float32), array([-0.10100009], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24256945],
#        [-0.04935019]], dtype=float32), array([-0.10200009], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.2291646],
#        [-0.0342492]], dtype=float32), array([-0.09800009], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.23926002],
#        [-0.06054852]], dtype=float32), array([-0.10200009], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24175523],
#        [-0.06454731]], dtype=float32), array([-0.10300009], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.2319504 ],
#        [-0.05344602]], dtype=float32), array([-0.10000009], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.7155 - categorical_accuracy: 1.0000
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.23034576],
#        [-0.05624495]], dtype=float32), array([-0.10000009], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.22894114],
#        [-0.04604382]], dtype=float32), array([-0.09900009], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22533657],
#        [-0.0399429 ]], dtype=float32), array([-0.09800009], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 461us/step - loss: 0.6949 - categorical_accuracy: 1.0000
# Epoch 15/40
#
#  w 0 :
#  [array([[-0.24233206],
#        [-0.0525421 ]], dtype=float32), array([-0.10300009], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8058 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23332721],
#        [-0.04174105]], dtype=float32), array([-0.10000009], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22332254],
#        [-0.02704021]], dtype=float32), array([-0.09700009], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23741807],
#        [-0.03993967]], dtype=float32), array([-0.10200009], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23191333],
#        [-0.03053887]], dtype=float32), array([-0.1000001], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.2285087 ],
#        [-0.02873826]], dtype=float32), array([-0.0990001], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.23890412],
#        [-0.04743769]], dtype=float32), array([-0.1030001], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24059933],
#        [-0.05033674]], dtype=float32), array([-0.1040001], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23059452],
#        [-0.03673574]], dtype=float32), array([-0.1010001], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.23748991],
#        [-0.058235  ]], dtype=float32), array([-0.1040001], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24268515],
#        [-0.06643384]], dtype=float32), array([-0.1060001], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.7403 - categorical_accuracy: 1.0000
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.2328803 ],
#        [-0.05533251]], dtype=float32), array([-0.1030001], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.22857563],
#        [-0.0532314 ]], dtype=float32), array([-0.10200009], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.23077106],
#        [-0.04443034]], dtype=float32), array([-0.10200009], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22716644],
#        [-0.03832945]], dtype=float32), array([-0.10100009], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 541us/step - loss: 0.6932 - categorical_accuracy: 1.0000
# Epoch 16/40
#
#  w 0 :
#  [array([[-0.2441619 ],
#        [-0.05092868]], dtype=float32), array([-0.1060001], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8066 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23515701],
#        [-0.04012766]], dtype=float32), array([-0.1030001], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22515231],
#        [-0.02542686]], dtype=float32), array([-0.1000001], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23924781],
#        [-0.03832635]], dtype=float32), array([-0.1050001], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23374303],
#        [-0.02892559]], dtype=float32), array([-0.1030001], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.23033835],
#        [-0.02712501]], dtype=float32), array([-0.1020001], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.24073374],
#        [-0.04582447]], dtype=float32), array([-0.1060001], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24242893],
#        [-0.04872355]], dtype=float32), array([-0.10700011], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.22902408],
#        [-0.03362258]], dtype=float32), array([-0.1030001], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.2391195 ],
#        [-0.05992191]], dtype=float32), array([-0.10700011], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.7105 - categorical_accuracy: 1.0000
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24161471],
#        [-0.06392071]], dtype=float32), array([-0.10800011], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.23180988],
#        [-0.05281943]], dtype=float32), array([-0.10500011], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.23020525],
#        [-0.05561838]], dtype=float32), array([-0.10500011], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.22880065],
#        [-0.04541726]], dtype=float32), array([-0.10400011], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22519608],
#        [-0.03931636]], dtype=float32), array([-0.1030001], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 578us/step - loss: 0.6936 - categorical_accuracy: 1.0000
# Epoch 17/40
#
#  w 0 :
#  [array([[-0.24219158],
#        [-0.05191557]], dtype=float32), array([-0.10800011], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8065 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23318674],
#        [-0.04111453]], dtype=float32), array([-0.10500011], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22318207],
#        [-0.02641371]], dtype=float32), array([-0.10200011], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.2372776 ],
#        [-0.03931318]], dtype=float32), array([-0.10700011], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23177285],
#        [-0.0299124 ]], dtype=float32), array([-0.10500012], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.22836822],
#        [-0.0281118 ]], dtype=float32), array([-0.10400011], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.23876366],
#        [-0.04681124]], dtype=float32), array([-0.10800011], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.24045889],
#        [-0.0497103 ]], dtype=float32), array([-0.10900012], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.22705407],
#        [-0.0346093 ]], dtype=float32), array([-0.10500012], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.23714954],
#        [-0.06090861]], dtype=float32), array([-0.10900012], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.2396448 ],
#        [-0.06490739]], dtype=float32), array([-0.11000012], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.7403 - categorical_accuracy: 1.0000
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.22984001],
#        [-0.0538061 ]], dtype=float32), array([-0.10700012], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.22823541],
#        [-0.05660502]], dtype=float32), array([-0.10700012], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.22683084],
#        [-0.04640388]], dtype=float32), array([-0.10600012], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22322631],
#        [-0.04030296]], dtype=float32), array([-0.10500012], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 539us/step - loss: 0.6936 - categorical_accuracy: 1.0000
# Epoch 18/40
#
#  w 0 :
#  [array([[-0.23742184],
#        [-0.04620215]], dtype=float32), array([-0.10900012], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.7991 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23391709],
#        [-0.04510123]], dtype=float32), array([-0.10800011], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.2239124 ],
#        [-0.03040033]], dtype=float32), array([-0.10500012], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23420793],
#        [-0.04179972]], dtype=float32), array([-0.10900012], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.22870325],
#        [-0.03239888]], dtype=float32), array([-0.10700012], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.22229867],
#        [-0.02399823]], dtype=float32), array([-0.10500012], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.23269422],
#        [-0.04269776]], dtype=float32), array([-0.10900012], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.23788957],
#        [-0.0469969 ]], dtype=float32), array([-0.11100012], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.23078482],
#        [-0.03759596]], dtype=float32), array([-0.10900012], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.7881 - categorical_accuracy: 1.0000
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.2376802 ],
#        [-0.05909521]], dtype=float32), array([-0.11200012], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24017544],
#        [-0.06309403]], dtype=float32), array([-0.11300012], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.23037064],
#        [-0.05199277]], dtype=float32), array([-0.11000013], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.22876604],
#        [-0.05479173]], dtype=float32), array([-0.11000013], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.22736147],
#        [-0.04459063]], dtype=float32), array([-0.10900012], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22375692],
#        [-0.03848974]], dtype=float32), array([-0.10800012], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 644us/step - loss: 0.6931 - categorical_accuracy: 1.0000
# Epoch 19/40
#
#  w 0 :
#  [array([[-0.24075244],
#        [-0.05108897]], dtype=float32), array([-0.11300012], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8058 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23174763],
#        [-0.04028795]], dtype=float32), array([-0.11000013], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22174299],
#        [-0.02558714]], dtype=float32), array([-0.10700013], dtype=float32)]
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23583855],
#        [-0.03848663]], dtype=float32), array([-0.11200013], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.23033383],
#        [-0.02908586]], dtype=float32), array([-0.11000013], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.22692923],
#        [-0.02728528]], dtype=float32), array([-0.10900013], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.2373247 ],
#        [-0.04598473]], dtype=float32), array([-0.11300013], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.23901996],
#        [-0.04888381]], dtype=float32), array([-0.11400013], dtype=float32)]
#
#  80/150 [===============>..............] - ETA: 0s - loss: 0.8072 - categorical_accuracy: 1.0000
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.22901517],
#        [-0.03528284]], dtype=float32), array([-0.11100014], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.2359106 ],
#        [-0.05678213]], dtype=float32), array([-0.11400013], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.24110587],
#        [-0.06498099]], dtype=float32), array([-0.11600013], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.23130105],
#        [-0.05387969]], dtype=float32), array([-0.11300013], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.22699642],
#        [-0.05177861]], dtype=float32), array([-0.11200013], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.22559188],
#        [-0.04157758]], dtype=float32), array([-0.11100013], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.22198737],
#        [-0.03547674]], dtype=float32), array([-0.11000013], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 713us/step - loss: 0.6936 - categorical_accuracy: 1.0000
# Epoch 20/40
#
#  w 0 :
#  [array([[-0.24498293],
#        [-0.05977603]], dtype=float32), array([-0.11700013], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8202 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23597802],
#        [-0.04897483]], dtype=float32), array([-0.11400013], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.2230733 ],
#        [-0.02957386]], dtype=float32), array([-0.11000013], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.23336884],
#        [-0.04097326]], dtype=float32), array([-0.11400013], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.22786418],
#        [-0.03157245]], dtype=float32), array([-0.11200013], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.22145961],
#        [-0.02317182]], dtype=float32), array([-0.11000013], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.23185518],
#        [-0.04187135]], dtype=float32), array([-0.11400013], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.23705055],
#        [-0.04617052]], dtype=float32), array([-0.11600013], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.22994581],
#        [-0.03676959]], dtype=float32), array([-0.11400013], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.2368412 ],
#        [-0.05826886]], dtype=float32), array([-0.11700013], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.7132 - categorical_accuracy: 1.0000
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.23933646],
#        [-0.06226769]], dtype=float32), array([-0.11800013], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.22953168],
#        [-0.05116645]], dtype=float32), array([-0.11500014], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 12 :
#  [array([[-0.22792709],
#        [-0.05396543]], dtype=float32), array([-0.11500014], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 13 :
#  [array([[-0.22652254],
#        [-0.04376435]], dtype=float32), array([-0.11400013], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 14 :
#  [array([[-0.222918  ],
#        [-0.03766347]], dtype=float32), array([-0.11300013], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
# 150/150 [==============================] - 0s 588us/step - loss: 0.6953 - categorical_accuracy: 1.0000
# Epoch 21/40
#
#  w 0 :
#  [array([[-0.23991355],
#        [-0.05026272]], dtype=float32), array([-0.11800013], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8057 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[-0.23090875],
#        [-0.03946171]], dtype=float32), array([-0.11500014], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[-0.22090413],
#        [-0.02476092]], dtype=float32), array([-0.11200014], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[-0.2349997 ],
#        [-0.03766043]], dtype=float32), array([-0.11700014], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[-0.229495  ],
#        [-0.02825968]], dtype=float32), array([-0.11500014], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 5 :
#  [array([[-0.22609042],
#        [-0.02645911]], dtype=float32), array([-0.11400014], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 6 :
#  [array([[-0.2364859 ],
#        [-0.04515858]], dtype=float32), array([-0.11800014], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 7 :
#  [array([[-0.23818117],
#        [-0.04805768]], dtype=float32), array([-0.11900014], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 8 :
#  [array([[-0.2247764 ],
#        [-0.03295672]], dtype=float32), array([-0.11500014], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 9 :
#  [array([[-0.23487191],
#        [-0.05925606]], dtype=float32), array([-0.11900014], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 10 :
#  [array([[-0.23736721],
#        [-0.06325488]], dtype=float32), array([-0.12000015], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 11 :
#  [array([[-0.22756247],
#        [-0.05215361]], dtype=float32), array([-0.11700015], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.7136 - categorical_accuracy: 1.0000
#  z:  [3.  5.1] y:  -1
#
# ...
#        [-0.87489086]], dtype=float32), array([0.05300602], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.76163185],
#        [-0.87446713]], dtype=float32), array([0.05331852], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 222us/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 133/150
#
#  w 0 :
#  [array([[ 0.7616166],
#        [-0.8744497]], dtype=float32), array([0.05331852], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0019 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.76266384],
#        [-0.8738384 ]], dtype=float32), array([0.05363102], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7611486],
#        [-0.8764147]], dtype=float32), array([0.05300602], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.7611334],
#        [-0.8763972]], dtype=float32), array([0.05300602], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7618369],
#        [-0.8759734]], dtype=float32), array([0.05331852], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 311us/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 134/150
#
#  w 0 :
#  [array([[ 0.7618216],
#        [-0.8759559]], dtype=float32), array([0.05331852], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0020 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.7628689 ],
#        [-0.87534463]], dtype=float32), array([0.05363102], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7621036 ],
#        [-0.87688965]], dtype=float32), array([0.05331852], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.76208836],
#        [-0.8768721 ]], dtype=float32), array([0.05331852], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7627919 ],
#        [-0.87644833]], dtype=float32), array([0.05363102], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 245us/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 135/150
#
#  w 0 :
#  [array([[ 0.7627766],
#        [-0.8764308]], dtype=float32), array([0.05363102], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0019 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.76382387],
#        [-0.8758195 ]], dtype=float32), array([0.05394352], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7630586],
#        [-0.8773645]], dtype=float32), array([0.05363102], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.76304334],
#        [-0.877347  ]], dtype=float32), array([0.05363102], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.76374686],
#        [-0.8769232 ]], dtype=float32), array([0.05394352], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 182us/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 136/150
#
#  w 0 :
#  [array([[ 0.7637316],
#        [-0.8769057]], dtype=float32), array([0.05394352], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0018 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.76477885],
#        [-0.8762944 ]], dtype=float32), array([0.05425602], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7640135],
#        [-0.8778393]], dtype=float32), array([0.05394352], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.76399827],
#        [-0.87782174]], dtype=float32), array([0.05394352], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7647017 ],
#        [-0.87739795]], dtype=float32), array([0.05425602], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 223us/step - loss: 0.0070 - categorical_accuracy: 1.0000
# Epoch 137/150
#
#  w 0 :
#  [array([[ 0.7646864 ],
#        [-0.87738043]], dtype=float32), array([0.05425602], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0018 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.7657336],
#        [-0.8767691]], dtype=float32), array([0.05456852], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7649683],
#        [-0.8783141]], dtype=float32), array([0.05425602], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.76495296],
#        [-0.8782965 ]], dtype=float32), array([0.05425602], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7656564],
#        [-0.8778727]], dtype=float32), array([0.05456852], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 266us/step - loss: 0.0070 - categorical_accuracy: 1.0000
# Epoch 138/150
#
#  w 0 :
#  [array([[ 0.7656411],
#        [-0.8778551]], dtype=float32), array([0.05456852], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0017 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.7666883],
#        [-0.8772438]], dtype=float32), array([0.05488102], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.76517296],
#        [-0.87982005]], dtype=float32), array([0.05425602], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.76515764],
#        [-0.87980247]], dtype=float32), array([0.05425602], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7658611],
#        [-0.8793786]], dtype=float32), array([0.05456852], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 261us/step - loss: 0.0070 - categorical_accuracy: 1.0000
# Epoch 139/150
#
#  w 0 :
#  [array([[ 0.7658458 ],
#        [-0.87936103]], dtype=float32), array([0.05456852], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0017 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.76689297],
#        [-0.87874967]], dtype=float32), array([0.05488102], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.76612765],
#        [-0.8802946 ]], dtype=float32), array([0.05456852], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.7661123 ],
#        [-0.88027704]], dtype=float32), array([0.05456852], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7668158],
#        [-0.8798532]], dtype=float32), array([0.05488102], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 197us/step - loss: 0.0070 - categorical_accuracy: 1.0000
# Epoch 140/150
#
#  w 0 :
#  [array([[ 0.76680046],
#        [-0.8798356 ]], dtype=float32), array([0.05488102], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0017 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.7678476 ],
#        [-0.87922424]], dtype=float32), array([0.05519352], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7670822 ],
#        [-0.88076913]], dtype=float32), array([0.05488102], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.7670669],
#        [-0.8807515]], dtype=float32), array([0.05488102], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7677703 ],
#        [-0.88032764]], dtype=float32), array([0.05519352], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 216us/step - loss: 0.0069 - categorical_accuracy: 1.0000
# Epoch 141/150
#
#  w 0 :
#  [array([[ 0.7677549 ],
#        [-0.88031006]], dtype=float32), array([0.05519352], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0016 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.76880205],
#        [-0.8796987 ]], dtype=float32), array([0.05550602], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.76803666],
#        [-0.8812436 ]], dtype=float32), array([0.05519352], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.7680213 ],
#        [-0.88122594]], dtype=float32), array([0.05519352], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7687247],
#        [-0.8808021]], dtype=float32), array([0.05550602], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 205us/step - loss: 0.0069 - categorical_accuracy: 1.0000
# Epoch 142/150
#
#  w 0 :
#  [array([[ 0.7687093 ],
#        [-0.88078445]], dtype=float32), array([0.05550602], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0015 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.76975644],
#        [-0.8801731 ]], dtype=float32), array([0.05581852], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#  w 2 :
#  [array([[ 0.76899105],
#        [-0.881718  ]], dtype=float32), array([0.05550602], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.7689757 ],
#        [-0.88170034]], dtype=float32), array([0.05550602], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.76967907],
#        [-0.8812764 ]], dtype=float32), array([0.05581852], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 250us/step - loss: 0.0069 - categorical_accuracy: 1.0000
# Epoch 143/150
#
#  w 0 :
#  [array([[ 0.7696637],
#        [-0.8812588]], dtype=float32), array([0.05581852], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.7707108],
#        [-0.8806474]], dtype=float32), array([0.05613102], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7699454],
#        [-0.8821923]], dtype=float32), array([0.05581852], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.76993  ],
#        [-0.8821747]], dtype=float32), array([0.05581852], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.77063334],
#        [-0.88175076]], dtype=float32), array([0.05613102], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 218us/step - loss: 0.0069 - categorical_accuracy: 1.0000
# Epoch 144/150
#
#  w 0 :
#  [array([[ 0.7706179],
#        [-0.8817331]], dtype=float32), array([0.05613102], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.77060246],
#        [-0.8817155 ]], dtype=float32), array([0.05613102], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7698371 ],
#        [-0.88326037]], dtype=float32), array([0.05581852], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.7698217],
#        [-0.8832427]], dtype=float32), array([0.05581852], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.77052504],
#        [-0.8828188 ]], dtype=float32), array([0.05613102], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 241us/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 145/150
#
#  w 0 :
#  [array([[ 0.7705096],
#        [-0.8828012]], dtype=float32), array([0.05613102], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.7715567 ],
#        [-0.88218975]], dtype=float32), array([0.05644352], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.77079123],
#        [-0.8837346 ]], dtype=float32), array([0.05613102], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.7707758],
#        [-0.8837169]], dtype=float32), array([0.05613102], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7714791],
#        [-0.883293 ]], dtype=float32), array([0.05644352], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 239us/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 146/150
#
#  w 0 :
#  [array([[ 0.7714637 ],
#        [-0.88327533]], dtype=float32), array([0.05644352], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.77144825],
#        [-0.8832577 ]], dtype=float32), array([0.05644352], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7706828],
#        [-0.8848025]], dtype=float32), array([0.05613102], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.7706674],
#        [-0.8847848]], dtype=float32), array([0.05613102], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7713707 ],
#        [-0.88436085]], dtype=float32), array([0.05644352], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 199us/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 147/150
#
#  w 0 :
#  [array([[ 0.7713553 ],
#        [-0.88434315]], dtype=float32), array([0.05644352], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.77240235],
#        [-0.8837317 ]], dtype=float32), array([0.05675602], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7716369 ],
#        [-0.88527656]], dtype=float32), array([0.05644352], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.77162147],
#        [-0.88525885]], dtype=float32), array([0.05644352], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7723248],
#        [-0.8848349]], dtype=float32), array([0.05675602], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 252us/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 148/150
#
#  w 0 :
#  [array([[ 0.77230936],
#        [-0.8848172 ]], dtype=float32), array([0.05675602], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.7722939],
#        [-0.8847995]], dtype=float32), array([0.05675602], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7715285],
#        [-0.8863443]], dtype=float32), array([0.05644352], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.77151304],
#        [-0.8863266 ]], dtype=float32), array([0.05644352], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7722164 ],
#        [-0.88590264]], dtype=float32), array([0.05675602], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 216us/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 149/150
#
#  w 0 :
#  [array([[ 0.77220094],
#        [-0.88588494]], dtype=float32), array([0.05675602], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.773248  ],
#        [-0.88527346]], dtype=float32), array([0.05706852], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7724826 ],
#        [-0.88681823]], dtype=float32), array([0.05675602], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.77246714],
#        [-0.88680047]], dtype=float32), array([0.05675602], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.7731704],
#        [-0.8863765]], dtype=float32), array([0.05706852], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 226us/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 150/150
#
#  w 0 :
#  [array([[ 0.773155 ],
#        [-0.8863588]], dtype=float32), array([0.05706852], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000
#  z:  [3.1 5.5] y:  -1
#
#  w 1 :
#  [array([[ 0.77313954],
#        [-0.8863411 ]], dtype=float32), array([0.05706852], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 2 :
#  [array([[ 0.7723741 ],
#        [-0.88788587]], dtype=float32), array([0.05675602], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 3 :
#  [array([[ 0.77235866],
#        [-0.8878681 ]], dtype=float32), array([0.05675602], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 4 :
#  [array([[ 0.77306193],
#        [-0.8874441 ]], dtype=float32), array([0.05706852], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
# 150/150 [==============================] - 0s 214us/step - loss: 0.0067 - categorical_accuracy: 1.0000

# %% [markdown]
# As expected, after calling the CALL BACKS, our algorithm looks way better.
