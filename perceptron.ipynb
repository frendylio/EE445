# %% [markdown]
# In this assignment, we will learn how to build simple neural networks. We will build the three basic blocks we learnt in class: the perceptron, the LinearRegression classifier (Fisher discriminant) and the Support Vector Machine. All these three are just one-neuron "networks". In each case, we train the neuron (ie set the weights) by minimizing a different kind of loss function. Specifically:
# 1. Perceptron: activation is linear, train by minimizing the ramp loss = max(0, -y_true* y_predicted)
# 2. Fisher Discriminant: activation is linear, train by minimizing square loss (y_true - y_predicted)^2
# 3. Support vector machine: activation is linear (for now). We train by minimizing the hinge loss = max(0, 1- y_true* y_predicted), but to the hinge loss, we add a (1/C)||w||^2 term, where C is some constant. In machine learning parlance, adding a ||w||^2 term to the loss is called l2 regularization. So this is a single neuron, linear activation, trained using hinge loss with l2 regularization.
#
# This assignment will build all three neurons. Rather than code each one from scratch, we are going to use off-the-shelf components from keras, and use gradient descent to learn the weights. To help you, I have simulated the one neuron network that simulates the perceptron completely (and as you can see, it does separate linearly separable data by running enough epochs).
#
# In the code below, every component of keras is stripped down to its bare essentials, so we know what is happening. We will learn to add back the more complicated parts later.

# %%
import numpy as np


import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# A good linearly separable dataset is the IRIS dataset (contains dimensions of various flowers, the task is to classify the type of flower). It has a nice backstory as well.

# %%
from sklearn import datasets

iris = datasets.load_iris()

# let us check what has been loaded
print(dir(iris))
# a short description
print(iris.DESCR)
print(iris.target_names)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target', 'target_names']
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# Let us visualize the dataset, after all there are only 4 features. Let us plot all examples in the space of the first three features. Based on the class (0,1,2---corresponding to setosa, versicolor and virginica respectively), we assign a different color. The darkest dots are the setosa examples, the green ones are versicolor and the yellow ones are virginica (compare with the colorbar at 0, 1 and 2, I am a little colorblind myself).

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

fig = plt.figure()
ax = plt.axes(projection='3d')
figiris = ax.scatter(iris.data[:,0],iris.data[:,1],iris.data[:,2],c=iris.target)
ax.set_xlabel(iris.feature_names[0]+' (0)')
ax.set_ylabel(iris.feature_names[1]+' (1)')
ax.set_zlabel(iris.feature_names[2]+' (2)')

# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)


plt.colorbar(figiris)
ax.view_init(45,45)

# %% [markdown]
# Choosing sepal width (feature 1) against petal length (feature 2) seems to yield linearly separable points if we want to classify the setosia (label 0) examples against all the other examples. Let us double check that.

# %%
fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 0, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')

# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)

# %% [markdown]
# Sure enough it works. Let us train a perceptron with this data. Our training data are features 1 and 2, label is 1 if setosia, -1 else. A perceptron is a neural network with 1 layer, 1 node, linear activation function, and the ramp loss we discussed in class. Its inputs are weight two vectors (features 1 and 2).
#
# We could implement the perceptron algorithm as a loop of course. But we have a better way: to do this in keras. keras allows us to build a wide variety of networks either by simply building them layer by layer (Sequential) or as arbitrary graphs (we will worry about this later).
#
# With the perceptron,
# 1. The topology is trivial---just a single layer with one neuron
# 2. The input here has dimension 2 (feature 1 and 2)
#
# Let us first put that into keras. keras also wants to know what activation function to use. To understand the activation function, recall that the neuron computes the dot product between the example and its weights. The activation function is applied to the dot product.
#
# When we learnt about this topic, we initially used the sign activation function (label was the sign of the dot product). But doing so yielded a loss terrain with plateaus at different heights (run the old demo again if you do not remember). It is difficult to figure out which direction to move while doing gradient descent, so we shifted to the ramp loss instead. To compute the ramp loss, we just ask the neuron to output the entire dot product---so essentially, we want the activation function to leave the dot product unchanged. The way to do that is to use the linear activation function (f(x)=x).
#
# One additional detail here. In class, we ignored the intercept. Here we will use the intercept---so we will classify using a plane w^T x +b =0 (instead of just planes through the origin, w^T x=0). The keras neuron automatically makes the intercept available.
#
# Conceptually, the intercept is not a big deal---we just pretend that the weights in the neuron are the coefficients of the input coordinates and the intercept b. So here, since the input has dimension 2, we have two coefficients and one intercept---bringing the number of tunable weights to be 3. We also pretend that every example is actually a vector with 3 coordinates, the first two coordinates are the ones given to us and the last coordinate is simply 1. Then w^T z +b = (w,b)^T(z,1), so we have reduced it to a case without an intercept (albeit by adding in an additional dummy coordinate).

# %%
# This piece of code defines the perceptron as above. 

perceptron = Sequential([
    Dense(1, input_shape=(2,)),
    Activation('linear'),
])

# %% [markdown]
# Ok, now on to the training algorithm. Recall that we use
# 1. stochastic gradient descent on the
# 2. the ramp loss function
#
# keras has a lot of useful loss functions built in, but the ramp loss is not one of them (though the hinge loss is). We will just write the function out here. Unfortunately, here there is a catch---we cannot use the extensive numpy libraries (though it is ok to pass numpy arrays here). Instead we have to use the tensorflow functions, which can sometimes be a little clumsy and eschews lot of automatic type conversions (because it is built for speed, not convenience always). That is why we explicity convert the label to a float below (else we could not multiply in the last line), and note that we write max (0.0, ...) not max (0, ...). This is to indicate that the comparison is a float comparison. If you do not do these things, TensorFlow will complain.
#
# loss functions we define *must* be tensorflow functions, and *always* take in two arguments (y_true and y_pred). y_true is the correct label of the example while y_pred is the output of the neuron (in our case, z\dot w, since we used linear activation).
#
# Finally perceptron training algorithm was vanilla stochastic gradient descent with learning parameter 1. We first pass the name of the algorithm (sgd for stochastic gradient descent, which is built into keras), the loss and what we are interested in achieving on test data (accuracy of classification---categorical accuracy in other words).

# %%
from keras.optimizers import SGD

# the ramp loss we used is not predefined, so we define it ourselves here. The code here is tensorflow
# code as is required. We cannot use numpy code/data types here.

def perceptron_loss(y_true,y_pred):
    tf.cast(y_true, tf.float32)
    return(tf.maximum(0.0,-(y_true)*y_pred))

# We want to do plain vanilla stochastic gradient descent here, nothing fancy. 
# The call below removes all bells and whistles from the keras implementation of stochastic gradient
# descent. We will learn how to add back the momentum and Nesterov acceleration later.

opt = SGD(lr=1,momentum=0,nesterov=False)

# Here we tell the perceptron to use plain vanilla stochastic gradient descent to optimize the perceptron loss defined
# above

perceptron.compile(optimizer=opt, loss=perceptron_loss)

# %% [markdown]
# We set the learning rate to 1 so as to mimic the Perceptron Training Algorithm exactly.

# %% [markdown]
# Now, we prepare the training data by extracting columns 1 and 2 from the data. We want to separate out setosa (original label 0) from the other two classes, so we assign label 1 to setosas (original label 0) and -1 to the other two classes (original labels 1 and 2).

# %%
# Get hold of the training data. We will classify setosas vs the other two. This yields a linear separable data
# that we know the perceptron can handle.

training = iris.data[:,[1,2]]
labels = np.where(iris.target == 0, 1,-1)

n = training.shape[0]

# We shuffle the order of the training examples and labels. Normally
# keras does this automatically. Here, we do it manually and we will
# ask keras not to shuffle. This is so that we can observe the perceptron
# algorithm as it progresses.

from sklearn.utils import shuffle

training, labels = shuffle(training, labels)

# %% [markdown]
# Now we just get keras to train our model, and get the output at the end of the training into w

# %%
from keras.callbacks import LambdaCallback
import keras.backend as K
    
# We initialize weights to something a little away from 0, since the perceptron has 0 loss when the weights are exactly 0
# regardless of input and output. This is because when weights are 0, w^Tz -b = 0^Tz -0 =0, so our prediction is 0. Therefore,
# y_true*y_predicted =0 always. This is not a fatal flaw, it just means we cannot start at 0.

perceptron.layers[0].set_weights([np.array([[0.01],[0.01]]),np.array([0.0])])

# The line below trains the perceptron.
# In the line below, increase the number of epochs till you see the loss become 0. You may need more than one/two epochs.

perceptron.fit(training, labels, epochs=2, batch_size=1, shuffle=False)

# These are weights obtained after training.

w = perceptron.layers[0].get_weights()
# Out:
# Epoch 1/2
# 150/150 [==============================] - 0s 1ms/step - loss: 0.1977
# Epoch 2/2
# 150/150 [==============================] - 0s 994us/step - loss: 0.0000e+00

# %% [markdown]
# Let us plot the separating line. The line is w0 x + w1 y + b=0, or y = -(b+w0 x)/w1

# %%
fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 0, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(w[1][0]+w[0][0,0]*x)/w[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)

# %% [markdown]
# It worked as we expected it to! We want a little more transparency of course. Let us also retrieve the input and weights at the beginning of every example.

# %%
from keras.callbacks import LambdaCallback
import keras.backend as K
    
print_weights = LambdaCallback(on_batch_begin=lambda batch, logs: print('\n w',batch,': \n',perceptron.layers[0].get_weights(),'\n'))
print_examples = LambdaCallback(on_batch_end = lambda batch, logs: print('\n z: ',training[batch,:],'y: ', labels[batch]))

# Again we initialize weights
perceptron.layers[0].set_weights([np.array([[0.01],[0.01]]),np.array([0.0])])
# And start stochastic gradient descent. This time, we print out the weights and examples corresponding to each step of the
# SGD.
perceptron.fit(training, labels, epochs=1, batch_size=1, callbacks = [ print_weights, print_examples ],shuffle=False)
# Out:
# Epoch 1/1
#
#  w 0 :
#  [array([[0.01],
#        [0.01]], dtype=float32), array([0.], dtype=float32)]
#
#   1/150 [..............................] - ETA: 0s - loss: 0.0000e+00
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[0.01],
#        [0.01]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-2.89     ],
#        [-4.6899996]], dtype=float32), array([-1.], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-2.89     ],
#        [-4.6899996]], dtype=float32), array([-1.], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.30999994],
#        [-3.3899996 ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[ 3.4099998],
#        [-1.8899996]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[ 0.7099998],
#        [-5.79     ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[ 0.7099998],
#        [-5.79     ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[ 0.7099998],
#        [-5.79     ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[ 0.7099998],
#        [-5.79     ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[ 0.7099998],
#        [-5.79     ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[ 0.7099998],
#        [-5.79     ]], dtype=float32), array([0.], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  13/150 [=>............................] - ETA: 0s - loss: 2.2809
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
#
#  w 15 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.2] y:  1
#
#  w 16 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 1.5] y:  1
#
#  w 17 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.2 4. ] y:  -1
#
#  w 18 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.6 6.9] y:  -1
#
#  w 19 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.9 1.7] y:  1
#
#  w 20 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 21 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 5.6] y:  -1
#
#  w 22 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 23 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.6] y:  -1
#
#  w 24 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  25/150 [====>.........................] - ETA: 0s - loss: 1.1861
#  z:  [3.4 1.4] y:  1
#
#  w 25 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  26/150 [====>.........................] - ETA: 0s - loss: 1.1405
#  z:  [3.  4.8] y:  -1
#
#  w 26 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.5] y:  -1
#
#  w 27 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 5.7] y:  -1
#
#  w 28 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 4. ] y:  -1
#
#  w 29 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.3 4. ] y:  -1
#
#  w 30 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 5.1] y:  -1
#
#  w 31 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.4] y:  1
#
#  w 32 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
#
#  w 33 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 5.9] y:  -1
#
#  w 34 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.6] y:  1
#
#  w 35 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 36 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  37/150 [======>.......................] - ETA: 0s - loss: 0.8014
#  z:  [2.8 4.8] y:  -1
#
#  w 37 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 5.6] y:  -1
#
#  w 38 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 39 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 4.4] y:  -1
#
#  w 40 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 5.1] y:  -1
#
#  w 41 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.6 6.1] y:  -1
#
#  w 42 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 3.6] y:  -1
#
#  w 43 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 44 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.5] y:  -1
#
#  w 45 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.1] y:  -1
#
#  w 46 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 5.5] y:  -1
#
#  w 47 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  48/150 [========>.....................] - ETA: 0s - loss: 0.6177
#  z:  [2.2 5. ] y:  -1
#
#  w 48 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.5] y:  1
#
#  w 49 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 5.7] y:  -1
#
#  w 50 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 51 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.1] y:  1
#
#  w 52 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.3] y:  1
#
#  w 53 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 1.6] y:  1
#
#  w 54 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.7] y:  -1
#
#  w 55 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.6] y:  -1
#
#  w 56 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.6] y:  1
#
#  w 57 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.5] y:  -1
#
#  w 58 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.2] y:  -1
#
#  w 59 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  60/150 [===========>..................] - ETA: 0s - loss: 0.4942
#  z:  [3.  5.2] y:  -1
#
#  w 60 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.6 1.4] y:  1
#
#  w 61 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 6.3] y:  -1
#
#  w 62 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 6.7] y:  -1
#
#  w 63 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 5.1] y:  -1
#
#  w 64 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 65 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 5.7] y:  -1
#
#  w 66 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 5.1] y:  -1
#
#  w 67 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 6.7] y:  -1
#
#  w 68 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#  z:  [3.  6.1] y:  -1
#
#  w 69 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.9] y:  -1
#
#  w 70 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  71/150 [=============>................] - ETA: 0s - loss: 0.4176
#  z:  [2.3 1.3] y:  1
#
#  w 71 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 72 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 73 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 3. ] y:  -1
#
#  w 74 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 75 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.3] y:  -1
#
#  w 76 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.3] y:  1
#
#  w 77 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.3 3.3] y:  -1
#
#  w 78 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 4.5] y:  -1
#
#  w 79 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 4.5] y:  -1
#
#  w 80 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 5.8] y:  -1
#
#  w 81 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 82 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  83/150 [===============>..............] - ETA: 0s - loss: 0.3573
#  z:  [2.2 4.5] y:  -1
#
#  w 83 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.1] y:  -1
#
#  w 84 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.6 1. ] y:  1
#
#  w 85 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.5] y:  -1
#
#  w 86 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 6. ] y:  -1
#
#  w 87 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 88 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 5. ] y:  -1
#
#  w 89 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.1] y:  -1
#
#  w 90 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
#
#  w 91 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 6.4] y:  -1
#
#  w 92 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  1.3] y:  1
#
#  w 93 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#  94/150 [=================>............] - ETA: 0s - loss: 0.3154
#  z:  [2.9 4.3] y:  -1
#
#  w 94 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 95 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 1.4] y:  1
#
#  w 96 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
#
#  w 97 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 1.7] y:  1
#
#  w 98 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 99 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.4 3.8] y:  -1
#
#  w 100 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 5. ] y:  -1
#
#  w 101 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 4.9] y:  -1
#
#  w 102 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 103 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 104 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.8] y:  -1
#
#  w 105 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
# 106/150 [====================>.........] - ETA: 0s - loss: 0.2797
#  z:  [2.5 4.9] y:  -1
#
#  w 106 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.3 4.4] y:  -1
#
#  w 107 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.4 3.7] y:  -1
#
#  w 108 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.8] y:  -1
#
#  w 109 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 110 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 111 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 112 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.4] y:  -1
#
#  w 113 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 114 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 5.4] y:  -1
#
#  w 115 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.  3.5] y:  -1
#
#  w 116 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
# 117/150 [======================>.......] - ETA: 0s - loss: 0.2534
#  z:  [4.2 1.4] y:  1
#
#  w 117 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4. ] y:  -1
#
#  w 118 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.4] y:  1
#
#  w 119 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.8 1.9] y:  1
#
#  w 120 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [4.1 1.5] y:  1
#
#  w 121 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.2] y:  -1
#
#  w 122 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.7] y:  1
#
#  w 123 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 5.4] y:  -1
#
#  w 124 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 6.1] y:  -1
#
#  w 125 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.3 4.7] y:  -1
#
#  w 126 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 1.4] y:  1
#
#  w 127 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.6 5.6] y:  -1
#
#  w 128 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
# 129/150 [========================>.....] - ETA: 0s - loss: 0.2299
#  z:  [3.  4.2] y:  -1
#
#  w 129 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.7 4.1] y:  -1
#
#  w 130 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 5.3] y:  -1
#
#  w 131 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [4.4 1.5] y:  1
#
#  w 132 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 1.4] y:  1
#
#  w 133 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.1 4.9] y:  -1
#
#  w 134 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 135 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  4.5] y:  -1
#  w 136 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.6 1.4] y:  1
#
#  w 137 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.5 3.9] y:  -1
#
#  w 138 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 1.6] y:  1
#
#  w 139 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
# 140/150 [===========================>..] - ETA: 0s - loss: 0.2118
#  z:  [2.4 3.3] y:  -1
#
#  w 140 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.9 4.6] y:  -1
#
#  w 141 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.6 3.5] y:  -1
#
#  w 142 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 4.5] y:  -1
#
#  w 143 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.5 1.4] y:  1
#
#  w 144 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.  5.9] y:  -1
#
#  w 145 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [2.8 5.6] y:  -1
#
#  w 146 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 147 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 4.5] y:  -1
#
#  w 148 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 149 :
#  [array([[ 4.1099997],
#        [-4.29     ]], dtype=float32), array([1.], dtype=float32)]
#
#
#  z:  [3.4 5.6] y:  -1
# 150/150 [==============================] - 1s 5ms/step - loss: 0.1977

# %% [markdown]
# Note above that whenever there is a mistake made, the weights are updated as:
#
# w_{i+1} = w_i +y_i z_i.
#
# Note again that here there are effectively three weights: the two coefficients of the coordinates of the example and the intercept, because we are looking for separating boundaries that are lines not necessarily through the origin. Correspondingly, each example is interpreted as a vector of length 3, the first two coefficients being the actual example and the third coordinate equal to 1 always.
#
# This is exactly the perceptron training algorithm we studied in class. We have simulated it exactly using keras and gradient descent.
#
# Your assignment is as follows:
#
# ### Problem 1.
# a. Using keras and gradient descent, simulate a 1-neuron network that mimics LinearRegression. Use a learning rate of .01 here.

# %%
# Create model
# 1 Neuron network
iris_lr = Sequential([
    Dense(1, input_shape=(2,)), 
    Activation('linear'), 
])

#Lr of 0.1
opt = SGD(lr=0.01,momentum=0,nesterov=False)

iris_lr.compile(optimizer=opt, loss=keras.losses.MSE)

# %% [markdown]
# b. Test your simulation on the Iris dataset above. This time do both cases: (a) classes that are *NOT* linearly separable (for eg. label 1 in the IRIS dataset from the other two) and (b) classes that are linearly separable as above. Make sure if the gradients are what you expect by checking the weights before and after an example using callbacks as above. Later on, we will learn how to extract/manipulate gradient information. Choose the batch size wisely.

# %%
print_weights = LambdaCallback(on_batch_begin=lambda batch, logs: print('\n w',batch,': \n',iris_lr.layers[0].get_weights(),'\n'))
print_examples = LambdaCallback(on_batch_end = lambda batch, logs: print('\n z: ',training[batch,:],'y: ', labels[batch]))
# 

# Again we initialize weights
iris_lr.layers[0].set_weights([np.array([[0.01],[0.01]]),np.array([0.0])])

# %%
##############
# (a) not linearly seperable
#############
color_train = iris.data[:,[1,2]]
color_target = np.where(iris.target == 2, 1,-1)

color_train, color_target = shuffle(training, color_target)

iris_lr.fit(color_train, color_target, epochs=40, batch_size=10,callbacks = [ print_weights, print_examples ], shuffle=False)

lr = iris_lr.layers[0].get_weights()

fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 2, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(lr[1][0]+lr[0][0,0]*x)/lr[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)
# Out:
# Epoch 1/40
#
#  w 0 :
#  [array([[0.01],
#        [0.01]], dtype=float32), array([0.], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0162
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.008484 ],
#        [ 0.0077564]], dtype=float32), array([-0.005308], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.05694766],
#        [-0.03973772]], dtype=float32), array([-0.02109468], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.03340086],
#        [-0.01757994]], dtype=float32), array([-0.01372515], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.0748008 ],
#        [-0.05449732]], dtype=float32), array([-0.02625925], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.08187594],
#        [-0.0655865 ]], dtype=float32), array([-0.02916705], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.06218811],
#        [-0.03524271]], dtype=float32), array([-0.02228997], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.10181463],
#        [-0.08402364]], dtype=float32), array([-0.0352346], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.06233921],
#        [-0.03321798]], dtype=float32), array([-0.02152239], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.05027524],
#        [-0.02799815]], dtype=float32), array([-0.01837672], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.03678336],
#        [-0.00536755]], dtype=float32), array([-0.01276161], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.06294457],
#        [-0.04128495]], dtype=float32), array([-0.02181292], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.9631
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.02337743],
#        [-0.01168909]], dtype=float32), array([-0.01059444], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05168922],
#        [-0.02677405]], dtype=float32), array([-0.02014063], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.02405404],
#        [ 0.00966967]], dtype=float32), array([-0.01083792], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 845us/step - loss: 0.9745
# Epoch 2/40
#
#  w 0 :
#  [array([[-0.0417555 ],
#        [-0.02897761]], dtype=float32), array([-0.01772769], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 1.0044
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04069094],
#        [-0.00765529]], dtype=float32), array([-0.01678552], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.07967874],
#        [-0.04627504]], dtype=float32), array([-0.02951359], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.04900002],
#        [-0.01497955]], dtype=float32), array([-0.01996148], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.08737986],
#        [-0.04928301]], dtype=float32), array([-0.03155713], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09290513],
#        [-0.05898584]], dtype=float32), array([-0.03397082], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07233347],
#        [-0.02822064]], dtype=float32), array([-0.0268428], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11145023],
#        [-0.07688245]], dtype=float32), array([-0.03962959], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07174322],
#        [-0.02608204]], dtype=float32), array([-0.02586327], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.05933581],
#        [-0.02095376]], dtype=float32), array([-0.02262354], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.04567123],
#        [ 0.00148512]], dtype=float32), array([-0.01697159], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9170
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.0718324 ],
#        [-0.03491741]], dtype=float32), array([-0.02603765], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03166702],
#        [-0.00512798]], dtype=float32), array([-0.01466497], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05950746],
#        [-0.02022399]], dtype=float32), array([-0.02408205], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03182808],
#        [ 0.01579774]], dtype=float32), array([-0.01478192], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 498us/step - loss: 0.9616
# Epoch 3/40
#
#  w 0 :
#  [array([[-0.04885177],
#        [-0.02282226]], dtype=float32), array([-0.02150764], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9925
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04744773],
#        [-0.00155141]], dtype=float32), array([-0.02046809], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08587106],
#        [-0.04010162]], dtype=float32), array([-0.03303319], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05523958],
#        [-0.00930379]], dtype=float32), array([-0.02350947], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.0932086 ],
#        [-0.04370983]], dtype=float32), array([-0.03499886], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09865056],
#        [-0.05377066]], dtype=float32), array([-0.03739496], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07797905],
#        [-0.02339979]], dtype=float32), array([-0.03025956], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11697949],
#        [-0.07227691]], dtype=float32), array([-0.04301319], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07721098],
#        [-0.02159828]], dtype=float32), array([-0.02924112], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06463705],
#        [-0.01658898]], dtype=float32), array([-0.02595734], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05087909],
#        [ 0.00571501]], dtype=float32), array([-0.02028685], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.0770475 ],
#        [-0.03099628]], dtype=float32), array([-0.02936433], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03651836],
#        [-0.00108807]], dtype=float32), array([-0.01789766], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06407224],
#        [-0.01619222]], dtype=float32), array([-0.02723614], dtype=float32)]
#
# 140/150 [===========================>..] - ETA: 0s - loss: 0.9584
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03636391],
#        [ 0.01957444]], dtype=float32), array([-0.01793655], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 432us/step - loss: 0.9609
# Epoch 4/40
#
#  w 0 :
#  [array([[-0.0529781 ],
#        [-0.01903157]], dtype=float32), array([-0.02456313], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9854
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05136774],
#        [ 0.00220595]], dtype=float32), array([-0.02346428], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08944507],
#        [-0.03630057]], dtype=float32), array([-0.03592931], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05884639],
#        [-0.00581194]], dtype=float32), array([-0.02642404], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09656315],
#        [-0.04027845]], dtype=float32), array([-0.03784795], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10195334],
#        [-0.05055784]], dtype=float32), array([-0.04023295], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08122118],
#        [-0.02042739]], dtype=float32), array([-0.03309305], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12015079],
#        [-0.06943762]], dtype=float32), array([-0.04582636], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08034334],
#        [-0.01883015]], dtype=float32), array([-0.03205012], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06767058],
#        [-0.01389798]], dtype=float32), array([-0.02874015], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05385355],
#        [ 0.00832721]], dtype=float32), array([-0.02305743], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.0800267 ],
#        [-0.02857356]], dtype=float32), array([-0.03214194], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03927482],
#        [ 0.00141048]], dtype=float32), array([-0.02061735], dtype=float32)]
# 130/150 [=========================>....] - ETA: 0s - loss: 0.9399
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06665383],
#        [-0.01369863]], dtype=float32), array([-0.02990769], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03892533],
#        [ 0.02191563]], dtype=float32), array([-0.02060722], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 455us/step - loss: 0.9605
# Epoch 5/40
#
#  w 0 :
#  [array([[-0.05529339],
#        [-0.01668413]], dtype=float32), array([-0.02717417], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9811
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05355782],
#        [ 0.00453131]], dtype=float32), array([-0.02603918], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09142236],
#        [-0.03394723]], dtype=float32), array([-0.0384425], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06084762],
#        [-0.00365269]], dtype=float32), array([-0.02894961], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09840885],
#        [-0.03815398]], dtype=float32), array([-0.0403329], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10376649],
#        [-0.04856681]], dtype=float32), array([-0.04271075], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08299759],
#        [-0.01858287]], dtype=float32), array([-0.03556813], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12188413],
#        [-0.06767608]], dtype=float32), array([-0.04828896], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08205155],
#        [-0.01710887]], dtype=float32), array([-0.03450951], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.9048
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06932124],
#        [-0.01222827]], dtype=float32), array([-0.03118423], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05546607],
#        [ 0.00995232]], dtype=float32), array([-0.02549315], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08164245],
#        [-0.02706514]], dtype=float32), array([-0.03458203], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.04075385],
#        [ 0.00296853]], dtype=float32), array([-0.0230215], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06802614],
#        [-0.01214358]], dtype=float32), array([-0.03228229], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.04028282],
#        [ 0.0233809 ]], dtype=float32), array([-0.02298007], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 633us/step - loss: 0.9603
# Epoch 6/40
#
#  w 0 :
#  [array([[-0.05650443],
#        [-0.01521733]], dtype=float32), array([-0.02951149], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9785
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05469313],
#        [ 0.00598288]], dtype=float32), array([-0.02835451], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09242619],
#        [-0.03247726]], dtype=float32), array([-0.04071952], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06186995],
#        [-0.00230657]], dtype=float32), array([-0.0312353], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09933466],
#        [-0.03682697]], dtype=float32), array([-0.04259314], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10467149],
#        [-0.04732134]], dtype=float32), array([-0.04496627], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08388044],
#        [-0.0174266 ]], dtype=float32), array([-0.037822], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12274083],
#        [-0.06657218]], dtype=float32), array([-0.05053512], dtype=float32)]
#
#  80/150 [===============>..............] - ETA: 0s - loss: 0.8938
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08289151],
#        [-0.01602638]], dtype=float32), array([-0.03675305], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.07012886],
#        [-0.01118175]], dtype=float32), array([-0.03341911], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05624834],
#        [ 0.01097508]], dtype=float32), array([-0.02772203], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08242702],
#        [-0.02611465]], dtype=float32), array([-0.03681365], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.0414542 ],
#        [ 0.00395264]], dtype=float32), array([-0.02523061], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06866133],
#        [-0.01116129]], dtype=float32), array([-0.03447319], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.0409065],
#        [ 0.0243116]], dtype=float32), array([-0.0251687], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 735us/step - loss: 0.9602
# Epoch 7/40
#
#  w 0 :
#  [array([[-0.05704243],
#        [-0.01428798]], dtype=float32), array([-0.03167927], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9769
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05518558],
#        [ 0.00690123]], dtype=float32), array([-0.03050894], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09283675],
#        [-0.03154638]], dtype=float32), array([-0.04284992], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06229569],
#        [-0.00145667]], dtype=float32), array([-0.03337209], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09969989],
#        [-0.03598662]], dtype=float32), array([-0.04471375], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10502307],
#        [-0.04653085]], dtype=float32), array([-0.04708362], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08421879],
#        [-0.01669037]], dtype=float32), array([-0.03993836], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12306337],
#        [-0.06586963]], dtype=float32), array([-0.05264669], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08320244],
#        [-0.01533377]], dtype=float32), array([-0.03886237], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.9042
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.07042278],
#        [-0.01051557]], dtype=float32), array([-0.03552381], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05652473],
#        [ 0.01163023]], dtype=float32), array([-0.02982217], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08270514],
#        [-0.02550469]], dtype=float32), array([-0.03891553], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.04168014],
#        [ 0.00458646]], dtype=float32), array([-0.02731817], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06884748],
#        [-0.01052857]], dtype=float32), array([-0.03654946], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.04108312],
#        [ 0.02491604]], dtype=float32), array([-0.02724238], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 681us/step - loss: 0.9601
# Epoch 8/40
#
#  w 0 :
#  [array([[-0.05717049],
#        [-0.01368664]], dtype=float32), array([-0.03374109], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9759
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05528649],
#        [ 0.00749412]], dtype=float32), array([-0.03256266], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09288606],
#        [-0.03094452]], dtype=float32), array([-0.04488833], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06235813],
#        [-0.00090961]], dtype=float32), array([-0.03541551], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09972382],
#        [-0.03544329]], dtype=float32), array([-0.04674664], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10503773],
#        [-0.04601805]], dtype=float32), array([-0.04911416], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08422562],
#        [-0.01621048]], dtype=float32), array([-0.0419683], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12306069],
#        [-0.06541203]], dtype=float32), array([-0.05467362], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08319131],
#        [-0.01487912]], dtype=float32), array([-0.04088726], dtype=float32)]
#  90/150 [=================>............] - ETA: 0s - loss: 0.9041
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.070404  ],
#        [-0.01008153]], dtype=float32), array([-0.03754656], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05649317],
#        [ 0.01206099]], dtype=float32), array([-0.03184125], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08267497],
#        [-0.02510257]], dtype=float32), array([-0.04093574], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.04161733],
#        [ 0.00500645]], dtype=float32), array([-0.02932906], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06876034],
#        [-0.01010923]], dtype=float32), array([-0.03855328], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.04098771],
#        [ 0.02532129]], dtype=float32), array([-0.02924342], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 618us/step - loss: 0.9600
# Epoch 9/40
#
#  w 0 :
#  [array([[-0.05704911],
#        [-0.01328553]], dtype=float32), array([-0.03573573], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9752
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05514921],
#        [ 0.00788834]], dtype=float32), array([-0.03455242], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09271564],
#        [-0.03054352]], dtype=float32), array([-0.04686809], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06219958],
#        [-0.00054742]], dtype=float32), array([-0.03739943], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09954017],
#        [-0.03508129]], dtype=float32), array([-0.04872347], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10484747],
#        [-0.04567478]], dtype=float32), array([-0.0510892], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08403085],
#        [-0.01588713]], dtype=float32), array([-0.04394299], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12286026],
#        [-0.06510401]], dtype=float32), array([-0.05664638], dtype=float32)]
#
#  80/150 [===============>..............] - ETA: 0s - loss: 0.8931
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08298434],
#        [-0.01456978]], dtype=float32), array([-0.04285812], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.07019509],
#        [-0.00978921]], dtype=float32), array([-0.03951678], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.0562744 ],
#        [ 0.01235474]], dtype=float32), array([-0.03380834], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08245738],
#        [-0.02482738]], dtype=float32), array([-0.04290359], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.04137902],
#        [ 0.00529588]], dtype=float32), array([-0.03129065], dtype=float32)]
#
# 130/150 [=========================>....] - ETA: 0s - loss: 0.9389
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06850717],
#        [-0.0098202 ]], dtype=float32), array([-0.04051036], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.04072702],
#        [ 0.0256049 ]], dtype=float32), array([-0.03119762], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 789us/step - loss: 0.9600
# Epoch 10/40
#
#  w 0 :
#  [array([[-0.05677623],
#        [-0.01300671]], dtype=float32), array([-0.03768686], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9748
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05486728],
#        [ 0.00816125]], dtype=float32), array([-0.03650063], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09241184],
#        [-0.03026517]], dtype=float32), array([-0.04880955], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06190688],
#        [-0.00029811]], dtype=float32), array([-0.03934452], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09923055],
#        [-0.03483   ]], dtype=float32), array([-0.05066359], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10453288],
#        [-0.04543503]], dtype=float32), array([-0.05302785], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08371378],
#        [-0.01565936]], dtype=float32), array([-0.04588145], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12253986],
#        [-0.06488731]], dtype=float32), array([-0.05858357], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08265859],
#        [-0.01434918]], dtype=float32), array([-0.04479351], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06987085],
#        [-0.00958345]], dtype=float32), array([-0.04145244], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.0559421 ],
#        [ 0.01256479]], dtype=float32), array([-0.0357412], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9128
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08212611],
#        [-0.02462972]], dtype=float32), array([-0.044837], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.04103432],
#        [ 0.00550552]], dtype=float32), array([-0.03321965], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06815335],
#        [-0.00961078]], dtype=float32), array([-0.04243645], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.04036617],
#        [ 0.02581414]], dtype=float32), array([-0.03312075], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 577us/step - loss: 0.9600
# Epoch 11/40
#
#  w 0 :
#  [array([[-0.05641158],
#        [-0.01280263]], dtype=float32), array([-0.03960896], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9746
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05449775],
#        [ 0.00836002]], dtype=float32), array([-0.03842099], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09202734],
#        [-0.03006179]], dtype=float32), array([-0.05072515], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06153299],
#        [-0.00011779]], dtype=float32), array([-0.04126344], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09884475],
#        [-0.03464641]], dtype=float32), array([-0.05257883], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10414311],
#        [-0.04525859]], dtype=float32), array([-0.05494184], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08332275],
#        [-0.01549005]], dtype=float32), array([-0.04779532], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12214693],
#        [-0.06472646]], dtype=float32), array([-0.06049659], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08226101],
#        [-0.01418287]], dtype=float32), array([-0.04670477], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.0694769 ],
#        [-0.00943062]], dtype=float32), array([-0.04336453], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05554118],
#        [ 0.01272365]], dtype=float32), array([-0.0376507], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08172616],
#        [-0.02447948]], dtype=float32), array([-0.04674689], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.9465
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.04062537],
#        [ 0.00566635]], dtype=float32), array([-0.03512628], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06773881],
#        [-0.00945007]], dtype=float32), array([-0.04434112], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03994487],
#        [ 0.0259779 ]], dtype=float32), array([-0.03502243], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 533us/step - loss: 0.9599
# Epoch 12/40
#
#  w 0 :
#  [array([[-0.05599161],
#        [-0.01264426]], dtype=float32), array([-0.04151084], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9744
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05407545],
#        [ 0.00851343]], dtype=float32), array([-0.04032188], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09159428],
#        [-0.02990426]], dtype=float32), array([-0.05262248], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-6.1110221e-02],
#        [ 2.0353124e-05]], dtype=float32), array([-0.04316388], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#  w 4 :
#  [array([[-0.09841313],
#        [-0.0345042 ]], dtype=float32), array([-0.05447637], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10370813],
#        [-0.04512084]], dtype=float32), array([-0.05683826], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08288728],
#        [-0.01535648]], dtype=float32), array([-0.04969168], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12171045],
#        [-0.06459977]], dtype=float32), array([-0.06239234], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08182033],
#        [-0.01404976]], dtype=float32), array([-0.0485988], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06904113],
#        [-0.00931014]], dtype=float32), array([-0.04525973], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9195
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.0550991],
#        [ 0.0128512]], dtype=float32), array([-0.03954343], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08128499],
#        [-0.02435826]], dtype=float32), array([-0.04863995], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.04017793],
#        [ 0.00579733]], dtype=float32), array([-0.03701677], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06728792],
#        [-0.00931915]], dtype=float32), array([-0.04623023], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03948744],
#        [ 0.0261138 ]], dtype=float32), array([-0.03690854], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 574us/step - loss: 0.9599
# Epoch 13/40
#
#  w 0 :
#  [array([[-0.0555386 ],
#        [-0.01251388]], dtype=float32), array([-0.0433979], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9742
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05362166],
#        [ 0.00863909]], dtype=float32), array([-0.04220838], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09113228],
#        [-0.0297748 ]], dtype=float32), array([-0.05450618], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06065832],
#        [ 0.00013267]], dtype=float32), array([-0.04505057], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09795424],
#        [-0.03438733]], dtype=float32), array([-0.05636065], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10324627],
#        [-0.0450068 ]], dtype=float32), array([-0.05872148], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08242536],
#        [-0.01524482]], dtype=float32), array([-0.05157489], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12124804],
#        [-0.06449401]], dtype=float32), array([-0.06427509], dtype=float32)]
#
#  80/150 [===============>..............] - ETA: 0s - loss: 0.8929
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08135401],
#        [-0.01393702]], dtype=float32), array([-0.05047985], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06858047],
#        [-0.00920951]], dtype=float32), array([-0.04714216], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05463257],
#        [ 0.01295954]], dtype=float32), array([-0.04142348], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08081935],
#        [-0.02425485]], dtype=float32), array([-0.05052026], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03970767],
#        [ 0.00590996]], dtype=float32), array([-0.03889494], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06681551],
#        [-0.00920655]], dtype=float32), array([-0.04810739], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.0390086 ],
#        [ 0.02623257]], dtype=float32), array([-0.03878268], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 588us/step - loss: 0.9599
# Epoch 14/40
#
#  w 0 :
#  [array([[-0.05506608],
#        [-0.0124007 ]], dtype=float32), array([-0.04527344], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9741
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.0531493],
#        [ 0.0087477]], dtype=float32), array([-0.04408364], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.0906533 ],
#        [-0.02966259]], dtype=float32), array([-0.05637909], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.06018928],
#        [ 0.00022915]], dtype=float32), array([-0.04692638], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09747937],
#        [-0.03428603]], dtype=float32), array([-0.05823435], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10276865],
#        [-0.04490735]], dtype=float32), array([-0.06059419], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08194797],
#        [-0.01514664]], dtype=float32), array([-0.05344759], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12077048],
#        [-0.06440113]], dtype=float32), array([-0.06614742], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.0808727 ],
#        [-0.01383682]], dtype=float32), array([-0.0523505], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.0681053 ],
#        [-0.00912108]], dtype=float32), array([-0.0490143], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9195
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.0541518 ],
#        [ 0.01305604]], dtype=float32), array([-0.04329329], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.08033943],
#        [-0.0241624 ]], dtype=float32), array([-0.0523903], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03922416],
#        [ 0.00601129]], dtype=float32), array([-0.04076311], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06633065],
#        [-0.00910522]], dtype=float32), array([-0.04997476], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03851739],
#        [ 0.02634076]], dtype=float32), array([-0.04064705], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 604us/step - loss: 0.9599
# Epoch 15/40
#
#  w 0 :
#  [array([[-0.05458231],
#        [-0.01229814]], dtype=float32), array([-0.04713949], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9740
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05266628],
#        [ 0.00884577]], dtype=float32), array([-0.04594957], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.09016462],
#        [-0.02956104]], dtype=float32), array([-0.05824295], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05971046],
#        [ 0.00031584]], dtype=float32), array([-0.04879308], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09699542],
#        [-0.03419434]], dtype=float32), array([-0.06009912], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.1022821 ],
#        [-0.04481689]], dtype=float32), array([-0.06245799], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08146182],
#        [-0.01505679]], dtype=float32), array([-0.05531141], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.12028436],
#        [-0.0643162 ]], dtype=float32), array([-0.06801093], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.08038296],
#        [-0.01374438]], dtype=float32), array([-0.05421235], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06762196],
#        [-0.00904018]], dtype=float32), array([-0.05087771], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05366301],
#        [ 0.01314523]], dtype=float32), array([-0.0451544], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9127
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.07985149],
#        [-0.02407675]], dtype=float32), array([-0.05425163], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03873322],
#        [ 0.00610561]], dtype=float32), array([-0.04262272], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06583886],
#        [-0.00901089]], dtype=float32), array([-0.05183371], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03801931],
#        [ 0.02644237]], dtype=float32), array([-0.04250299], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 587us/step - loss: 0.9598
# Epoch 16/40
#
#  w 0 :
#  [array([[-0.05409236],
#        [-0.01220217]], dtype=float32), array([-0.04899728], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9740
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05217741],
#        [ 0.00893733]], dtype=float32), array([-0.04780734], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.0896707 ],
#        [-0.02946607]], dtype=float32), array([-0.06009881], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05922633],
#        [ 0.00039648]], dtype=float32), array([-0.05065177], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09650659],
#        [-0.03410862]], dtype=float32), array([-0.06195598], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10179076],
#        [-0.04473201]], dtype=float32), array([-0.0643139], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08097098],
#        [-0.01497212]], dtype=float32), array([-0.05716734], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11979368],
#        [-0.06423622]], dtype=float32), array([-0.06986659], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.0798887 ],
#        [-0.01365677]], dtype=float32), array([-0.05606635], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06713428],
#        [-0.00896398]], dtype=float32), array([-0.05273332], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9195
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05316999],
#        [ 0.01322984]], dtype=float32), array([-0.04700775], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.07935931],
#        [-0.02399534]], dtype=float32), array([-0.05610517], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03823844],
#        [ 0.00619555]], dtype=float32), array([-0.04447465], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06534351],
#        [-0.00892093]], dtype=float32), array([-0.05368507], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03751772],
#        [ 0.02653986]], dtype=float32), array([-0.04435134], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 602us/step - loss: 0.9598
# Epoch 17/40
#
#  w 0 :
#  [array([[-0.05359931],
#        [-0.01211032]], dtype=float32), array([-0.05084758], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9739
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05168566],
#        [ 0.00902481]], dtype=float32), array([-0.04965768], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08917426],
#        [-0.02937524]], dtype=float32), array([-0.06194736], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05873962],
#        [ 0.00047334]], dtype=float32), array([-0.05250311], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09601545],
#        [-0.03402662]], dtype=float32), array([-0.06380557], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10129718],
#        [-0.04465064]], dtype=float32), array([-0.06616256], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.08047795],
#        [-0.0148907 ]], dtype=float32), array([-0.05901603], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11930089],
#        [-0.06415934]], dtype=float32), array([-0.07171501], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07939239],
#        [-0.01357223]], dtype=float32), array([-0.05791312], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06664461],
#        [-0.00889072]], dtype=float32), array([-0.05458172], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05267506],
#        [ 0.01331156]], dtype=float32), array([-0.0488539], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.0788652 ],
#        [-0.02391662]], dtype=float32), array([-0.05795151], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.9465
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03774198],
#        [ 0.00628269]], dtype=float32), array([-0.04631944], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06484667],
#        [-0.00883376]], dtype=float32), array([-0.05552933], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03701467],
#        [ 0.0266347 ]], dtype=float32), array([-0.04619261], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 649us/step - loss: 0.9598
# Epoch 18/40
#
#  w 0 :
#  [array([[-0.05310501],
#        [-0.0120211 ]], dtype=float32), array([-0.05269084], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9738
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05119279],
#        [ 0.00910968]], dtype=float32), array([-0.05150103], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08867692],
#        [-0.02928706]], dtype=float32), array([-0.06378898], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05825196],
#        [ 0.00054778]], dtype=float32), array([-0.0543475], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09552355],
#        [-0.03394701]], dtype=float32), array([-0.06564827], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10080286],
#        [-0.04457153]], dtype=float32), array([-0.06800435], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07998424],
#        [-0.01481138]], dtype=float32), array([-0.06085784], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11880744],
#        [-0.06408447]], dtype=float32), array([-0.07355659], dtype=float32)]
#
#  80/150 [===============>..............] - ETA: 0s - loss: 0.8928
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07889546],
#        [-0.01348966]], dtype=float32), array([-0.05975306], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06615438],
#        [-0.00881936]], dtype=float32), array([-0.0564233], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05217962],
#        [ 0.01339142]], dtype=float32), array([-0.05069324], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.07837059],
#        [-0.02383963]], dtype=float32), array([-0.05979104], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03724514],
#        [ 0.00636804]], dtype=float32), array([-0.04815746], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06434957],
#        [-0.00874839]], dtype=float32), array([-0.05736685], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03651139],
#        [ 0.02672782]], dtype=float32), array([-0.04802715], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 737us/step - loss: 0.9598
# Epoch 19/40
#
#  w 0 :
#  [array([[-0.05261063],
#        [-0.01193362]], dtype=float32), array([-0.05452742], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9738
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05069991],
#        [ 0.00919286]], dtype=float32), array([-0.05333771], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08817972],
#        [-0.02920059]], dtype=float32), array([-0.06562398], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.0577644 ],
#        [ 0.00062068]], dtype=float32), array([-0.05618525], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09503184],
#        [-0.03386895]], dtype=float32), array([-0.06748435], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.10030877],
#        [-0.04449387]], dtype=float32), array([-0.06983951], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07949077],
#        [-0.01473344]], dtype=float32), array([-0.06269302], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11831427],
#        [-0.0640109 ]], dtype=float32), array([-0.07539154], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07839884],
#        [-0.01340839]], dtype=float32), array([-0.06158638], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06566446],
#        [-0.00874925]], dtype=float32), array([-0.05825827], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05168453],
#        [ 0.01347004]], dtype=float32), array([-0.05252598], dtype=float32)]
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9127
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.07787631],
#        [-0.02376381]], dtype=float32), array([-0.06162397], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03674875],
#        [ 0.00645216]], dtype=float32), array([-0.04998891], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06385297],
#        [-0.00866424]], dtype=float32), array([-0.05919782], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03600864],
#        [ 0.02681976]], dtype=float32), array([-0.04985515], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 523us/step - loss: 0.9597
# Epoch 20/40
#
#  w 0 :
#  [array([[-0.05211684],
#        [-0.01184729]], dtype=float32), array([-0.05635747], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9737
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.05020766],
#        [ 0.0092749 ]], dtype=float32), array([-0.05516787], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08768325],
#        [-0.02911529]], dtype=float32), array([-0.06745248], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05727753],
#        [ 0.00069251]], dtype=float32), array([-0.0580165], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09454089],
#        [-0.03379195]], dtype=float32), array([-0.06931395], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09981546],
#        [-0.04441722]], dtype=float32), array([-0.0716682], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07899809],
#        [-0.01465644]], dtype=float32), array([-0.06452174], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11782189],
#        [-0.06393825]], dtype=float32), array([-0.07722004], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07790302],
#        [-0.01332804]], dtype=float32), array([-0.06341325], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06517536],
#        [-0.00868   ]], dtype=float32), array([-0.06008679], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9195
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05119029],
#        [ 0.01354778]], dtype=float32), array([-0.05435228], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.07738288],
#        [-0.0236888 ]], dtype=float32), array([-0.06345045], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03625324],
#        [ 0.00653542]], dtype=float32), array([-0.05181392], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06335732],
#        [-0.00858094]], dtype=float32), array([-0.06102237], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03550686],
#        [ 0.02691084]], dtype=float32), array([-0.05167673], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 615us/step - loss: 0.9597
# Epoch 21/40
#
#  w 0 :
#  [array([[-0.05162406],
#        [-0.01176179]], dtype=float32), array([-0.05818111], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9736
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04971645],
#        [ 0.00935612]], dtype=float32), array([-0.05699164], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08718788],
#        [-0.02903082]], dtype=float32), array([-0.06927461], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05679172],
#        [ 0.00076361]], dtype=float32), array([-0.05984136], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09405107],
#        [-0.0337157 ]], dtype=float32), array([-0.07113717], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09932329],
#        [-0.04434128]], dtype=float32), array([-0.07349052], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07850656],
#        [-0.01458013]], dtype=float32), array([-0.06634409], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11733069],
#        [-0.06386623]], dtype=float32), array([-0.07904216], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.0774084 ],
#        [-0.01324834]], dtype=float32), array([-0.06523375], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.06468745],
#        [-0.00861134]], dtype=float32), array([-0.06190894], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9195
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.05069726],
#        [ 0.01362491]], dtype=float32), array([-0.05617222], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.07689067],
#        [-0.02361438]], dtype=float32), array([-0.06527057], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.03575901],
#        [ 0.00661806]], dtype=float32), array([-0.05363259], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.06286295],
#        [-0.00849827]], dtype=float32), array([-0.06284058], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.03500639],
#        [ 0.02700132]], dtype=float32), array([-0.05349199], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 581us/step - loss: 0.9597
# Epoch 22/40
#
#  w 0 :
#  [array([[-0.05113257],
#        [-0.01167689]], dtype=float32), array([-0.05999843], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9736
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04922654],
#        [ 0.00943677]], dtype=float32), array([-0.05880909], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08669387],
#        [-0.02894694]], dtype=float32), array([-0.07109044], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05630725],
#        [ 0.00083418]], dtype=float32), array([-0.06165992], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.09356261],
#        [-0.03363997]], dtype=float32), array([-0.0729541], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09883249],
#        [-0.04426586]], dtype=float32), array([-0.07530654], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.0780164],
#        [-0.0145043]], dtype=float32), array([-0.06816015], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11684085],
#        [-0.06379468]], dtype=float32), array([-0.08085799], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07691516],
#        [-0.01316913]], dtype=float32), array([-0.06704796], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.0642009 ],
# ...
#        [ 0.0075826 ]], dtype=float32), array([-0.07497714], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05705311],
#        [-0.00753335]], dtype=float32), array([-0.08417989], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.02912494],
#        [ 0.02805801]], dtype=float32), array([-0.07479661], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 638us/step - loss: 0.9594
# Epoch 34/40
#
#  w 0 :
#  [array([[-0.04535732],
#        [-0.01068567]], dtype=float32), array([-0.08132736], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9729
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04347011],
#        [ 0.0103781 ]], dtype=float32), array([-0.08013962], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08088961],
#        [-0.02796771]], dtype=float32), array([-0.0924021], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05061483],
#        [ 0.00165768]], dtype=float32), array([-0.08300348], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.08782374],
#        [-0.03275597]], dtype=float32), array([-0.0942787], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09306627],
#        [-0.04338505]], dtype=float32), array([-0.09662057], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.0722578 ],
#        [-0.01361848]], dtype=float32), array([-0.08947454], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11108617],
#        [-0.06295888]], dtype=float32), array([-0.10216984], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#  w 8 :
#  [array([[-0.07112058],
#        [-0.01224331]], dtype=float32), array([-0.08834084], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.058485  ],
#        [-0.00774641]], dtype=float32), array([-0.08503701], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9196
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.04443   ],
#        [ 0.01459766]], dtype=float32), array([-0.07927229], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.07063371],
#        [-0.02267549]], dtype=float32), array([-0.08837292], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.02947687],
#        [ 0.00766113]], dtype=float32), array([-0.07671666], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05657954],
#        [-0.00745479]], dtype=float32), array([-0.08591899], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.02864553],
#        [ 0.02814407]], dtype=float32), array([-0.07653287], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 587us/step - loss: 0.9594
# Epoch 35/40
#
#  w 0 :
#  [array([[-0.04488657],
#        [-0.01060494]], dtype=float32), array([-0.08306561], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9729
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04300091],
#        [ 0.01045476]], dtype=float32), array([-0.08187799], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.08041652],
#        [-0.02788796]], dtype=float32), array([-0.09413894], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05015083],
#        [ 0.00172474]], dtype=float32), array([-0.08474292], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.08735596],
#        [-0.03268398]], dtype=float32), array([-0.09601659], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09259626],
#        [-0.04331332]], dtype=float32), array([-0.0983576], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07178841],
#        [-0.01354634]], dtype=float32), array([-0.0912116], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11061709],
#        [-0.06289082]], dtype=float32), array([-0.10390669], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07064827],
#        [-0.01216792]], dtype=float32), array([-0.09007614], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.9035
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.0580191 ],
#        [-0.00768154]], dtype=float32), array([-0.08677389], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.04395923],
#        [ 0.01467063]], dtype=float32), array([-0.08100707], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.07016371],
#        [-0.02260504]], dtype=float32), array([-0.09010787], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.02900498],
#        [ 0.0077394 ]], dtype=float32), array([-0.07845024], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05610757],
#        [-0.00737649]], dtype=float32), array([-0.08765214], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.02816774],
#        [ 0.02822983]], dtype=float32), array([-0.07826321], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 649us/step - loss: 0.9594
# Epoch 36/40
#
#  w 0 :
#  [array([[-0.04441741],
#        [-0.0105245 ]], dtype=float32), array([-0.08479793], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9728
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04253329],
#        [ 0.01053115]], dtype=float32), array([-0.08361045], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.07994501],
#        [-0.0278085 ]], dtype=float32), array([-0.09586985], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.04968842],
#        [ 0.00179156]], dtype=float32), array([-0.08647643], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.08688978],
#        [-0.03261223]], dtype=float32), array([-0.09774856], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09212786],
#        [-0.04324184]], dtype=float32), array([-0.10008872], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07132064],
#        [-0.01347445]], dtype=float32), array([-0.09294274], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.11014965],
#        [-0.06282298]], dtype=float32), array([-0.10563762], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.07017758],
#        [-0.01209277]], dtype=float32), array([-0.09180553], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.0575548 ],
#        [-0.00761687]], dtype=float32), array([-0.08850485], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9197
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.04349008],
#        [ 0.01474337]], dtype=float32), array([-0.08273593], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.06969533],
#        [-0.02253483]], dtype=float32), array([-0.0918369], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.02853472],
#        [ 0.00781741]], dtype=float32), array([-0.0801779], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05563722],
#        [-0.00729845]], dtype=float32), array([-0.08937939], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.0276916],
#        [ 0.0283153]], dtype=float32), array([-0.07998765], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 641us/step - loss: 0.9594
# Epoch 37/40
#
#  w 0 :
#  [array([[-0.04394987],
#        [-0.01044434]], dtype=float32), array([-0.08652433], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9728
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04206727],
#        [ 0.01060728]], dtype=float32), array([-0.08533698], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.07947513],
#        [-0.0277293 ]], dtype=float32), array([-0.09759486], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.0492276 ],
#        [ 0.00185816]], dtype=float32), array([-0.08820402], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.0864252 ],
#        [-0.03254074]], dtype=float32), array([-0.09947461], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09166107],
#        [-0.0431706 ]], dtype=float32), array([-0.10181391], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07085446],
#        [-0.01340279]], dtype=float32), array([-0.09466796], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.10968378],
#        [-0.06275538]], dtype=float32), array([-0.10736264], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.06970848],
#        [-0.01201787]], dtype=float32), array([-0.09352902], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.05709208],
#        [-0.00755243]], dtype=float32), array([-0.0902299], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.04302252],
#        [ 0.01481586]], dtype=float32), array([-0.0844589], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.9128
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.06922854],
#        [-0.02246487]], dtype=float32), array([-0.09356003], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.02806607],
#        [ 0.00789514]], dtype=float32), array([-0.08189967], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05516847],
#        [-0.00722068]], dtype=float32), array([-0.09110073], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.02721707],
#        [ 0.02840048]], dtype=float32), array([-0.08170619], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 560us/step - loss: 0.9594
# Epoch 38/40
#
#  w 0 :
#  [array([[-0.04348392],
#        [-0.01036444]], dtype=float32), array([-0.08824484], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9727
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04160284],
#        [ 0.01068315]], dtype=float32), array([-0.08705762], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.07900685],
#        [-0.02765037]], dtype=float32), array([-0.09931398], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#  w 3 :
#  [array([[-0.04876833],
#        [ 0.00192453]], dtype=float32), array([-0.08992571], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.08596219],
#        [-0.03246949]], dtype=float32), array([-0.10119478], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09119585],
#        [-0.0430996 ]], dtype=float32), array([-0.10353323], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.07038986],
#        [-0.01333139]], dtype=float32), array([-0.09638731], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.10921951],
#        [-0.062688  ]], dtype=float32), array([-0.10908178], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.06924099],
#        [-0.01194322]], dtype=float32), array([-0.09524663], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.05663093],
#        [-0.0074882 ]], dtype=float32), array([-0.09194907], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.9197
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.04255656],
#        [ 0.01488811]], dtype=float32), array([-0.08617599], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.06876336],
#        [-0.02239514]], dtype=float32), array([-0.09527729], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.02759901],
#        [ 0.00797261]], dtype=float32), array([-0.08361557], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05470132],
#        [-0.00714318]], dtype=float32), array([-0.09281621], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.02674417],
#        [ 0.02848537]], dtype=float32), array([-0.08341888], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 643us/step - loss: 0.9593
# Epoch 39/40
#
#  w 0 :
#  [array([[-0.04301956],
#        [-0.01028481]], dtype=float32), array([-0.08995949], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9727
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04114   ],
#        [ 0.01075877]], dtype=float32), array([-0.08877239], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.07854018],
#        [-0.02757171]], dtype=float32), array([-0.10102724], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.04831065],
#        [ 0.00199068]], dtype=float32), array([-0.09164154], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.08550078],
#        [-0.03239848]], dtype=float32), array([-0.10290907], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09073225],
#        [-0.04302884]], dtype=float32), array([-0.10524668], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.06992687],
#        [-0.01326022]], dtype=float32), array([-0.09810079], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.10875683],
#        [-0.06262086]], dtype=float32), array([-0.11079505], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.0687751 ],
#        [-0.01186886]], dtype=float32), array([-0.09695837], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.9034
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.05617137],
#        [-0.0074242 ]], dtype=float32), array([-0.09366237], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.04209219],
#        [ 0.0149601 ]], dtype=float32), array([-0.08788721], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.06829975],
#        [-0.02232564]], dtype=float32), array([-0.09698868], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.02713354],
#        [ 0.00804982]], dtype=float32), array([-0.08532561], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05423576],
#        [-0.00706595]], dtype=float32), array([-0.09452583], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.02627287],
#        [ 0.02856996]], dtype=float32), array([-0.08512572], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 645us/step - loss: 0.9593
# Epoch 40/40
#
#  w 0 :
#  [array([[-0.04255677],
#        [-0.01020547]], dtype=float32), array([-0.09166828], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9726
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.04067873],
#        [ 0.01083411]], dtype=float32), array([-0.09048132], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.07807508],
#        [-0.02749333]], dtype=float32), array([-0.10273466], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.04785452],
#        [ 0.00205659]], dtype=float32), array([-0.09335151], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.08504093],
#        [-0.03232771]], dtype=float32), array([-0.10461753], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.09027021],
#        [-0.04295833]], dtype=float32), array([-0.10695428], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.06946544],
#        [-0.0131893 ]], dtype=float32), array([-0.09980842], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.10829571],
#        [-0.06255394]], dtype=float32), array([-0.11250249], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.06831079],
#        [-0.01179473]], dtype=float32), array([-0.09866428], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.9034
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.05571336],
#        [-0.00736041]], dtype=float32), array([-0.09536983], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.04162941],
#        [ 0.01503185]], dtype=float32), array([-0.08959261], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.06783772],
#        [-0.02225639]], dtype=float32), array([-0.09869424], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.02666965],
#        [ 0.00812676]], dtype=float32), array([-0.08702983], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.05377179],
#        [-0.00698898]], dtype=float32), array([-0.09622964], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.02580318],
#        [ 0.02865427]], dtype=float32), array([-0.08682676], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 734us/step - loss: 0.9593

# %%
##############
# (b) linearly seperable
#############

iris_lr.fit(training, labels, epochs=1, batch_size=1,callbacks = [ print_weights, print_examples ], shuffle=False)

lr = iris_lr.layers[0].get_weights()

fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 0, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(lr[1][0]+lr[0][0,0]*x)/lr[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)
# Out:
# Epoch 1/1
#
#  w 0 :
#  [array([[-0.04209557],
#        [-0.01012639]], dtype=float32), array([-0.09337126], dtype=float32)]
#
#   1/150 [..............................] - ETA: 0s - loss: 1.5223
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[0.03193452],
#        [0.02442099]], dtype=float32), array([-0.06869456], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.03410974],
#        [-0.08261625]], dtype=float32), array([-0.09146845], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.05955756],
#        [-0.12176675]], dtype=float32), array([-0.10125607], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.0332512 ],
#        [-0.08406319]], dtype=float32), array([-0.07225333], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[ 0.1011579 ],
#        [-0.05120511]], dtype=float32), array([-0.05034794], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[ 0.04591167],
#        [-0.13100523]], dtype=float32), array([-0.07080951], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[ 0.0337742 ],
#        [-0.15770765]], dtype=float32), array([-0.07485534], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[ 0.02139095],
#        [-0.17917195]], dtype=float32), array([-0.07898308], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[ 0.01238727],
#        [-0.1928227 ]], dtype=float32), array([-0.0818875], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[ 0.01618899],
#        [-0.18536006]], dtype=float32), array([-0.08047945], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[ 0.00978047],
#        [-0.19477257]], dtype=float32), array([-0.08248211], dtype=float32)]
#
#  12/150 [=>............................] - ETA: 0s - loss: 0.7772
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[ 0.1009948 ],
#        [-0.15453096]], dtype=float32), array([-0.05565437], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[ 0.07251428],
#        [-0.20199847]], dtype=float32), array([-0.06514788], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[ 0.06275813],
#        [-0.2179335 ]], dtype=float32), array([-0.06839993], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
#
#  w 15 :
#  [array([[ 0.05723203],
#        [-0.22622265]], dtype=float32), array([-0.07012683], dtype=float32)]
#
#
#  z:  [3.2 1.2] y:  1
#
#  w 16 :
#  [array([[ 0.13137293],
#        [-0.19841981]], dtype=float32), array([-0.0469578], dtype=float32)]
#
#
#  z:  [3.8 1.5] y:  1
#
#  w 17 :
#  [array([[ 0.19562107],
#        [-0.17305869]], dtype=float32), array([-0.03005039], dtype=float32)]
#
#
#  z:  [2.2 4. ] y:  -1
#
#  w 18 :
#  [array([[ 0.1644655 ],
#        [-0.22970518]], dtype=float32), array([-0.04421202], dtype=float32)]
#
#
#  z:  [2.6 6.9] y:  -1
#
#  w 19 :
#  [array([[ 0.17494701],
#        [-0.20188886]], dtype=float32), array([-0.04018067], dtype=float32)]
#
#
#  z:  [3.9 1.7] y:  1
#
#  w 20 :
#  [array([[ 0.22963268],
#        [-0.17805152]], dtype=float32), array([-0.0261587], dtype=float32)]
#
#
#  z:  [3.1 1.6] y:  1
#
#  w 21 :
#  [array([[ 0.26678184],
#        [-0.15887776]], dtype=float32), array([-0.0141751], dtype=float32)]
#
#
#  z:  [2.9 5.6] y:  -1
#
#  w 22 :
#  [array([[ 0.21633479],
#        [-0.25629276]], dtype=float32), array([-0.03157064], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 23 :
#  [array([[ 0.26188704],
#        [-0.23782563]], dtype=float32), array([-0.01925922], dtype=float32)]
#
#
#  z:  [2.8 4.6] y:  -1
#
#  w 24 :
#  [array([[ 0.22716555],
#        [-0.29486808]], dtype=float32), array([-0.03165975], dtype=float32)]
#
#  25/150 [====>.........................] - ETA: 0s - loss: 0.6003
#  z:  [3.4 1.4] y:  1
#
#  w 25 :
#  [array([[ 0.27286917],
#        [-0.27604893]], dtype=float32), array([-0.01821751], dtype=float32)]
#
#
#  z:  [3.  4.8] y:  -1
#
#  w 26 :
#  [array([[ 0.24434786],
#        [-0.32168302]], dtype=float32), array([-0.02772461], dtype=float32)]
#
#
#  z:  [2.9 4.5] y:  -1
#
#  w 27 :
#  [array([[ 0.23081584],
#        [-0.342681  ]], dtype=float32), array([-0.03239082], dtype=float32)]
#
#
#  z:  [3.3 5.7] y:  -1
#
#  w 28 :
#  [array([[ 0.24559854],
#        [-0.31714725]], dtype=float32), array([-0.02791122], dtype=float32)]
#
#
#  z:  [2.5 4. ] y:  -1
#
#  w 29 :
#  [array([[ 0.22972374],
#        [-0.34254694]], dtype=float32), array([-0.03426114], dtype=float32)]
#
#
#  z:  [2.3 4. ] y:  -1
#
#  w 30 :
#  [array([[ 0.22402361],
#        [-0.3524602 ]], dtype=float32), array([-0.03673945], dtype=float32)]
#
#
#  z:  [3.1 5.1] y:  -1
#
#  w 31 :
#  [array([[ 0.23269203],
#        [-0.33819926]], dtype=float32), array([-0.03394318], dtype=float32)]
#
#
#  z:  [3.5 1.4] y:  1
#
#  w 32 :
#  [array([[ 0.28120202],
#        [-0.31879526]], dtype=float32), array([-0.02008319], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
#
#  w 33 :
#  [array([[ 0.31856945],
#        [-0.30135712]], dtype=float32), array([-0.00762738], dtype=float32)]
#
#
#  z:  [3.2 5.9] y:  -1
#
#  w 34 :
#  [array([[ 0.30360702],
#        [-0.3289441 ]], dtype=float32), array([-0.01230313], dtype=float32)]
#
#
#  z:  [3.  1.6] y:  1
#
#  w 35 :
#  [array([[ 0.34127456],
#        [-0.30885473]], dtype=float32), array([0.00025272], dtype=float32)]
#
#
#  z:  [3.4 1.9] y:  1
#
#  w 36 :
#  [array([[ 0.37025872],
#        [-0.2926577 ]], dtype=float32), array([0.00877747], dtype=float32)]
#
#  37/150 [======>.......................] - ETA: 0s - loss: 0.4698
#  z:  [2.8 4.8] y:  -1
#
#  w 37 :
#  [array([[ 0.334377  ],
#        [-0.35416922]], dtype=float32), array([-0.00403743], dtype=float32)]
#
#
#  z:  [2.8 5.6] y:  -1
#
#  w 38 :
#  [array([[ 0.33724025],
#        [-0.34844273]], dtype=float32), array([-0.00301484], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 39 :
#  [array([[ 0.36135682],
#        [-0.33864537]], dtype=float32), array([0.00452159], dtype=float32)]
#
#
#  z:  [3.1 4.4] y:  -1
#
#  w 40 :
#  [array([[ 0.32200617],
#        [-0.39449793]], dtype=float32), array([-0.00817217], dtype=float32)]
#
#
#  z:  [2.8 5.1] y:  -1
#
#  w 41 :
#  [array([[ 0.32864186],
#        [-0.3824115 ]], dtype=float32), array([-0.00580228], dtype=float32)]
#
#
#  z:  [3.6 6.1] y:  -1
#
#  w 42 :
#  [array([[ 0.3398308],
#        [-0.3634525]], dtype=float32), array([-0.00269424], dtype=float32)]
#
#
#  z:  [2.9 3.6] y:  -1
#
#  w 43 :
#  [array([[ 0.3007164],
#        [-0.4120083]], dtype=float32), array([-0.01618196], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 44 :
#  [array([[ 0.33931062],
#        [-0.39636198]], dtype=float32), array([-0.00575109], dtype=float32)]
#
#
#  z:  [3.  5.5] y:  -1
#
#  w 45 :
#  [array([[ 0.3493792 ],
#        [-0.37790287]], dtype=float32), array([-0.00239489], dtype=float32)]
#
#
#  z:  [3.  4.1] y:  -1
#
#  w 46 :
#  [array([[ 0.31959876],
#        [-0.41860282]], dtype=float32), array([-0.01232171], dtype=float32)]
#
#
#  z:  [3.1 5.5] y:  -1
#
#  w 47 :
#  [array([[ 0.3396794],
#        [-0.3829759]], dtype=float32), array([-0.00584409], dtype=float32)]
#
#  48/150 [========>.....................] - ETA: 0s - loss: 0.3980
#  z:  [2.2 5. ] y:  -1
#
#  w 48 :
#  [array([[ 0.34731027],
#        [-0.365633  ]], dtype=float32), array([-0.00237551], dtype=float32)]
#
#
#  z:  [3.5 1.5] y:  1
#
#  w 49 :
#  [array([[ 0.370777  ],
#        [-0.35557583]], dtype=float32), array([0.00432927], dtype=float32)]
#
#
#  z:  [3.3 5.7] y:  -1
#
#  w 50 :
#  [array([[ 0.35750368],
#        [-0.3785025 ]], dtype=float32), array([0.00030705], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 51 :
#  [array([[ 0.3310757 ],
#        [-0.41667625]], dtype=float32), array([-0.00948109], dtype=float32)]
#
#
#  z:  [3.  1.1] y:  1
#
#  w 52 :
#  [array([[ 0.35955158],
#        [-0.4062351 ]], dtype=float32), array([1.0861084e-05], dtype=float32)]
#
#
#  z:  [3.5 1.3] y:  1
#
#  w 53 :
#  [array([[ 0.37842807],
#        [-0.39922383]], dtype=float32), array([0.00540415], dtype=float32)]
#
#
#  z:  [3.8 1.6] y:  1
#
#  w 54 :
#  [array([[ 0.39327294],
#        [-0.39297336]], dtype=float32), array([0.00931069], dtype=float32)]
#
#
#  z:  [2.8 4.7] y:  -1
#
#  w 55 :
#  [array([[ 0.3785169 ],
#        [-0.41774237]], dtype=float32), array([0.00404069], dtype=float32)]
#
#
#  z:  [3.  4.6] y:  -1
#
#  w 56 :
#  [array([[ 0.3654383],
#        [-0.4377962]], dtype=float32), array([-0.00031884], dtype=float32)]
#
#
#  z:  [3.5 1.6] y:  1
#
#  w 57 :
#  [array([[ 0.39496142],
#        [-0.42429993]], dtype=float32), array([0.00811633], dtype=float32)]
#
#
#  z:  [3.  4.5] y:  -1
#
#  w 58 :
#  [array([[ 0.37794235],
#        [-0.4498285 ]], dtype=float32), array([0.00244331], dtype=float32)]
#  z:  [3.  4.2] y:  -1
#
#  w 59 :
#  [array([[ 0.3631229 ],
#        [-0.47057572]], dtype=float32), array([-0.0024965], dtype=float32)]
#
#  60/150 [===========>..................] - ETA: 0s - loss: 0.3400
#  z:  [3.  5.2] y:  -1
#
#  w 60 :
#  [array([[ 0.3847302],
#        [-0.4331231]], dtype=float32), array([0.00470592], dtype=float32)]
#
#
#  z:  [3.6 1.4] y:  1
#
#  w 61 :
#  [array([[ 0.4003281 ],
#        [-0.42705727]], dtype=float32), array([0.00903868], dtype=float32)]
#
#
#  z:  [2.9 6.3] y:  -1
#
#  w 62 :
#  [array([[ 0.4305154 ],
#        [-0.36147797]], dtype=float32), array([0.01944809], dtype=float32)]
#
#
#  z:  [3.8 6.7] y:  -1
#
#  w 63 :
#  [array([[ 0.41276908],
#        [-0.39276755]], dtype=float32), array([0.01477801], dtype=float32)]
#
#
#  z:  [3.2 5.1] y:  -1
#
#  w 64 :
#  [array([[ 0.3914875 ],
#        [-0.42668507]], dtype=float32), array([0.00812752], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 65 :
#  [array([[ 0.39747882],
#        [-0.41536817]], dtype=float32), array([0.01034652], dtype=float32)]
#
#
#  z:  [3.2 5.7] y:  -1
#
#  w 66 :
#  [array([[ 0.4029393],
#        [-0.4056417]], dtype=float32), array([0.01205291], dtype=float32)]
#
#
#  z:  [2.8 5.1] y:  -1
#
#  w 67 :
#  [array([[ 0.39893472],
#        [-0.41293576]], dtype=float32), array([0.01062271], dtype=float32)]
#
#
#  z:  [2.8 6.7] y:  -1
#
#  w 68 :
#  [array([[ 0.43472037],
#        [-0.3273058 ]], dtype=float32), array([0.0234033], dtype=float32)]
#
#
#  z:  [3.  6.1] y:  -1
#
#  w 69 :
#  [array([[ 0.41486043],
#        [-0.36768767]], dtype=float32), array([0.01678332], dtype=float32)]
#
#
#  z:  [2.8 4.9] y:  -1
#
#  w 70 :
#  [array([[ 0.39376396],
#        [-0.40460652]], dtype=float32), array([0.00924886], dtype=float32)]
#
#
#  z:  [2.3 1.3] y:  1
#
#  w 71 :
#  [array([[ 0.42187375],
#        [-0.38871837]], dtype=float32), array([0.02147051], dtype=float32)]
#
#  72/150 [=============>................] - ETA: 0s - loss: 0.3056
#  z:  [3.1 1.5] y:  1
#
#  w 72 :
#  [array([[ 0.43760926],
#        [-0.3811044 ]], dtype=float32), array([0.02654648], dtype=float32)]
#
#
#  z:  [3.8 1.7] y:  1
#
#  w 73 :
#  [array([[ 0.43444887],
#        [-0.38251826]], dtype=float32), array([0.0257148], dtype=float32)]
#
#
#  z:  [2.5 3. ] y:  -1
#
#  w 74 :
#  [array([[ 0.38623476],
#        [-0.44037518]], dtype=float32), array([0.00642915], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 75 :
#  [array([[ 0.4145567],
#        [-0.426671 ]], dtype=float32), array([0.01556527], dtype=float32)]
#
#
#  z:  [2.9 4.3] y:  -1
#
#  w 76 :
#  [array([[ 0.39233723],
#        [-0.4596171 ]], dtype=float32), array([0.00790338], dtype=float32)]
#
#
#  z:  [3.5 1.3] y:  1
#
#  w 77 :
#  [array([[ 0.40748653],
#        [-0.45399022]], dtype=float32), array([0.01223175], dtype=float32)]
#
#
#  z:  [2.3 3.3] y:  -1
#
#  w 78 :
#  [array([[ 0.3867275],
#        [-0.4837749]], dtype=float32), array([0.00320609], dtype=float32)]
#
#
#  z:  [3.2 4.5] y:  -1
#
#  w 79 :
#  [array([[ 0.3826477 ],
#        [-0.48951212]], dtype=float32), array([0.00193115], dtype=float32)]
#
#
#  z:  [2.5 4.5] y:  -1
#
#  w 80 :
#  [array([[ 0.3948604 ],
#        [-0.46752924]], dtype=float32), array([0.00681624], dtype=float32)]
#
#
#  z:  [2.5 5.8] y:  -1
#
#  w 81 :
#  [array([[ 0.4307455 ],
#        [-0.38427573]], dtype=float32), array([0.02117029], dtype=float32)]
#
#
#  z:  [4.  1.2] y:  1
#
#  w 82 :
#  [array([[ 0.4081038 ],
#        [-0.39106825]], dtype=float32), array([0.01550986], dtype=float32)]
#
#
#  z:  [2.2 4.5] y:  -1
#
#  w 83 :
#  [array([[ 0.4013484 ],
#        [-0.40488604]], dtype=float32), array([0.01243924], dtype=float32)]
#
#  84/150 [===============>..............] - ETA: 0s - loss: 0.2887
#  z:  [3.  5.1] y:  -1
#
#  w 84 :
#  [array([[ 0.39225447],
#        [-0.42034575]], dtype=float32), array([0.00940792], dtype=float32)]
#
#
#  z:  [3.6 1. ] y:  1
#
#  w 85 :
#  [array([[ 0.39216965],
#        [-0.42036933]], dtype=float32), array([0.00938436], dtype=float32)]
#
#
#  z:  [3.  5.5] y:  -1
#
#  w 86 :
#  [array([[ 0.39973792],
#        [-0.40649414]], dtype=float32), array([0.01190712], dtype=float32)]
#
#
#  z:  [3.3 6. ] y:  -1
#
#  w 87 :
#  [array([[ 0.4068608 ],
#        [-0.39354342]], dtype=float32), array([0.01406557], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 88 :
#  [array([[ 0.42265564],
#        [-0.38611054]], dtype=float32), array([0.01871111], dtype=float32)]
#
#
#  z:  [2.5 5. ] y:  -1
#
#  w 89 :
#  [array([[ 0.41541576],
#        [-0.4005903 ]], dtype=float32), array([0.01581516], dtype=float32)]
#
#
#  z:  [2.8 4.1] y:  -1
#
#  w 90 :
#  [array([[ 0.38536847],
#        [-0.44458815]], dtype=float32), array([0.00508398], dtype=float32)]
#
#
#  z:  [3.  1.4] y:  1
#
#  w 91 :
#  [array([[ 0.41304252],
#        [-0.43167362]], dtype=float32), array([0.01430866], dtype=float32)]
#
#  92/150 [=================>............] - ETA: 0s - loss: 0.2705
#  z:  [3.8 6.4] y:  -1
#
#  w 92 :
#  [array([[ 0.42663443],
#        [-0.40878195]], dtype=float32), array([0.01788548], dtype=float32)]
#
#
#  z:  [3.  1.3] y:  1
#
#  w 93 :
#  [array([[ 0.4406521 ],
#        [-0.40270764]], dtype=float32), array([0.02255804], dtype=float32)]
#
#
#  z:  [2.9 4.3] y:  -1
#
#  w 94 :
#  [array([[ 0.40766135],
#        [-0.45162496]], dtype=float32), array([0.01118191], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 95 :
#  [array([[ 0.41799802],
#        [-0.43210018]], dtype=float32), array([0.01501031], dtype=float32)]
#
#
#  z:  [3.3 1.4] y:  1
#
#  w 96 :
#  [array([[ 0.4318934 ],
#        [-0.42620516]], dtype=float32), array([0.01922104], dtype=float32)]
#
#
#  z:  [3.1 5.6] y:  -1
#
#  w 97 :
#  [array([[ 0.43367022],
#        [-0.42299545]], dtype=float32), array([0.0197942], dtype=float32)]
#
#
#  z:  [3.3 1.7] y:  1
#
#  w 98 :
#  [array([[ 0.45137054],
#        [-0.4138771 ]], dtype=float32), array([0.02515793], dtype=float32)]
#
#
#  z:  [2.7 4.2] y:  -1
#
#  w 99 :
#  [array([[ 0.4240695 ],
#        [-0.45634538]], dtype=float32), array([0.01504643], dtype=float32)]
#
#
#  z:  [2.4 3.8] y:  -1
#
#  w 100 :
#  [array([[ 0.40973186],
#        [-0.47904664]], dtype=float32), array([0.00907242], dtype=float32)]
#
#
#  z:  [2.5 5. ] y:  -1
#
#  w 101 :
#  [array([[ 0.42782342],
#        [-0.44286352]], dtype=float32), array([0.01630904], dtype=float32)]
#
# 102/150 [===================>..........] - ETA: 0s - loss: 0.2538
#  z:  [2.7 4.9] y:  -1
#
#  w 102 :
#  [array([[ 0.4277478 ],
#        [-0.44300082]], dtype=float32), array([0.01628102], dtype=float32)]
#
#
#  z:  [2.8 4.8] y:  -1
#
#  w 103 :
#  [array([[ 0.4228438],
#        [-0.4514076]], dtype=float32), array([0.0145296], dtype=float32)]
#
#
#  z:  [3.4 1.6] y:  1
#
#  w 104 :
#  [array([[ 0.44120747],
#        [-0.4427659 ]], dtype=float32), array([0.01993067], dtype=float32)]
#
#
#  z:  [3.  5.8] y:  -1
#
#  w 105 :
#  [array([[ 0.4546768 ],
#        [-0.41672516]], dtype=float32), array([0.02442046], dtype=float32)]
#
#
#  z:  [2.5 4.9] y:  -1
#
#  w 106 :
#  [array([[ 0.44871885],
#        [-0.42840275]], dtype=float32), array([0.02203727], dtype=float32)]
#
#
#  z:  [2.3 4.4] y:  -1
#
#  w 107 :
#  [array([[ 0.4409394 ],
#        [-0.44328517]], dtype=float32), array([0.0186549], dtype=float32)]
#
#
#  z:  [2.4 3.7] y:  -1
#
#  w 108 :
#  [array([[ 0.4199752 ],
#        [-0.47560498]], dtype=float32), array([0.00991982], dtype=float32)]
#
#
#  z:  [3.  5.8] y:  -1
#
#  w 109 :
#  [array([[ 0.449295],
#        [-0.41892 ]], dtype=float32), array([0.01969309], dtype=float32)]
#
#
#  z:  [3.9 1.3] y:  1
#
#  w 110 :
#  [array([[ 0.4315619 ],
#        [-0.42483106]], dtype=float32), array([0.01514614], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 111 :
#  [array([[ 0.44208762],
#        [-0.42018735]], dtype=float32), array([0.01824194], dtype=float32)]
#
# 112/150 [=====================>........] - ETA: 0s - loss: 0.2373
#  z:  [3.4 1.5] y:  1
#
#  w 112 :
#  [array([[ 0.4494956],
#        [-0.4169191]], dtype=float32), array([0.02042076], dtype=float32)]
#
#
#  z:  [3.  4.4] y:  -1
#
#  w 113 :
#  [array([[ 0.4174278],
#        [-0.4639519]], dtype=float32), array([0.00973149], dtype=float32)]
#
#
#  z:  [2.7 5.1] y:  -1
#
#  w 114 :
#  [array([[ 0.42981368],
#        [-0.44055635]], dtype=float32), array([0.01431885], dtype=float32)]
#
#
#  z:  [3.1 5.4] y:  -1
#
#  w 115 :
#  [array([[ 0.431814  ],
#        [-0.43707195]], dtype=float32), array([0.01496411], dtype=float32)]
#
#
#  z:  [2.  3.5] y:  -1
#
#  w 116 :
#  [array([[ 0.4178604 ],
#        [-0.46149078]], dtype=float32), array([0.0079873], dtype=float32)]
#
#
#  z:  [4.2 1.4] y:  1
#
#  w 117 :
#  [array([[ 0.40803963],
#        [-0.46476436]], dtype=float32), array([0.00564903], dtype=float32)]
#
#
#  z:  [2.8 4. ] y:  -1
#
#  w 118 :
#  [array([[ 0.39184988],
#        [-0.48789257]], dtype=float32), array([-0.00013302], dtype=float32)]
#
#
#  z:  [3.2 1.4] y:  1
#
#  w 119 :
#  [array([[ 0.4193227],
#        [-0.4758732]], dtype=float32), array([0.00845224], dtype=float32)]
#  z:  [3.8 1.9] y:  1
#
#  w 120 :
#  [array([[ 0.44229603],
#        [-0.46438655]], dtype=float32), array([0.01449785], dtype=float32)]
#
#
#  z:  [4.1 1.5] y:  1
#
#  w 121 :
#  [array([[ 0.43152684],
#        [-0.4683265 ]], dtype=float32), array([0.01187122], dtype=float32)]
#
#
#  z:  [2.9 4.2] y:  -1
#
#  w 122 :
#  [array([[ 0.41433984],
#        [-0.49321803]], dtype=float32), array([0.00594466], dtype=float32)]
#
# 123/150 [=======================>......] - ETA: 0s - loss: 0.2252
#  z:  [3.4 1.7] y:  1
#
#  w 123 :
#  [array([[ 0.44315624],
#        [-0.47880983]], dtype=float32), array([0.01442007], dtype=float32)]
#
#
#  z:  [3.4 5.4] y:  -1
#
#  w 124 :
#  [array([[ 0.44753695],
#        [-0.47185227]], dtype=float32), array([0.01570851], dtype=float32)]
#
#
#  z:  [2.8 6.1] y:  -1
#
#  w 125 :
#  [array([[ 0.4816682 ],
#        [-0.39749488]], dtype=float32), array([0.02789824], dtype=float32)]
#
#
#  z:  [3.3 4.7] y:  -1
#
#  w 126 :
#  [array([[ 0.4322225 ],
#        [-0.46791756]], dtype=float32), array([0.01291469], dtype=float32)]
#
#
#  z:  [3.4 1.4] y:  1
#
#  w 127 :
#  [array([[ 0.4439602],
#        [-0.4630844]], dtype=float32), array([0.01636696], dtype=float32)]
#
#
#  z:  [2.6 5.6] y:  -1
#
#  w 128 :
#  [array([[ 0.4659359 ],
#        [-0.41575217]], dtype=float32), array([0.02481915], dtype=float32)]
#
#
#  z:  [3.  4.2] y:  -1
#
#  w 129 :
#  [array([[ 0.42534783],
#        [-0.47257546]], dtype=float32), array([0.0112898], dtype=float32)]
#
#
#  z:  [2.7 4.1] y:  -1
#
#  w 130 :
#  [array([[ 0.41335067],
#        [-0.49079335]], dtype=float32), array([0.0068464], dtype=float32)]
#
#
#  z:  [3.2 5.3] y:  -1
#
#  w 131 :
#  [array([[ 0.43073538],
#        [-0.4619999 ]], dtype=float32), array([0.01227913], dtype=float32)]
#
#
#  z:  [4.4 1.5] y:  1
#
#  w 132 :
#  [array([[ 0.41185805],
#        [-0.46843535]], dtype=float32), array([0.00798883], dtype=float32)]
#
# 133/150 [=========================>....] - ETA: 0s - loss: 0.2231
#  z:  [2.9 1.4] y:  1
#
#  w 133 :
#  [array([[ 0.4381571 ],
#        [-0.45573926]], dtype=float32), array([0.01705747], dtype=float32)]
#
#
#  z:  [3.1 4.9] y:  -1
#
#  w 134 :
#  [array([[ 0.42933935],
#        [-0.46967703]], dtype=float32), array([0.01421303], dtype=float32)]
#
#
#  z:  [2.6 4.4] y:  -1
#
#  w 135 :
#  [array([[ 0.4260157 ],
#        [-0.47530168]], dtype=float32), array([0.01293471], dtype=float32)]
#
#
#  z:  [3.  4.5] y:  -1
#
#  w 136 :
#  [array([[ 0.41688827],
#        [-0.48899287]], dtype=float32), array([0.00989222], dtype=float32)]
#
#
#  z:  [3.6 1.4] y:  1
#
#  w 137 :
#  [array([[ 0.42940906],
#        [-0.48412368]], dtype=float32), array([0.01337022], dtype=float32)]
#
#
#  z:  [2.5 3.9] y:  -1
#
#  w 138 :
#  [array([[ 0.41946852],
#        [-0.4996309 ]], dtype=float32), array([0.00939401], dtype=float32)]
#
#
#  z:  [3.2 1.6] y:  1
#
#  w 139 :
#  [array([[ 0.44812235],
#        [-0.485304  ]], dtype=float32), array([0.01834833], dtype=float32)]
#
#
#  z:  [2.4 3.3] y:  -1
#
#  w 140 :
#  [array([[ 0.4244901 ],
#        [-0.51779836]], dtype=float32), array([0.00850155], dtype=float32)]
#
#
#  z:  [2.9 4.6] y:  -1
#
#  w 141 :
#  [array([[ 0.43274638],
#        [-0.5047022 ]], dtype=float32), array([0.01134855], dtype=float32)]
#
#
#  z:  [2.6 3.5] y:  -1
#
#  w 142 :
#  [array([[ 0.41350475],
#        [-0.5306044 ]], dtype=float32), array([0.00394792], dtype=float32)]
#
# 143/150 [===========================>..] - ETA: 0s - loss: 0.2129
#  z:  [2.8 4.5] y:  -1
#
#  w 143 :
#  [array([[ 0.42615843],
#        [-0.51026815]], dtype=float32), array([0.00846709], dtype=float32)]
#
#
#  z:  [3.5 1.4] y:  1
#
#  w 144 :
#  [array([[ 0.44116318],
#        [-0.50426626]], dtype=float32), array([0.01275417], dtype=float32)]
#
#
#  z:  [3.  5.9] y:  -1
#
#  w 145 :
#  [array([[ 0.47949883],
#        [-0.42887282]], dtype=float32), array([0.02553272], dtype=float32)]
#
#
#  z:  [2.8 5.6] y:  -1
#
#  w 146 :
#  [array([[ 0.4813781 ],
#        [-0.42511427]], dtype=float32), array([0.02620388], dtype=float32)]
#
#
#  z:  [3.7 1.5] y:  1
#
#  w 147 :
#  [array([[ 0.46882537],
#        [-0.43020323]], dtype=float32), array([0.02281125], dtype=float32)]
#
#
#  z:  [3.4 4.5] y:  -1
#
#  w 148 :
#  [array([[ 0.42252395],
#        [-0.4914845 ]], dtype=float32), array([0.00919319], dtype=float32)]
#
#
#  z:  [3.2 6. ] y:  -1
#
#  w 149 :
#  [array([[ 0.46013272],
#        [-0.42096806]], dtype=float32), array([0.02094593], dtype=float32)]
#
#
#  z:  [3.4 5.6] y:  -1
# 150/150 [==============================] - 1s 5ms/step - loss: 0.2119

# %% [markdown]
# ### Problem 2.
# a. Using keras and gradient descent, simulate a 1-neuron network that mimics support vector machine (namely minimize hinge loss, but add in l2 regularization for the model weights). You will have to look up the documentation on keras.regularizers (if you fail to figure this out, email me with the steps you tried).

# %%
from keras import regularizers
from keras.losses import hinge


iris_lr = Sequential([
    Dense(1, input_shape=(2,), 
          kernel_regularizer=regularizers.l2(0.001)),
    Activation('linear'),
    
])

opt = SGD(lr=0.01,momentum=0,nesterov=False)

iris_lr.compile(optimizer=opt,
              loss = hinge,
              metrics = ['categorical_accuracy'])

# %% [markdown]
# b. As before, test your algorithm on the Iris dataset above to classify non-linearly separable classes. Again, check if the gradients are what you expect by checking the weights before and after an example using callbacks as above.

# %%
print_weights = LambdaCallback(on_batch_begin=lambda batch, logs: print('\n w',batch,': \n',iris_lr.layers[0].get_weights(),'\n'))
print_examples = LambdaCallback(on_batch_end = lambda batch, logs: print('\n z: ',training[batch,:],'y: ', labels[batch]))

iris_lr.layers[0].set_weights([np.array([[0.01],[0.01]]),np.array([0.0])])



####################
## Non Linearly seperable
###################
print("=================== Non Linear ===================")


iris_lr.fit(color_train, color_target, epochs=40, batch_size=10,callbacks = [ print_weights, print_examples ], shuffle=False)

lr = iris_lr.layers[0].get_weights()

fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 2, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(lr[1][0]+lr[0][0,0]*x)/lr[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)


####################
## CAlls backs
###################
print("=================== CALLS BACKS ===================")

iris_lr.fit(training, labels, epochs=100, batch_size=32,callbacks = [ print_weights, print_examples ], shuffle=False)

lr = iris_lr.layers[0].get_weights()

fig = plt.figure()
ax2 = plt.axes()
figiris = ax2.scatter(iris.data[:,1],iris.data[:,2],c=np.where(iris.target == 0, 0,1))
ax2.set_xlabel(iris.feature_names[1]+' (1)')
ax2.set_ylabel(iris.feature_names[2]+' (2)')
x = np.linspace(2,4.5,100)
plt.plot(x, -(lr[1][0]+lr[0][0,0]*x)/lr[0][1,0])
# this adjusts the space around the plot so we can read the z label
plt.gcf().subplots_adjust(left=-0.5,bottom=-0.3)

plt.colorbar(figiris)
ax.view_init(45,45)
# Out:
# =================== Non Linear ===================
# Epoch 1/40
#
#  w 0 :
#  [array([[0.01],
#        [0.01]], dtype=float32), array([0.], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 1s - loss: 1.0058 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[0.0027998],
#        [0.0113998]], dtype=float32), array([-0.002], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.02180025],
#        [-0.01240043]], dtype=float32), array([-0.01], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.02199982],
#        [-0.01730018]], dtype=float32), array([-0.01], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.04809938],
#        [-0.04159983]], dtype=float32), array([-0.018], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.06549841],
#        [-0.065599  ]], dtype=float32), array([-0.024], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.0721971 ],
#        [-0.07389769]], dtype=float32), array([-0.026], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.10289565],
#        [-0.11349621]], dtype=float32), array([-0.036], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.1031936 ],
#        [-0.11759394]], dtype=float32), array([-0.036], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.10479153],
#        [-0.12439159]], dtype=float32), array([-0.037], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.10298944],
#        [-0.1193891 ]], dtype=float32), array([-0.036], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.11198737],
#        [-0.12558672]], dtype=float32), array([-0.039], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.10298514],
#        [-0.12438421]], dtype=float32), array([-0.037], dtype=float32)]
#
# 130/150 [=========================>....] - ETA: 0s - loss: 0.8547 - categorical_accuracy: 1.0000
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.12088308],
#        [-0.13648172]], dtype=float32), array([-0.043], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.10848066],
#        [-0.11977899]], dtype=float32), array([-0.039], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 959us/step - loss: 0.8629 - categorical_accuracy: 1.0000
# Epoch 2/40
#
#  w 0 :
#  [array([[-0.11327849],
#        [-0.12837659]], dtype=float32), array([-0.041], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9394 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.11457623],
#        [-0.11637402]], dtype=float32), array([-0.041], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.13597393],
#        [-0.1344717 ]], dtype=float32), array([-0.048], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.12317121],
#        [-0.11806901]], dtype=float32), array([-0.044], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.14306875],
#        [-0.13146664]], dtype=float32), array([-0.05], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.14836589],
#        [-0.13386402]], dtype=float32), array([-0.052], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.14366291],
#        [-0.12066134]], dtype=float32), array([-0.05], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.15896004],
#        [-0.13275893]], dtype=float32), array([-0.055], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.14995687],
#        [-0.12145627]], dtype=float32), array([-0.052], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.14235386],
#        [-0.11345384]], dtype=float32), array([-0.05], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.13455102],
#        [-0.09805158]], dtype=float32), array([-0.047], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.14644833],
#        [-0.10984962]], dtype=float32), array([-0.051], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.7234 - categorical_accuracy: 1.0000
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.1347454 ],
#        [-0.10354742]], dtype=float32), array([-0.048], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.15264271],
#        [-0.11564535]], dtype=float32), array([-0.054], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.14023966],
#        [-0.09894304]], dtype=float32), array([-0.05], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 487us/step - loss: 0.7418 - categorical_accuracy: 1.0000
# Epoch 3/40
#
#  w 0 :
#  [array([[-0.14503685],
#        [-0.10754106]], dtype=float32), array([-0.052], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.9102 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.14633395],
#        [-0.09553891]], dtype=float32), array([-0.052], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.16773102],
#        [-0.113637  ]], dtype=float32), array([-0.059], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.15492766],
#        [-0.09723473]], dtype=float32), array([-0.055], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.17482457],
#        [-0.11063278]], dtype=float32), array([-0.061], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.18012106],
#        [-0.11303058]], dtype=float32), array([-0.063], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.17541745],
#        [-0.09982832]], dtype=float32), array([-0.061], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.19071394],
#        [-0.11192632]], dtype=float32), array([-0.066], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.17621014],
#        [-0.09302408]], dtype=float32), array([-0.061], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.16860661],
#        [-0.08502222]], dtype=float32), array([-0.059], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.16080324],
#        [-0.06962052]], dtype=float32), array([-0.056], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.17830002],
#        [-0.09441913]], dtype=float32), array([-0.062], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.7131 - categorical_accuracy: 1.0000
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.16659646],
#        [-0.08811724]], dtype=float32), array([-0.059], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.18449312],
#        [-0.10021548]], dtype=float32), array([-0.06500001], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.17208943],
#        [-0.08351348]], dtype=float32), array([-0.061], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 481us/step - loss: 0.7315 - categorical_accuracy: 1.0000
# Epoch 4/40
#
#  w 0 :
#  [array([[-0.17688599],
#        [-0.0921118 ]], dtype=float32), array([-0.063], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8876 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.17818245],
#        [-0.08010996]], dtype=float32), array([-0.063], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.19957888],
#        [-0.09820836]], dtype=float32), array([-0.07], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.1867749 ],
#        [-0.08180639]], dtype=float32), array([-0.066], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.20667116],
#        [-0.09520476]], dtype=float32), array([-0.072], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.21196704],
#        [-0.09760285]], dtype=float32), array([-0.07399999], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.2034628],
#        [-0.0828009]], dtype=float32), array([-0.07099999], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.21585873],
#        [-0.09059925]], dtype=float32), array([-0.075], dtype=float32)]
#
#  80/150 [===============>..............] - ETA: 0s - loss: 0.6147 - categorical_accuracy: 1.0000
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.20395441],
#        [-0.07569744]], dtype=float32), array([-0.07099999], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.19635034],
#        [-0.06769592]], dtype=float32), array([-0.069], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.1885464 ],
#        [-0.05229457]], dtype=float32), array([-0.066], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.20604263],
#        [-0.07709353]], dtype=float32), array([-0.072], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.19153851],
#        [-0.06619199]], dtype=float32), array([-0.068], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.20943469],
#        [-0.07829066]], dtype=float32), array([-0.07399999], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.1970305],
#        [-0.0615891]], dtype=float32), array([-0.06999999], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 628us/step - loss: 0.7222 - categorical_accuracy: 1.0000
# Epoch 5/40
#
#  w 0 :
#  [array([[-0.20482656],
#        [-0.07568787]], dtype=float32), array([-0.07299999], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8642 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.20612247],
#        [-0.06368636]], dtype=float32), array([-0.07299999], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.22751835],
#        [-0.08178508]], dtype=float32), array([-0.07999999], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.2147138 ],
#        [-0.06538345]], dtype=float32), array([-0.07599999], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.2306095 ],
#        [-0.07758214]], dtype=float32), array([-0.08099999], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.23590489],
#        [-0.07998059]], dtype=float32), array([-0.08299999], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.22380017],
#        [-0.06417899]], dtype=float32), array([-0.07899999], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.23619568],
#        [-0.0719777 ]], dtype=float32), array([-0.08299999], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.22429095],
#        [-0.05707626]], dtype=float32), array([-0.07899999], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.21668647],
#        [-0.04907512]], dtype=float32), array([-0.07699999], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.21488214],
#        [-0.04407414]], dtype=float32), array([-0.07599999], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.23237784],
#        [-0.06887326]], dtype=float32), array([-0.08199999], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.6936 - categorical_accuracy: 1.0000
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.2178732 ],
#        [-0.05797188]], dtype=float32), array([-0.07799999], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.23186885],
#        [-0.06837072]], dtype=float32), array([-0.08299999], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.21946421],
#        [-0.05166936]], dtype=float32), array([-0.07899999], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 484us/step - loss: 0.7125 - categorical_accuracy: 1.0000
# Epoch 6/40
#
#  w 0 :
#  [array([[-0.22425982],
#        [-0.06026832]], dtype=float32), array([-0.08099999], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8468 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.22175534],
#        [-0.04656712]], dtype=float32), array([-0.07999998], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.2431509 ],
#        [-0.06466618]], dtype=float32), array([-0.08699998], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.22694604],
#        [-0.04676489]], dtype=float32), array([-0.08199998], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.2458415 ],
#        [-0.06396395]], dtype=float32), array([-0.08799998], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.24783659],
#        [-0.06466267]], dtype=float32), array([-0.08899998], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.23573163],
#        [-0.04886138]], dtype=float32), array([-0.08499998], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.25382692],
#        [-0.0660604 ]], dtype=float32), array([-0.09099998], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.23932184],
#        [-0.04715908]], dtype=float32), array([-0.08599997], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.23171705],
#        [-0.03915814]], dtype=float32), array([-0.08399998], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.22611241],
#        [-0.03265736]], dtype=float32), array([-0.08199998], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.6420 - categorical_accuracy: 1.0000
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.2436079 ],
#        [-0.05745671]], dtype=float32), array([-0.08799998], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.22910303],
#        [-0.04655556]], dtype=float32), array([-0.08399998], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.24309845],
#        [-0.05695463]], dtype=float32), array([-0.08899998], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.2306936 ],
#        [-0.04025349]], dtype=float32), array([-0.08499998], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 545us/step - loss: 0.7115 - categorical_accuracy: 1.0000
# Epoch 7/40
#
#  w 0 :
#  [array([[-0.23848899],
#        [-0.05435269]], dtype=float32), array([-0.08799998], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8429 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23598422],
#        [-0.0406516 ]], dtype=float32), array([-0.08699998], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.2536795 ],
#        [-0.05725078]], dtype=float32), array([-0.09299997], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.23747444],
#        [-0.03934964]], dtype=float32), array([-0.08799997], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25636968],
#        [-0.05654885]], dtype=float32), array([-0.09399997], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.25836456],
#        [-0.05724772]], dtype=float32), array([-0.09499997], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24625939],
#        [-0.04144657]], dtype=float32), array([-0.09099997], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26085445],
#        [-0.05734575]], dtype=float32), array([-0.09599997], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.24634923],
#        [-0.0384446 ]], dtype=float32), array([-0.09099997], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.2387443 ],
#        [-0.03044383]], dtype=float32), array([-0.08899997], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23313953],
#        [-0.02394322]], dtype=float32), array([-0.08699998], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25063488],
#        [-0.04874275]], dtype=float32), array([-0.09299997], dtype=float32)]
#
# 120/150 [=======================>......] - ETA: 0s - loss: 0.6899 - categorical_accuracy: 1.0000
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.23612987],
#        [-0.03784177]], dtype=float32), array([-0.08899997], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.25012514],
#        [-0.04824101]], dtype=float32), array([-0.09399997], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.23772013],
#        [-0.03154005]], dtype=float32), array([-0.08999997], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 491us/step - loss: 0.7092 - categorical_accuracy: 1.0000
# Epoch 8/40
#
#  w 0 :
#  [array([[-0.24181537],
#        [-0.04413942]], dtype=float32), array([-0.09199997], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8308 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23861054],
#        [-0.03413853]], dtype=float32), array([-0.09099997], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.25630575],
#        [-0.05073785]], dtype=float32), array([-0.09699997], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.24010062],
#        [-0.03283684]], dtype=float32), array([-0.09199996], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25899583],
#        [-0.05003618]], dtype=float32), array([-0.09799996], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.26099065],
#        [-0.05073518]], dtype=float32), array([-0.09899996], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24888542],
#        [-0.03493416]], dtype=float32), array([-0.09499996], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26628044],
#        [-0.05643346]], dtype=float32), array([-0.10099996], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.25177512],
#        [-0.03753233]], dtype=float32), array([-0.09599996], dtype=float32)]
#  90/150 [=================>............] - ETA: 0s - loss: 0.6197 - categorical_accuracy: 1.0000
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24077009],
#        [-0.02793158]], dtype=float32), array([-0.09299996], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23516527],
#        [-0.02143102]], dtype=float32), array([-0.09099996], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25266057],
#        [-0.0462306 ]], dtype=float32), array([-0.09699996], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.23815551],
#        [-0.03532967]], dtype=float32), array([-0.09299996], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.25215074],
#        [-0.04572896]], dtype=float32), array([-0.09799996], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.2397457 ],
#        [-0.02902805]], dtype=float32), array([-0.09399996], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 623us/step - loss: 0.7095 - categorical_accuracy: 1.0000
# Epoch 9/40
#
#  w 0 :
#  [array([[-0.24384092],
#        [-0.04162747]], dtype=float32), array([-0.09599996], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8293 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.24063604],
#        [-0.03162663]], dtype=float32), array([-0.09499995], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.2583312],
#        [-0.048226 ]], dtype=float32), array([-0.10099995], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.24212605],
#        [-0.03032504]], dtype=float32), array([-0.09599995], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.2610212 ],
#        [-0.04752443]], dtype=float32), array([-0.10199995], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.263016  ],
#        [-0.04822348]], dtype=float32), array([-0.10299995], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.25091073],
#        [-0.03242252]], dtype=float32), array([-0.09899995], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26830572],
#        [-0.05392186]], dtype=float32), array([-0.10499994], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.25380036],
#        [-0.03502078]], dtype=float32), array([-0.09999994], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24279529],
#        [-0.02542008]], dtype=float32), array([-0.09699994], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23719043],
#        [-0.01891957]], dtype=float32), array([-0.09499995], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.6387 - categorical_accuracy: 1.0000
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25468567],
#        [-0.04371919]], dtype=float32), array([-0.10099994], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.24018058],
#        [-0.03281832]], dtype=float32), array([-0.09699994], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.25417578],
#        [-0.04321766]], dtype=float32), array([-0.10199995], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.2417707],
#        [-0.0265168]], dtype=float32), array([-0.09799995], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 536us/step - loss: 0.7094 - categorical_accuracy: 1.0000
# Epoch 10/40
#
#  w 0 :
#  [array([[-0.24526587],
#        [-0.04431627]], dtype=float32), array([-0.09999994], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8341 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23926097],
#        [-0.02921538]], dtype=float32), array([-0.09799995], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.2569562],
#        [-0.0458148]], dtype=float32), array([-0.10399994], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.24075106],
#        [-0.02791388]], dtype=float32), array([-0.09899994], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25964624],
#        [-0.04511333]], dtype=float32), array([-0.10499994], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.26164106],
#        [-0.04581242]], dtype=float32), array([-0.10599994], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24953583],
#        [-0.03001151]], dtype=float32), array([-0.10199994], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26993084],
#        [-0.05611091]], dtype=float32), array([-0.10899994], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.25542545],
#        [-0.03720979]], dtype=float32), array([-0.10399994], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24442035],
#        [-0.02760904]], dtype=float32), array([-0.10099994], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.6574 - categorical_accuracy: 1.0000
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23881546],
#        [-0.02110849]], dtype=float32), array([-0.09899994], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25631067],
#        [-0.04590807]], dtype=float32), array([-0.10499994], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.24180554],
#        [-0.03500715]], dtype=float32), array([-0.10099994], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.2558007 ],
#        [-0.04540645]], dtype=float32), array([-0.10599994], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.24339558],
#        [-0.02870555]], dtype=float32), array([-0.10199994], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 686us/step - loss: 0.7109 - categorical_accuracy: 1.0000
# Epoch 11/40
#
#  w 0 :
#  [array([[-0.24389072],
#        [-0.03990497]], dtype=float32), array([-0.10299994], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8283 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.24068584],
#        [-0.02990417]], dtype=float32), array([-0.10199994], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.258381  ],
#        [-0.04650357]], dtype=float32), array([-0.10799994], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.24217585],
#        [-0.02860264]], dtype=float32), array([-0.10299993], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.261071  ],
#        [-0.04580207]], dtype=float32), array([-0.10899993], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.2630658 ],
#        [-0.04650116]], dtype=float32), array([-0.10999993], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.25096053],
#        [-0.03070023]], dtype=float32), array([-0.10599993], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26835552],
#        [-0.05219961]], dtype=float32), array([-0.11199993], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.25385016],
#        [-0.03329857]], dtype=float32), array([-0.10699993], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.6188 - categorical_accuracy: 1.0000
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24284509],
#        [-0.0236979 ]], dtype=float32), array([-0.10399993], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23724023],
#        [-0.01719743]], dtype=float32), array([-0.10199993], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25473547],
#        [-0.04199708]], dtype=float32), array([-0.10799993], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.24023038],
#        [-0.03109624]], dtype=float32), array([-0.10399993], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.25422558],
#        [-0.04149562]], dtype=float32), array([-0.10899993], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.2418205 ],
#        [-0.02479479]], dtype=float32), array([-0.10499993], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 647us/step - loss: 0.7093 - categorical_accuracy: 1.0000
# Epoch 12/40
#
#  w 0 :
#  [array([[-0.24531567],
#        [-0.0425943 ]], dtype=float32), array([-0.10699993], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8330 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23931077],
#        [-0.02749345]], dtype=float32), array([-0.10499993], dtype=float32)]
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.257006 ],
#        [-0.0440929]], dtype=float32), array([-0.11099993], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.24080086],
#        [-0.02619202]], dtype=float32), array([-0.10599992], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25969604],
#        [-0.04339149]], dtype=float32), array([-0.11199992], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.26169086],
#        [-0.04409062]], dtype=float32), array([-0.11299992], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24958563],
#        [-0.02828974]], dtype=float32), array([-0.10899992], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26998064],
#        [-0.05438918]], dtype=float32), array([-0.11599992], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.25547525],
#        [-0.03548809]], dtype=float32), array([-0.11099992], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.6217 - categorical_accuracy: 1.0000
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24447015],
#        [-0.02588738]], dtype=float32), array([-0.10799992], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23886526],
#        [-0.01938686]], dtype=float32), array([-0.10599992], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25636047],
#        [-0.04418647]], dtype=float32), array([-0.11199992], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.24185534],
#        [-0.03328559]], dtype=float32), array([-0.10799992], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.2558505 ],
#        [-0.04368492]], dtype=float32), array([-0.11299992], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.24344538],
#        [-0.02698405]], dtype=float32), array([-0.10899992], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 638us/step - loss: 0.7107 - categorical_accuracy: 1.0000
# Epoch 13/40
#
#  w 0 :
#  [array([[-0.24394052],
#        [-0.03818351]], dtype=float32), array([-0.10999992], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8273 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.24073564],
#        [-0.02818274]], dtype=float32), array([-0.10899992], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.2584308 ],
#        [-0.04478218]], dtype=float32), array([-0.11499992], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.24222565],
#        [-0.02688129]], dtype=float32), array([-0.10999992], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.2611208 ],
#        [-0.04408075]], dtype=float32), array([-0.11599991], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.26311558],
#        [-0.04477986]], dtype=float32), array([-0.11699992], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.25101033],
#        [-0.02897897]], dtype=float32), array([-0.11299992], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.2714053 ],
#        [-0.05507839]], dtype=float32), array([-0.11999992], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.2568999 ],
#        [-0.03617729]], dtype=float32), array([-0.11499991], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.6208 - categorical_accuracy: 1.0000
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24589476],
#        [-0.02657656]], dtype=float32), array([-0.11199991], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.24028984],
#        [-0.02007603]], dtype=float32), array([-0.10999992], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25778502],
#        [-0.04487563]], dtype=float32), array([-0.11599991], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.24327986],
#        [-0.03397473]], dtype=float32), array([-0.11199991], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.257275  ],
#        [-0.04437405]], dtype=float32), array([-0.11699992], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.24486984],
#        [-0.02767316]], dtype=float32), array([-0.11299992], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 763us/step - loss: 0.7101 - categorical_accuracy: 1.0000
# Epoch 14/40
#
#  w 0 :
#  [array([[-0.24536495],
#        [-0.03887261]], dtype=float32), array([-0.11399992], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8289 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.24216004],
#        [-0.02887183]], dtype=float32), array([-0.11299992], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.2563552 ],
#        [-0.04387125]], dtype=float32), array([-0.11799992], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.24015006],
#        [-0.02597038]], dtype=float32), array([-0.11299992], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25904527],
#        [-0.04316986]], dtype=float32), array([-0.11899991], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.2610401 ],
#        [-0.04386899]], dtype=float32), array([-0.11999992], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24893486],
#        [-0.02806812]], dtype=float32), array([-0.11599991], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26932988],
#        [-0.05416755]], dtype=float32), array([-0.12299991], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.2548245 ],
#        [-0.03526647]], dtype=float32), array([-0.11799991], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24381939],
#        [-0.02566576]], dtype=float32), array([-0.11499991], dtype=float32)]
#
# 100/150 [===================>..........] - ETA: 0s - loss: 0.6557 - categorical_accuracy: 1.0000
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23821451],
#        [-0.01916525]], dtype=float32), array([-0.11299992], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25570974],
#        [-0.04396487]], dtype=float32), array([-0.11899991], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.24120462],
#        [-0.03306399]], dtype=float32), array([-0.11499991], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.2551998 ],
#        [-0.04346333]], dtype=float32), array([-0.11999992], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.24279469],
#        [-0.02676246]], dtype=float32), array([-0.11599991], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 660us/step - loss: 0.7096 - categorical_accuracy: 1.0000
# Epoch 15/40
#
#  w 0 :
#  [array([[-0.24328984],
#        [-0.03796192]], dtype=float32), array([-0.11699992], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8276 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.24008498],
#        [-0.02796116]], dtype=float32), array([-0.11599991], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.25428018],
#        [-0.04296061]], dtype=float32), array([-0.12099992], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.23807509],
#        [-0.02505975]], dtype=float32), array([-0.11599991], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25697035],
#        [-0.04225925]], dtype=float32), array([-0.12199991], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.2589652],
#        [-0.0429584]], dtype=float32), array([-0.12299991], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24686001],
#        [-0.02715754]], dtype=float32), array([-0.11899991], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26725507],
#        [-0.053257  ]], dtype=float32), array([-0.12599991], dtype=float32)]
#
#  80/150 [===============>..............] - ETA: 0s - loss: 0.5914 - categorical_accuracy: 1.0000
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.2527497 ],
#        [-0.03435593]], dtype=float32), array([-0.12099991], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24174465],
#        [-0.02475524]], dtype=float32), array([-0.11799991], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23613982],
#        [-0.01825475]], dtype=float32), array([-0.11599991], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#  w 11 :
#  [array([[-0.2536351 ],
#        [-0.04305439]], dtype=float32), array([-0.12199991], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.23913004],
#        [-0.03215352]], dtype=float32), array([-0.11799991], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.25312525],
#        [-0.04255288]], dtype=float32), array([-0.12299991], dtype=float32)]
#
# 140/150 [===========================>..] - ETA: 0s - loss: 0.7140 - categorical_accuracy: 1.0000
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.24072018],
#        [-0.02585203]], dtype=float32), array([-0.11899991], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 773us/step - loss: 0.7096 - categorical_accuracy: 1.0000
# Epoch 16/40
#
#  w 0 :
#  [array([[-0.24121536],
#        [-0.03705151]], dtype=float32), array([-0.11999992], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8263 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23801054],
#        [-0.02705077]], dtype=float32), array([-0.11899991], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.25570577],
#        [-0.04365023]], dtype=float32), array([-0.12499991], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.23950066],
#        [-0.02574936]], dtype=float32), array([-0.11999991], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25839585],
#        [-0.04294884]], dtype=float32), array([-0.12599991], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.26039067],
#        [-0.04364798]], dtype=float32), array([-0.12699991], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24828546],
#        [-0.02784711]], dtype=float32), array([-0.12299991], dtype=float32)]
#
#  70/150 [=============>................] - ETA: 0s - loss: 0.5253 - categorical_accuracy: 1.0000
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26868048],
#        [-0.05394655]], dtype=float32), array([-0.12999992], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.2541751 ],
#        [-0.03504547]], dtype=float32), array([-0.12499992], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24317001],
#        [-0.02544477]], dtype=float32), array([-0.12199992], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23756514],
#        [-0.01894426]], dtype=float32), array([-0.11999992], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.2550604 ],
#        [-0.04374389]], dtype=float32), array([-0.12599993], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.2405553 ],
#        [-0.03284301]], dtype=float32), array([-0.12199993], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.2545505 ],
#        [-0.04324235]], dtype=float32), array([-0.12699993], dtype=float32)]
#
# 140/150 [===========================>..] - ETA: 0s - loss: 0.7144 - categorical_accuracy: 1.0000
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.24214539],
#        [-0.02654149]], dtype=float32), array([-0.12299993], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 933us/step - loss: 0.7099 - categorical_accuracy: 1.0000
# Epoch 17/40
#
#  w 0 :
#  [array([[-0.24264054],
#        [-0.03774096]], dtype=float32), array([-0.12399993], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8278 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23943569],
#        [-0.0277402 ]], dtype=float32), array([-0.12299993], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.2536309 ],
#        [-0.04273965]], dtype=float32), array([-0.12799993], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.23742583],
#        [-0.02483879]], dtype=float32), array([-0.12299993], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25632107],
#        [-0.0420383 ]], dtype=float32), array([-0.12899993], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.25831595],
#        [-0.04273745]], dtype=float32), array([-0.12999994], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24621078],
#        [-0.0269366 ]], dtype=float32), array([-0.12599994], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26660585],
#        [-0.05303606]], dtype=float32), array([-0.13299994], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.25210053],
#        [-0.034135  ]], dtype=float32), array([-0.12799995], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.6197 - categorical_accuracy: 1.0000
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24109548],
#        [-0.02453432]], dtype=float32), array([-0.12499995], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23549066],
#        [-0.01803383]], dtype=float32), array([-0.12299995], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25298595],
#        [-0.04283347]], dtype=float32), array([-0.12899995], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.2384809 ],
#        [-0.03193261]], dtype=float32), array([-0.12499995], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.25247613],
#        [-0.04233197]], dtype=float32), array([-0.12999995], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.24007107],
#        [-0.02563113]], dtype=float32), array([-0.12599996], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 689us/step - loss: 0.7094 - categorical_accuracy: 1.0000
# Epoch 18/40
#
#  w 0 :
#  [array([[-0.24056627],
#        [-0.03683062]], dtype=float32), array([-0.12699996], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8266 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23736146],
#        [-0.02682988]], dtype=float32), array([-0.12599996], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.2550567 ],
#        [-0.04342934]], dtype=float32), array([-0.13199995], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.2388516 ],
#        [-0.02552848]], dtype=float32), array([-0.12699996], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25424683],
#        [-0.04122797]], dtype=float32), array([-0.13199995], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.25624174],
#        [-0.04192714]], dtype=float32), array([-0.13299996], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24413662],
#        [-0.02612631]], dtype=float32), array([-0.12899996], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26453173],
#        [-0.05222578]], dtype=float32), array([-0.13599996], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.25002643],
#        [-0.03332474]], dtype=float32), array([-0.13099997], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.6194 - categorical_accuracy: 1.0000
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.23902144],
#        [-0.02372408]], dtype=float32), array([-0.12799996], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23341666],
#        [-0.0172236 ]], dtype=float32), array([-0.12599996], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25091198],
#        [-0.04202326]], dtype=float32), array([-0.13199995], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.23640697],
#        [-0.03112242]], dtype=float32), array([-0.12799996], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.25040224],
#        [-0.0415218 ]], dtype=float32), array([-0.13299996], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.23799723],
#        [-0.02482096]], dtype=float32), array([-0.12899996], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 688us/step - loss: 0.7093 - categorical_accuracy: 1.0000
# Epoch 19/40
#
#  w 0 :
#  [array([[-0.23849247],
#        [-0.03602047]], dtype=float32), array([-0.12999997], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8254 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23528771],
#        [-0.02601974]], dtype=float32), array([-0.12899996], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.252983  ],
#        [-0.04261922]], dtype=float32), array([-0.13499996], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#  w 3 :
#  [array([[-0.23677795],
#        [-0.02471837]], dtype=float32), array([-0.12999997], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.2556732 ],
#        [-0.04191788]], dtype=float32), array([-0.13599996], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.25766808],
#        [-0.04261704]], dtype=float32), array([-0.13699996], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24556293],
#        [-0.02681619]], dtype=float32), array([-0.13299997], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.265958  ],
#        [-0.05291565]], dtype=float32), array([-0.13999997], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.25145268],
#        [-0.03401459]], dtype=float32), array([-0.13499998], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.24044766],
#        [-0.02441391]], dtype=float32), array([-0.13199997], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23484285],
#        [-0.01791342]], dtype=float32), array([-0.12999997], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.6387 - categorical_accuracy: 1.0000
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25233817],
#        [-0.04271306]], dtype=float32), array([-0.13599996], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.23783313],
#        [-0.03181221]], dtype=float32), array([-0.13199997], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.25182837],
#        [-0.04221157]], dtype=float32), array([-0.13699996], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.23942333],
#        [-0.02551073]], dtype=float32), array([-0.13299997], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 553us/step - loss: 0.7096 - categorical_accuracy: 1.0000
# Epoch 20/40
#
#  w 0 :
#  [array([[-0.23991854],
#        [-0.03671022]], dtype=float32), array([-0.13399997], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8269 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23671375],
#        [-0.02670948]], dtype=float32), array([-0.13299997], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.25090903],
#        [-0.04170895]], dtype=float32), array([-0.13799997], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.23470402],
#        [-0.02380811]], dtype=float32), array([-0.13299997], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.25359932],
#        [-0.04100764]], dtype=float32), array([-0.13899997], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.25559425],
#        [-0.04170682]], dtype=float32), array([-0.13999997], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.24348915],
#        [-0.02590599]], dtype=float32), array([-0.13599998], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26388428],
#        [-0.05200547]], dtype=float32), array([-0.14299998], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.249379  ],
#        [-0.03310443]], dtype=float32), array([-0.13799998], dtype=float32)]
#
#  90/150 [=================>............] - ETA: 0s - loss: 0.6194 - categorical_accuracy: 1.0000
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.23837401],
#        [-0.02350377]], dtype=float32), array([-0.13499998], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23276924],
#        [-0.01700329]], dtype=float32), array([-0.13299997], dtype=float32)]
#
#
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.25026459],
#        [-0.04180296]], dtype=float32), array([-0.13899997], dtype=float32)]
#
#
#  z:  [3.4 1.5] y:  1
#
#  w 12 :
#  [array([[-0.23575959],
#        [-0.03090212]], dtype=float32), array([-0.13499998], dtype=float32)]
#
#
#  z:  [3. 5.] y:  -1
#
#  w 13 :
#  [array([[-0.24975488],
#        [-0.0413015 ]], dtype=float32), array([-0.13999997], dtype=float32)]
#
#
#  z:  [3.  4.9] y:  -1
#
#  w 14 :
#  [array([[-0.23734988],
#        [-0.02460068]], dtype=float32), array([-0.13599998], dtype=float32)]
#
#
#  z:  [3.2 4.8] y:  -1
# 150/150 [==============================] - 0s 544us/step - loss: 0.7092 - categorical_accuracy: 1.0000
# Epoch 21/40
#
#  w 0 :
#  [array([[-0.23784514],
#        [-0.03580019]], dtype=float32), array([-0.13699998], dtype=float32)]
#
#  10/150 [=>............................] - ETA: 0s - loss: 0.8257 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[-0.23464037],
#        [-0.02579947]], dtype=float32), array([-0.13599998], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[-0.25233567],
#        [-0.04239895]], dtype=float32), array([-0.14199997], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[-0.23613063],
#        [-0.0244981 ]], dtype=float32), array([-0.13699998], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[-0.2515259 ],
#        [-0.04019761]], dtype=float32), array([-0.14199997], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
#
#  w 5 :
#  [array([[-0.25352088],
#        [-0.04089681]], dtype=float32), array([-0.14299998], dtype=float32)]
#
#
#  z:  [2.7 3.9] y:  -1
#
#  w 6 :
#  [array([[-0.2414158 ],
#        [-0.02509599]], dtype=float32), array([-0.13899998], dtype=float32)]
#
#
#  z:  [3.  6.6] y:  -1
#
#  w 7 :
#  [array([[-0.26181096],
#        [-0.05119549]], dtype=float32), array([-0.14599998], dtype=float32)]
#
#
#  z:  [3.  5.2] y:  -1
#
#  w 8 :
#  [array([[-0.24730572],
#        [-0.03229446]], dtype=float32), array([-0.14099999], dtype=float32)]
#
#
#  z:  [3.1 4.7] y:  -1
#
#  w 9 :
#  [array([[-0.23630078],
#        [-0.02269382]], dtype=float32), array([-0.13799998], dtype=float32)]
#
#
#  z:  [2.7 5.3] y:  -1
#
#  w 10 :
#  [array([[-0.23069605],
#        [-0.01619336]], dtype=float32), array([-0.13599998], dtype=float32)]
#
# 110/150 [=====================>........] - ETA: 0s - loss: 0.6383 - categorical_accuracy: 1.0000
#  z:  [3.2 4.7] y:  -1
#
#  w 11 :
#  [array([[-0.24819145],
# ...
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.72534245],
#        [-0.816655  ]], dtype=float32), array([-0.00132961], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 217us/step - loss: 0.0100 - categorical_accuracy: 1.0000
# Epoch 83/100
#
#  w 0 :
#  [array([[ 0.7243734 ],
#        [-0.81909317]], dtype=float32), array([-0.00178416], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0033 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7253277],
#        [-0.8185768]], dtype=float32), array([-0.00147166], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.72640693],
#        [-0.8185917 ]], dtype=float32), array([-0.00115916], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7263299],
#        [-0.8191066]], dtype=float32), array([-0.00115916], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7263154],
#        [-0.8190902]], dtype=float32), array([-0.00115916], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 188us/step - loss: 0.0099 - categorical_accuracy: 1.0000
# Epoch 84/100
#
#  w 0 :
#  [array([[ 0.7253463],
#        [-0.8215284]], dtype=float32), array([-0.0016137], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0033 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7263006 ],
#        [-0.82101196]], dtype=float32), array([-0.0013012], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7273798],
#        [-0.8210268]], dtype=float32), array([-0.0009887], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.72730273],
#        [-0.8215416 ]], dtype=float32), array([-0.0009887], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7272882 ],
#        [-0.82152516]], dtype=float32), array([-0.0009887], dtype=float32)]
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 282us/step - loss: 0.0098 - categorical_accuracy: 1.0000
# Epoch 85/100
#
#  w 0 :
#  [array([[ 0.7263191],
#        [-0.8239633]], dtype=float32), array([-0.00144325], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0033 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7272733],
#        [-0.8234468]], dtype=float32), array([-0.00113075], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7283525],
#        [-0.8234616]], dtype=float32), array([-0.00081825], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7282754],
#        [-0.8239764]], dtype=float32), array([-0.00081825], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7282609 ],
#        [-0.82395995]], dtype=float32), array([-0.00081825], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 220us/step - loss: 0.0097 - categorical_accuracy: 1.0000
# Epoch 86/100
#
#  w 0 :
#  [array([[ 0.72729176],
#        [-0.826398  ]], dtype=float32), array([-0.00127279], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0034 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.728246 ],
#        [-0.8258815]], dtype=float32), array([-0.00096029], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7293252],
#        [-0.8258962]], dtype=float32), array([-0.00064779], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7292481 ],
#        [-0.82641095]], dtype=float32), array([-0.00064779], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7292335 ],
#        [-0.82639444]], dtype=float32), array([-0.00064779], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 232us/step - loss: 0.0095 - categorical_accuracy: 1.0000
# Epoch 87/100
#
#  w 0 :
#  [array([[ 0.7282644 ],
#        [-0.82883245]], dtype=float32), array([-0.00110234], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0034 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7292186 ],
#        [-0.82831585]], dtype=float32), array([-0.00078984], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.73029774],
#        [-0.8283305 ]], dtype=float32), array([-0.00047734], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7302206],
#        [-0.8288452]], dtype=float32), array([-0.00047734], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.730206  ],
#        [-0.82882863]], dtype=float32), array([-0.00047734], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 220us/step - loss: 0.0094 - categorical_accuracy: 1.0000
# Epoch 88/100
#
#  w 0 :
#  [array([[ 0.7304187],
#        [-0.8296757]], dtype=float32), array([-0.00047734], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0032 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.73137283],
#        [-0.8291591 ]], dtype=float32), array([-0.00016484], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.732452  ],
#        [-0.82917374]], dtype=float32), array([0.00014766], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.73237485],
#        [-0.82968843]], dtype=float32), array([0.00014766], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7323602 ],
#        [-0.82967186]], dtype=float32), array([0.00014766], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 285us/step - loss: 0.0093 - categorical_accuracy: 1.0000
# Epoch 89/100
#
#  w 0 :
#  [array([[ 0.731391 ],
#        [-0.8321098]], dtype=float32), array([-0.00030688], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0032 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.73234516],
#        [-0.83159316]], dtype=float32), array([5.615031e-06], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.73342425],
#        [-0.83160776]], dtype=float32), array([0.00031812], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.73334706],
#        [-0.8321224 ]], dtype=float32), array([0.00031812], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7333324 ],
#        [-0.83210576]], dtype=float32), array([0.00031812], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 271us/step - loss: 0.0093 - categorical_accuracy: 1.0000
# Epoch 90/100
#
#  w 0 :
#  [array([[ 0.733545  ],
#        [-0.83295274]], dtype=float32), array([0.00031812], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0031 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7344991],
#        [-0.8324361]], dtype=float32), array([0.00063062], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7355782],
#        [-0.8324507]], dtype=float32), array([0.00094312], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.735501 ],
#        [-0.8329653]], dtype=float32), array([0.00094312], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.73548627],
#        [-0.8329487 ]], dtype=float32), array([0.00094312], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 286us/step - loss: 0.0091 - categorical_accuracy: 1.0000
# Epoch 91/100
#
#  w 0 :
#  [array([[ 0.7356988 ],
#        [-0.83379567]], dtype=float32), array([0.00094312], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0029 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.73665285],
#        [-0.833279  ]], dtype=float32), array([0.00125562], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7377319],
#        [-0.8332936]], dtype=float32), array([0.00156812], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7376546],
#        [-0.8338082]], dtype=float32), array([0.00156812], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.73763984],
#        [-0.8337915 ]], dtype=float32), array([0.00156812], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 204us/step - loss: 0.0090 - categorical_accuracy: 1.0000
# Epoch 92/100
#
#  w 0 :
#  [array([[ 0.73667055],
#        [-0.8362294 ]], dtype=float32), array([0.00111357], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0029 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7376246],
#        [-0.8357127]], dtype=float32), array([0.00142607], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7387036],
#        [-0.8357272]], dtype=float32), array([0.00173857], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.73862636],
#        [-0.8362417 ]], dtype=float32), array([0.00173857], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7386116],
#        [-0.836225 ]], dtype=float32), array([0.00173857], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 194us/step - loss: 0.0089 - categorical_accuracy: 1.0000
# Epoch 93/100
#
#  w 0 :
#  [array([[ 0.73882407],
#        [-0.8370719 ]], dtype=float32), array([0.00173857], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0027 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.73977804],
#        [-0.8365552 ]], dtype=float32), array([0.00205107], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.740857 ],
#        [-0.8365697]], dtype=float32), array([0.00236357], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7407797 ],
#        [-0.83708423]], dtype=float32), array([0.00236357], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.74076486],
#        [-0.8370675 ]], dtype=float32), array([0.00236357], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 245us/step - loss: 0.0088 - categorical_accuracy: 1.0000
# Epoch 94/100
#
#  w 0 :
#  [array([[ 0.7409773],
#        [-0.8379144]], dtype=float32), array([0.00236357], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0025 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7419312 ],
#        [-0.83739763]], dtype=float32), array([0.00267607], dtype=float32)]
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7430101],
#        [-0.8374121]], dtype=float32), array([0.00298857], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.74293274],
#        [-0.8379266 ]], dtype=float32), array([0.00298857], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7429179],
#        [-0.8379099]], dtype=float32), array([0.00298857], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 195us/step - loss: 0.0087 - categorical_accuracy: 1.0000
# Epoch 95/100
#
#  w 0 :
#  [array([[ 0.7419485 ],
#        [-0.84034765]], dtype=float32), array([0.00253402], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0026 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7429024],
#        [-0.8398308]], dtype=float32), array([0.00284652], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7439813 ],
#        [-0.83984524]], dtype=float32), array([0.00315902], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.74390393],
#        [-0.8403597 ]], dtype=float32), array([0.00315902], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.74388903],
#        [-0.8403429 ]], dtype=float32), array([0.00315902], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 201us/step - loss: 0.0086 - categorical_accuracy: 1.0000
# Epoch 96/100
#
#  w 0 :
#  [array([[ 0.7441014],
#        [-0.8411897]], dtype=float32), array([0.00315902], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0024 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.74505526],
#        [-0.84067285]], dtype=float32), array([0.00347152], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7461341],
#        [-0.8406873]], dtype=float32), array([0.00378402], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7460567],
#        [-0.8412017]], dtype=float32), array([0.00378402], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.7460418],
#        [-0.8411849]], dtype=float32), array([0.00378402], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 243us/step - loss: 0.0085 - categorical_accuracy: 1.0000
# Epoch 97/100
#
#  w 0 :
#  [array([[ 0.74625415],
#        [-0.8420317 ]], dtype=float32), array([0.00378402], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0022 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.747208 ],
#        [-0.8415149]], dtype=float32), array([0.00409652], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7482868],
#        [-0.8415293]], dtype=float32), array([0.00440902], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7482093 ],
#        [-0.84204376]], dtype=float32), array([0.00440902], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.74819434],
#        [-0.8420269 ]], dtype=float32), array([0.00440902], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 221us/step - loss: 0.0084 - categorical_accuracy: 1.0000
# Epoch 98/100
#
#  w 0 :
#  [array([[ 0.7472248],
#        [-0.8444646]], dtype=float32), array([0.00395448], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0022 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7481786],
#        [-0.8439477]], dtype=float32), array([0.00426698], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7492574],
#        [-0.8439621]], dtype=float32), array([0.00457948], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7491799 ],
#        [-0.84447646]], dtype=float32), array([0.00457948], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.74916494],
#        [-0.8444596 ]], dtype=float32), array([0.00457948], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 193us/step - loss: 0.0083 - categorical_accuracy: 1.0000
# Epoch 99/100
#
#  w 0 :
#  [array([[ 0.74937725],
#        [-0.84530634]], dtype=float32), array([0.00457948], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0021 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.750331  ],
#        [-0.84478945]], dtype=float32), array([0.00489198], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7514097],
#        [-0.8448038]], dtype=float32), array([0.00520448], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.75133216],
#        [-0.84531814]], dtype=float32), array([0.00520448], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.75131714],
#        [-0.8453012 ]], dtype=float32), array([0.00520448], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 268us/step - loss: 0.0082 - categorical_accuracy: 1.0000
# Epoch 100/100
#
#  w 0 :
#  [array([[ 0.7490294],
#        [-0.8483752]], dtype=float32), array([0.00429539], dtype=float32)]
#
#  32/150 [=====>........................] - ETA: 0s - loss: 0.0023 - categorical_accuracy: 1.0000
#  z:  [3.  1.4] y:  1
#
#  w 1 :
#  [array([[ 0.7499832 ],
#        [-0.84785825]], dtype=float32), array([0.00460789], dtype=float32)]
#
#
#  z:  [2.9 4.7] y:  -1
#
#  w 2 :
#  [array([[ 0.7510619 ],
#        [-0.84787256]], dtype=float32), array([0.00492039], dtype=float32)]
#
#
#  z:  [2.6 4. ] y:  -1
#
#  w 3 :
#  [array([[ 0.7509844],
#        [-0.8483868]], dtype=float32), array([0.00492039], dtype=float32)]
#
#
#  z:  [3.2 1.3] y:  1
#
#  w 4 :
#  [array([[ 0.75096935],
#        [-0.84836984]], dtype=float32), array([0.00492039], dtype=float32)]
#
#
#  z:  [3.1 1.5] y:  1
# 150/150 [==============================] - 0s 222us/step - loss: 0.0082 - categorical_accuracy: 1.0000

# %% [markdown]
# As expected, after calling the CALL BACKS, our algorithm looks way better.
